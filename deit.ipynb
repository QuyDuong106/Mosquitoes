# %% [markdown]
# # Lib

# %%
# !pip uninstall -y torch torchvision torchaudio

# !pip install --pre torch torchvision torchaudio \
  --index-url https://download.pytorch.org/whl/nightly/cu128
# Out:
# Found existing installation: torch 2.10.0+cu128
# Uninstalling torch-2.10.0+cu128:
#   Successfully uninstalled torch-2.10.0+cu128
# Found existing installation: torchvision 0.25.0+cu128
# Uninstalling torchvision-0.25.0+cu128:
#   Successfully uninstalled torchvision-0.25.0+cu128
# Found existing installation: torchaudio 2.10.0+cu128
# Uninstalling torchaudio-2.10.0+cu128:
#   Successfully uninstalled torchaudio-2.10.0+cu128
# Looking in indexes: https://download.pytorch.org/whl/nightly/cu128
# Collecting torch
#   Downloading https://download-r2.pytorch.org/whl/nightly/cu128/torch-2.12.0.dev20260408%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (31 kB)
# Collecting torchvision
#   Downloading https://download-r2.pytorch.org/whl/nightly/cu128/torchvision-0.27.0.dev20260407%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting torchaudio
#   Downloading https://download-r2.pytorch.org/whl/nightly/cu128/torchaudio-2.11.0.dev20260407%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.9 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2026.2.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch) (12.9.4)
# Collecting nvidia-cudnn-cu12==9.20.0.48 (from torch)
#   Downloading https://pypi.nvidia.com/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.20.0.48-py3-none-manylinux_2_27_x86_64.whl (657.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 657.9/657.9 MB 58.6 MB/s eta 0:00:00
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Collecting nvidia-nccl-cu12==2.29.7 (from torch)
#   Downloading https://pypi.nvidia.com/nvidia-nccl-cu12/nvidia_nccl_cu12-2.29.7-py3-none-manylinux_2_18_x86_64.whl (293.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.6/293.6 MB 84.7 MB/s eta 0:00:00
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.5)
# Collecting triton==3.7.0+git282c8251 (from torch)
#   Downloading https://download-r2.pytorch.org/whl/nightly/triton-3.7.0%2Bgit282c8251-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.90)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Collecting torch
#   Downloading https://download-r2.pytorch.org/whl/nightly/cu128/torch-2.12.0.dev20260407%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (31 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Collecting triton==3.7.0+git9c288bc5 (from torch)
#   Downloading https://download-r2.pytorch.org/whl/nightly/triton-3.7.0%2Bgit9c288bc5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch) (1.3.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Downloading https://download-r2.pytorch.org/whl/nightly/cu128/torchvision-0.27.0.dev20260407%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 33.7 MB/s eta 0:00:00
# Downloading https://download-r2.pytorch.org/whl/nightly/cu128/torch-2.12.0.dev20260407%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl (832.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 832.5/832.5 MB 2.1 MB/s eta 0:00:00
# Downloading https://download-r2.pytorch.org/whl/nightly/triton-3.7.0%2Bgit9c288bc5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (292.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.2/292.2 MB 6.0 MB/s eta 0:00:00
# Downloading https://download-r2.pytorch.org/whl/nightly/cu128/torchaudio-2.11.0.dev20260407%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 34.7 MB/s eta 0:00:00
# Installing collected packages: torchaudio, triton, nvidia-nccl-cu12, nvidia-cudnn-cu12, torch, torchvision
#   Attempting uninstall: triton
#     Found existing installation: triton 3.6.0
#     Uninstalling triton-3.6.0:
#       Successfully uninstalled triton-3.6.0
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.27.5
#     Uninstalling nvidia-nccl-cu12-2.27.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.27.5
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.10.2.21
#     Uninstalling nvidia-cudnn-cu12-9.10.2.21:
#       Successfully uninstalled nvidia-cudnn-cu12-9.10.2.21
# Successfully installed nvidia-cudnn-cu12-9.20.0.48 nvidia-nccl-cu12-2.29.7 torch-2.12.0.dev20260407+cu128 torchaudio-2.11.0.dev20260407+cu128 torchvision-0.27.0.dev20260407+cu128 triton-3.7.0+git9c288bc5

# %%
import os
from pathlib import Path
from PIL import Image
import numpy as np


import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import torch
import torch.nn as nn
import torch.distributed as dist

from torch.nn.parallel import DistributedDataParallel as DDP
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.distributed import DistributedSampler
from torchvision import transforms, models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import resample


from sklearn.metrics import (
    accuracy_score,
    precision_recall_fscore_support,
    classification_report,
    confusion_matrix,
    roc_auc_score,
    roc_curve,
    auc
)
from sklearn.preprocessing import label_binarize

# %%
import torchvision
print(torchvision.__version__)
# Out:
# 0.27.0.dev20260407+cu128

# %%
import torch

print("torch:", torch.__version__)
print("torch cuda:", torch.version.cuda)
print("cuda available:", torch.cuda.is_available())
print("gpu:", torch.cuda.get_device_name(0))
print("capability:", torch.cuda.get_device_capability(0))
# Out:
# torch: 2.12.0.dev20260407+cu128
# torch cuda: 12.8
# cuda available: True
# gpu: Tesla T4
# capability: (7, 5)

# %% [markdown]
# # Data

# %%
dataset_dir = Path("/kaggle/input/datasets/duongnguyenquy/mosquitoes-compsci760")

# # Image
# image_dir = dataset_dir / "images" / "images"
# # image_dir = dataset_dir / "image_crop" / "image_crop"

# # Annotation
# annotation_path = r"/kaggle/input/datasets/duongnguyenquy/mosquitoes-compsci760/labels/annotations.csv"
# # annotation_path = dataset_dir /"image_crop"/"image_crop"/ "cropped_annotations.csv"
image_dir = dataset_dir /"image_crop_new/image_crop_new" #original (not cropped images)
# annotation_path = dataset_dir / "image_crop_new/cropped_annotations.csv" #original dataset's csv
annotation_path = f"/kaggle/input/datasets/duongnguyenquy/mosquitoes-compsci760/image_crop_new/image_crop_new/cropped_annotations.csv"


annotations = pd.read_csv(annotation_path)
annotations.head()
# Out:
#                img_fName  img_w  img_h  bbx_xtl  bbx_ytl  bbx_xbr  bbx_ybr  \
# 0  train_00000_crop.jpeg    340    550        0        0      340      550
# 1  train_00001_crop.jpeg   1050   1093        0        0     1050     1093
# 2  train_00002_crop.jpeg    439    750        0        0      439      750
# 3  train_00003_crop.jpeg    417    462        0        0      417      462
# 4  train_00004_crop.jpeg    568    776        0        0      568      776
#
#   class_label      source_image
# 0  albopictus  train_00000.jpeg
# 1  albopictus  train_00001.jpeg
# 2  albopictus  train_00002.jpeg
# 3  albopictus  train_00003.jpeg
# 4       culex  train_00004.jpeg

# %%
annotations.columns
# Out:
# Index(['img_fName', 'img_w', 'img_h', 'bbx_xtl', 'bbx_ytl', 'bbx_xbr',
#        'bbx_ybr', 'class_label', 'source_image'],
#       dtype='object')

# %%
annotations.shape
# Out:
# (10485, 9)

# %%
print("Image dir exists:", image_dir.exists())
print("CSV rows:", len(annotations))
print("CSV columns:", annotations.columns.tolist())

# Get image names from CSV
csv_images = set(annotations["img_fName"].astype(str))

# Get actual image files in folder
image_exts = {".jpg", ".jpeg", ".png"}
folder_images = {
    p.name
    for p in image_dir.iterdir()
    if p.is_file() and p.suffix.lower() in image_exts
}

missing_files = sorted(csv_images - folder_images)
extra_files = sorted(folder_images - csv_images)

print("Unique images in CSV:", len(csv_images))
print("Image files in folder:", len(folder_images))
print("Missing image files:", len(missing_files))
print("Extra image files:", len(extra_files))

if missing_files:
    print("\nFirst missing files:")
    print(missing_files[:20])

if extra_files:
    print("\nFirst extra files:")
    print(extra_files[:20])

if not missing_files:
    print("\nAll CSV image names have matching image files.")
# Out:
# Image dir exists: True
# CSV rows: 10485
# CSV columns: ['img_fName', 'img_w', 'img_h', 'bbx_xtl', 'bbx_ytl', 'bbx_xbr', 'bbx_ybr', 'class_label', 'source_image']
# Unique images in CSV: 10485
# Image files in folder: 10485
# Missing image files: 0
# Extra image files: 0
#
# All CSV image names have matching image files.

# %%
image_df = (
    annotations.groupby("img_fName")["class_label"]
    .agg(lambda x: x.mode().iloc[0])
    .reset_index()
)

print("Number of images:", len(image_df))
print(image_df["class_label"].value_counts())
image_df.head()
# Out:
# Number of images: 10485
# class_label
# albopictus            4655
# culex                 4638
# culiseta               632
# japonicus-koreicus     429
# anopheles               84
# aegypti                 47
# Name: count, dtype: int64
#                img_fName class_label
# 0  train_00000_crop.jpeg  albopictus
# 1  train_00001_crop.jpeg  albopictus
# 2  train_00002_crop.jpeg  albopictus
# 3  train_00003_crop.jpeg  albopictus
# 4  train_00004_crop.jpeg       culex

# %%
# number of images to show
num_images = 6

sample_df = annotations.sample(num_images, random_state=760)

plt.figure(figsize=(12, 8))

for i, (_, row) in enumerate(sample_df.iterrows()):
    img_path = image_dir / row["img_fName"]   # adjust column name if needed
    
    img = Image.open(img_path)

    plt.subplot(2, 3, i + 1)
    plt.imshow(img)
    plt.title(f"Label: {row['class_label']}")
    plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Preprocessing

# %%
label_encoder = LabelEncoder()
image_df["label_id"] = label_encoder.fit_transform(image_df["class_label"])

class_names = list(label_encoder.classes_)
num_classes = len(class_names)

print(class_names)
print("Num classes:", num_classes)
# Out:
# ['aegypti', 'albopictus', 'anopheles', 'culex', 'culiseta', 'japonicus-koreicus']
# Num classes: 6

# %% [markdown]
# # Split

# %%
train_df, temp_df = train_test_split(
    image_df,
    test_size=0.30,
    random_state=42,
    stratify=image_df["label_id"]
)

val_df, test_df = train_test_split(
    temp_df,
    test_size=0.50,
    random_state=42,
    stratify=temp_df["label_id"]
)


#Oversampling method
# train_df = oversample_dataframe(train_df, label_col="label_id")

print("Train:", len(train_df))
print("Val:", len(val_df))
print("Test:", len(test_df))

print("\nTrain label distribution after oversampling:")
print(train_df["label_id"].value_counts())
# Out:
# Train: 7339
# Val: 1573
# Test: 1573
#
# Train label distribution after oversampling:
# label_id
# 1    3258
# 3    3247
# 4     442
# 5     300
# 2      59
# 0      33
# Name: count, dtype: int64

# %%
# train_subset_df = train_df.groupby("label_id", group_keys=False).apply(
#     lambda x: x.sample(min(len(x), 50), random_state=42)
# ).reset_index(drop=True)

# val_subset_df = val_df.groupby("label_id", group_keys=False).apply(
#     lambda x: x.sample(min(len(x), 20), random_state=42)
# ).reset_index(drop=True)

# test_subset_df = test_df.groupby("label_id", group_keys=False).apply(
#     lambda x: x.sample(min(len(x), 20), random_state=42)
# ).reset_index(drop=True)

# print("Subset Train:", len(train_subset_df))
# print("Subset Val:", len(val_subset_df))
# print("Subset Test:", len(test_subset_df))

# %% [markdown]
# # Modeling

# %% [markdown]
# ## ENV

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using:", device)

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
    print("Capability:", torch.cuda.get_device_capability(0))
# Out:
# Using: cuda
# GPU: Tesla T4
# Capability: (7, 5)

# %% [markdown]
# ## Transform

# %%
image_size = 224

# train_transform = transforms.Compose([
#     transforms.Resize((image_size, image_size)),
#     transforms.RandomResizedCrop(image_size, scale=(0.8, 1.0), ratio=(0.75, 1.33)),
#     transforms.RandomHorizontalFlip(p=0.5),
#     transforms.RandomVerticalFlip(p=0.2),
#     transforms.RandomRotation(degrees=15),
#     transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1),
#     transforms.RandomGrayscale(p=0.1),
#     transforms.GaussianBlur(kernel_size=(3, 5), sigma=(0.1, 2.0)),
#     transforms.ToTensor(),
#     transforms.Normalize(mean=[0.485, 0.456, 0.406],
#                          std=[0.229, 0.224, 0.225])
# ])

# eval_transform = transforms.Compose([
#     transforms.Resize((image_size, image_size)),
#     transforms.CenterCrop(image_size),
#     transforms.ToTensor(),
#     transforms.Normalize(mean=[0.485, 0.456, 0.406],
#                          std=[0.229, 0.224, 0.225])
# ])


train_transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

eval_transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %% [markdown]
# ## Dataset

# %%
class MosquitoImageDataset(Dataset):
    def __init__(self, df, image_dir, transform=None):
        self.df = df.reset_index(drop=True)
        self.image_dir = image_dir
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        image_path = self.image_dir / row["img_fName"]
        image = Image.open(image_path).convert("RGB")
        label = int(row["label_id"])

        if self.transform:
            image = self.transform(image)

        return image, label

# %%
train_dataset = MosquitoImageDataset(train_df, image_dir, transform=train_transform)
val_dataset = MosquitoImageDataset(val_df, image_dir, transform=eval_transform)
test_dataset = MosquitoImageDataset(test_df, image_dir, transform=eval_transform)

# Subset
# train_dataset = MosquitoImageDataset(train_subset_df, image_dir, transform=train_transform)
# val_dataset = MosquitoImageDataset(val_subset_df, image_dir, transform=eval_transform)
# test_dataset = MosquitoImageDataset(test_subset_df, image_dir, transform=eval_transform)


train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=2)

# %% [markdown]
# # Baseline modeling
# - Model builder and call out

# %%
import torch
import torch.nn as nn
from torchvision import models
from torchvision.models import (
    ResNet50_Weights,
    ResNet101_Weights,
    EfficientNet_V2_L_Weights,
    EfficientNet_B0_Weights,
    MobileNet_V2_Weights,
)
import timm


def build_model(model_name, num_classes, freeze_backbone=True):
    model_name = model_name.lower()

    if model_name == "resnet50":
        model = models.resnet50(weights=ResNet50_Weights.DEFAULT)
        model.fc = nn.Linear(model.fc.in_features, num_classes)
        backbone_params = [p for name, p in model.named_parameters() if not name.startswith("fc.")]

    elif model_name == "resnet101":
        model = models.resnet101(weights=ResNet101_Weights.DEFAULT)
        model.fc = nn.Linear(model.fc.in_features, num_classes)
        backbone_params = [p for name, p in model.named_parameters() if not name.startswith("fc.")]

    elif model_name == "efficientnet_v2_l":
        model = models.efficientnet_v2_l(weights=EfficientNet_V2_L_Weights.DEFAULT)
        model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)
        backbone_params = model.features.parameters()

    elif model_name == "efficientnet_b0":
        model = models.efficientnet_b0(weights=EfficientNet_B0_Weights.DEFAULT)
        model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)
        backbone_params = model.features.parameters()

    elif model_name == "mobilenet_v2":
        model = models.mobilenet_v2(weights=MobileNet_V2_Weights.DEFAULT)
        model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)
        backbone_params = model.features.parameters()

    elif model_name == "deit_tiny":
        model = timm.create_model(
            "deit_tiny_patch16_224",
            pretrained=True,
            num_classes=num_classes
        )
        backbone_params = [
            p for name, p in model.named_parameters()
            if not name.startswith("head.")
        ]

    elif model_name == "deit_small":
        model = timm.create_model(
            "deit_small_patch16_224",
            pretrained=True,
            num_classes=num_classes
        )
        backbone_params = [
            p for name, p in model.named_parameters()
            if not name.startswith("head.")
        ]

    elif model_name == "deit_base":
        model = timm.create_model(
            "deit_base_patch16_224",
            pretrained=True,
            num_classes=num_classes
        )
        backbone_params = [
            p for name, p in model.named_parameters()
            if not name.startswith("head.")
        ]

    else:
        raise ValueError(f"Unknown model name: {model_name}")

    if freeze_backbone:
        for param in backbone_params:
            param.requires_grad = False

    return model

# %% [markdown]
# # Training process

# %% [markdown]
# ## Training 1 model builder

# %% [markdown]
# - Number of epochs: 30
# - Lr = 1e-5
# - Transfer learning
# - criterion: CrossEntropy loss
# - optimizer: Adam

# %%
def train_one_model(
    model_name,
    train_loader,
    val_loader,
    num_classes,
    class_names,
    device,
    output_dir,
    num_epochs=30,
    patience=5,
    lr=1e-5,
    freeze_backbone=True
):
    print(f"\n\n==============================")
    print(f"Start training: {model_name}")
    print(f"==============================")

    model = build_model(
        model_name=model_name,
        num_classes=num_classes,
        freeze_backbone=freeze_backbone
    ).to(device)

    criterion = nn.CrossEntropyLoss()

    optimizer = torch.optim.Adam(
        filter(lambda p: p.requires_grad, model.parameters()),
        lr=lr
    )

    best_val_loss = float("inf")
    early_stop_counter = 0
    history = []

    print("Selected device:", device)
    print("Model device:", next(model.parameters()).device)

    for epoch in range(num_epochs):
        print(f"\n===== {model_name} | Epoch {epoch + 1}/{num_epochs} =====")

        # =========================
        # Training
        # =========================
        model.train()

        train_loss = 0.0
        train_correct = 0
        train_total = 0

        for batch_idx, (images, labels) in enumerate(train_loader):
            if batch_idx == 0:
                print("Before move:")
                print("  images device:", images.device)
                print("  labels device:", labels.device)

            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            if batch_idx == 0:
                print("After move:")
                print("  images device:", images.device)
                print("  labels device:", labels.device)
                print("  model device:", next(model.parameters()).device)

                if torch.cuda.is_available():
                    print(
                        "  GPU memory allocated:",
                        torch.cuda.memory_allocated() / 1024**2,
                        "MB"
                    )
                    print(
                        "  GPU memory reserved:",
                        torch.cuda.memory_reserved() / 1024**2,
                        "MB"
                    )

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * images.size(0)

            preds = outputs.argmax(dim=1)
            train_correct += (preds == labels).sum().item()
            train_total += labels.size(0)

            if batch_idx % 10 == 0:
                print(
                    f"[Train] {model_name} | "
                    f"Epoch {epoch + 1} Batch {batch_idx}/{len(train_loader)} | "
                    f"Loss: {loss.item():.4f}"
                )

        train_loss /= train_total
        train_acc = train_correct / train_total

        # =========================
        # Validation
        # =========================
        model.eval()

        val_loss = 0.0
        val_correct = 0
        val_total = 0

        with torch.no_grad():
            for batch_idx, (images, labels) in enumerate(val_loader):
                images = images.to(device, non_blocking=True)
                labels = labels.to(device, non_blocking=True)

                outputs = model(images)
                loss = criterion(outputs, labels)

                val_loss += loss.item() * images.size(0)

                preds = outputs.argmax(dim=1)
                val_correct += (preds == labels).sum().item()
                val_total += labels.size(0)

                if batch_idx % 10 == 0:
                    print(
                        f"[Val] {model_name} | "
                        f"Epoch {epoch + 1} Batch {batch_idx}/{len(val_loader)} | "
                        f"Loss: {loss.item():.4f}"
                    )

        val_loss /= val_total
        val_acc = val_correct / val_total

        print(
            f"{model_name} | Epoch {epoch + 1}/{num_epochs} | "
            f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f} | "
            f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}"
        )

        # =========================
        # Save history
        # =========================
        epoch_result = {
            "model_name": model_name,
            "epoch": epoch + 1,
            "train_loss": train_loss,
            "train_acc": train_acc,
            "val_loss": val_loss,
            "val_acc": val_acc,
            "best_val_loss_so_far": min(best_val_loss, val_loss),
            "early_stop_counter": early_stop_counter,
        }

        history.append(epoch_result)

        history_path = output_dir / f"{model_name}_training_history.csv"
        pd.DataFrame(history).to_csv(history_path, index=False)

        # =========================
        # Save best model
        # =========================
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            early_stop_counter = 0

            best_model_path = output_dir / f"best_{model_name}.pth"

            torch.save({
                "model_name": model_name,
                "epoch": epoch + 1,
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
                "train_loss": train_loss,
                "val_loss": val_loss,
                "train_acc": train_acc,
                "val_acc": val_acc,
                "class_names": class_names,
            }, best_model_path)

            print(f"Best model updated and saved to: {best_model_path}")

        else:
            early_stop_counter += 1
            print(
                f"No improvement. Early stop counter: "
                f"{early_stop_counter}/{patience}"
            )

        # update latest history with new early stop counter
        history[-1]["early_stop_counter"] = early_stop_counter
        pd.DataFrame(history).to_csv(history_path, index=False)

        if early_stop_counter >= patience:
            print(f"Early stopping triggered for {model_name}.")
            break

    # =========================
    # Final benchmark result
    # =========================
    history_df = pd.DataFrame(history)

    best_row = history_df.loc[history_df["val_loss"].idxmin()]

    benchmark_result = {
        "model_name": model_name,
        "best_epoch": int(best_row["epoch"]),
        "best_train_loss": float(best_row["train_loss"]),
        "best_train_acc": float(best_row["train_acc"]),
        "best_val_loss": float(best_row["val_loss"]),
        "best_val_acc": float(best_row["val_acc"]),
        "total_epochs_trained": len(history_df),
        "early_stopped": early_stop_counter >= patience,
        "best_model_path": str(output_dir / f"best_{model_name}.pth"),
        "history_path": str(history_path),
    }

    print(f"Training completed for {model_name}.")
    print("Best validation accuracy:", benchmark_result["best_val_acc"])

    return benchmark_result, history_df

# %%
MODEL_NAMES = [
    # "resnet101",
    # "efficientnet_v2_l"
    # "resnet50",
    # "efficientnet_b0",
    # "mobilenet_v2",
    "deit_base", "deit_small", "deit_tiny"
]

# %%
output_dir = Path("/kaggle/working/")
output_dir.mkdir(parents=True, exist_ok=True)


all_benchmarks = []

for model_name in MODEL_NAMES:
    benchmark_result, history_df = train_one_model(
        model_name=model_name,
        train_loader=train_loader,
        val_loader=val_loader,
        num_classes=num_classes,
        class_names=class_names,
        device=device,
        output_dir=output_dir,
        num_epochs=30,
        patience=5,
        lr=1e-5,
        freeze_backbone=True
    )

    all_benchmarks.append(benchmark_result)

# =========================
# Save combined benchmark
# =========================

benchmark_df = pd.DataFrame(all_benchmarks)

benchmark_path = output_dir / "model_benchmark_summary.csv"
benchmark_df.to_csv(benchmark_path, index=False)

print("\nAll model training completed.")
print(f"Benchmark summary saved to: {benchmark_path}")

benchmark_df
# Out:
# ==============================
# Start training: deit_base
# ==============================
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Selected device: cuda
# Model device: cuda:0
#
# ===== deit_base | Epoch 1/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 345.689453125 MB
#   GPU memory reserved: 402.0 MB
# [Train] deit_base | Epoch 1 Batch 0/230 | Loss: 2.1548
# [Train] deit_base | Epoch 1 Batch 10/230 | Loss: 2.2006
# [Train] deit_base | Epoch 1 Batch 20/230 | Loss: 2.0235
# [Train] deit_base | Epoch 1 Batch 30/230 | Loss: 2.2231
# [Train] deit_base | Epoch 1 Batch 40/230 | Loss: 2.2431
# [Train] deit_base | Epoch 1 Batch 50/230 | Loss: 2.2719
# [Train] deit_base | Epoch 1 Batch 60/230 | Loss: 2.0509
# [Train] deit_base | Epoch 1 Batch 70/230 | Loss: 1.9972
# [Train] deit_base | Epoch 1 Batch 80/230 | Loss: 2.0789
# [Train] deit_base | Epoch 1 Batch 90/230 | Loss: 1.9390
# [Train] deit_base | Epoch 1 Batch 100/230 | Loss: 2.0748
# [Train] deit_base | Epoch 1 Batch 110/230 | Loss: 1.9478
# [Train] deit_base | Epoch 1 Batch 120/230 | Loss: 1.9442
# [Train] deit_base | Epoch 1 Batch 130/230 | Loss: 1.9991
# [Train] deit_base | Epoch 1 Batch 140/230 | Loss: 1.8433
# [Train] deit_base | Epoch 1 Batch 150/230 | Loss: 1.7646
# [Train] deit_base | Epoch 1 Batch 160/230 | Loss: 1.8155
# [Train] deit_base | Epoch 1 Batch 170/230 | Loss: 1.7627
# [Train] deit_base | Epoch 1 Batch 180/230 | Loss: 1.8564
# [Train] deit_base | Epoch 1 Batch 190/230 | Loss: 1.6997
# [Train] deit_base | Epoch 1 Batch 200/230 | Loss: 1.8073
# [Train] deit_base | Epoch 1 Batch 210/230 | Loss: 1.7835
# [Train] deit_base | Epoch 1 Batch 220/230 | Loss: 1.5701
# [Val] deit_base | Epoch 1 Batch 0/50 | Loss: 1.6607
# [Val] deit_base | Epoch 1 Batch 10/50 | Loss: 1.8043
# [Val] deit_base | Epoch 1 Batch 20/50 | Loss: 1.7156
# [Val] deit_base | Epoch 1 Batch 30/50 | Loss: 1.6716
# [Val] deit_base | Epoch 1 Batch 40/50 | Loss: 1.6113
# deit_base | Epoch 1/30 | Train Loss: 1.9384 | Train Acc: 0.1551 | Val Loss: 1.6861 | Val Acc: 0.3560
# Best model updated and saved to: /kaggle/working/best_deit_base.pth
#
# ===== deit_base | Epoch 2/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 362.6201171875 MB
#   GPU memory reserved: 686.0 MB
# [Train] deit_base | Epoch 2 Batch 0/230 | Loss: 1.5915
# [Train] deit_base | Epoch 2 Batch 10/230 | Loss: 1.6903
# [Train] deit_base | Epoch 2 Batch 20/230 | Loss: 1.6351
# [Train] deit_base | Epoch 2 Batch 30/230 | Loss: 1.5952
# [Train] deit_base | Epoch 2 Batch 40/230 | Loss: 1.6566
# [Train] deit_base | Epoch 2 Batch 50/230 | Loss: 1.6932
# [Train] deit_base | Epoch 2 Batch 60/230 | Loss: 1.6093
# [Train] deit_base | Epoch 2 Batch 70/230 | Loss: 1.6683
# [Train] deit_base | Epoch 2 Batch 80/230 | Loss: 1.4837
# [Train] deit_base | Epoch 2 Batch 90/230 | Loss: 1.4819
# [Train] deit_base | Epoch 2 Batch 100/230 | Loss: 1.5079
# [Train] deit_base | Epoch 2 Batch 110/230 | Loss: 1.5592
# [Train] deit_base | Epoch 2 Batch 120/230 | Loss: 1.5222
# [Train] deit_base | Epoch 2 Batch 130/230 | Loss: 1.4493
# [Train] deit_base | Epoch 2 Batch 140/230 | Loss: 1.4275
# [Train] deit_base | Epoch 2 Batch 150/230 | Loss: 1.4150
# [Train] deit_base | Epoch 2 Batch 160/230 | Loss: 1.4667
# [Train] deit_base | Epoch 2 Batch 170/230 | Loss: 1.4003
# [Train] deit_base | Epoch 2 Batch 180/230 | Loss: 1.3781
# [Train] deit_base | Epoch 2 Batch 190/230 | Loss: 1.2794
# [Train] deit_base | Epoch 2 Batch 200/230 | Loss: 1.2973
# [Train] deit_base | Epoch 2 Batch 210/230 | Loss: 1.4332
# [Train] deit_base | Epoch 2 Batch 220/230 | Loss: 1.4281
# [Val] deit_base | Epoch 2 Batch 0/50 | Loss: 1.3397
# [Val] deit_base | Epoch 2 Batch 10/50 | Loss: 1.5513
# [Val] deit_base | Epoch 2 Batch 20/50 | Loss: 1.4038
# [Val] deit_base | Epoch 2 Batch 30/50 | Loss: 1.3662
# [Val] deit_base | Epoch 2 Batch 40/50 | Loss: 1.3410
# deit_base | Epoch 2/30 | Train Loss: 1.4986 | Train Acc: 0.4715 | Val Loss: 1.3828 | Val Acc: 0.5842
# Best model updated and saved to: /kaggle/working/best_deit_base.pth
#
# ===== deit_base | Epoch 3/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 362.6201171875 MB
#   GPU memory reserved: 686.0 MB
# [Train] deit_base | Epoch 3 Batch 0/230 | Loss: 1.4073
# [Train] deit_base | Epoch 3 Batch 10/230 | Loss: 1.3704
# [Train] deit_base | Epoch 3 Batch 20/230 | Loss: 1.3377
# [Train] deit_base | Epoch 3 Batch 30/230 | Loss: 1.3428
# [Train] deit_base | Epoch 3 Batch 40/230 | Loss: 1.2659
# [Train] deit_base | Epoch 3 Batch 50/230 | Loss: 1.2600
# [Train] deit_base | Epoch 3 Batch 60/230 | Loss: 1.1823
# [Train] deit_base | Epoch 3 Batch 70/230 | Loss: 1.1677
# [Train] deit_base | Epoch 3 Batch 80/230 | Loss: 1.3098
# [Train] deit_base | Epoch 3 Batch 90/230 | Loss: 1.4445
# [Train] deit_base | Epoch 3 Batch 100/230 | Loss: 1.3610
# [Train] deit_base | Epoch 3 Batch 110/230 | Loss: 1.5015
# [Train] deit_base | Epoch 3 Batch 120/230 | Loss: 1.1327
# [Train] deit_base | Epoch 3 Batch 130/230 | Loss: 1.3449
# [Train] deit_base | Epoch 3 Batch 140/230 | Loss: 1.0968
# [Train] deit_base | Epoch 3 Batch 150/230 | Loss: 1.2546
# [Train] deit_base | Epoch 3 Batch 160/230 | Loss: 1.2029
# [Train] deit_base | Epoch 3 Batch 170/230 | Loss: 1.0643
# [Train] deit_base | Epoch 3 Batch 180/230 | Loss: 1.0506
# [Train] deit_base | Epoch 3 Batch 190/230 | Loss: 1.0769
# [Train] deit_base | Epoch 3 Batch 200/230 | Loss: 1.0300
# [Train] deit_base | Epoch 3 Batch 210/230 | Loss: 1.1818
# [Train] deit_base | Epoch 3 Batch 220/230 | Loss: 1.2300
# [Val] deit_base | Epoch 3 Batch 0/50 | Loss: 1.1412
# [Val] deit_base | Epoch 3 Batch 10/50 | Loss: 1.3953
# [Val] deit_base | Epoch 3 Batch 20/50 | Loss: 1.2046
# [Val] deit_base | Epoch 3 Batch 30/50 | Loss: 1.1646
# [Val] deit_base | Epoch 3 Batch 40/50 | Loss: 1.1712
# deit_base | Epoch 3/30 | Train Loss: 1.2418 | Train Acc: 0.6055 | Val Loss: 1.1915 | Val Acc: 0.6961
# Best model updated and saved to: /kaggle/working/best_deit_base.pth
#
# ===== deit_base | Epoch 4/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 362.6201171875 MB
#   GPU memory reserved: 686.0 MB
# [Train] deit_base | Epoch 4 Batch 0/230 | Loss: 1.1754
# [Train] deit_base | Epoch 4 Batch 10/230 | Loss: 1.1549
# [Train] deit_base | Epoch 4 Batch 20/230 | Loss: 1.1322
# [Train] deit_base | Epoch 4 Batch 30/230 | Loss: 1.0828
# [Train] deit_base | Epoch 4 Batch 40/230 | Loss: 1.1323
# [Train] deit_base | Epoch 4 Batch 50/230 | Loss: 1.1660
# [Train] deit_base | Epoch 4 Batch 60/230 | Loss: 0.8918
# [Train] deit_base | Epoch 4 Batch 70/230 | Loss: 1.3087
# [Train] deit_base | Epoch 4 Batch 80/230 | Loss: 1.0772
# [Train] deit_base | Epoch 4 Batch 90/230 | Loss: 1.0716
# [Train] deit_base | Epoch 4 Batch 100/230 | Loss: 1.1055
# [Train] deit_base | Epoch 4 Batch 110/230 | Loss: 1.2045
# [Train] deit_base | Epoch 4 Batch 120/230 | Loss: 1.1040
# [Train] deit_base | Epoch 4 Batch 130/230 | Loss: 0.8665
# [Train] deit_base | Epoch 4 Batch 140/230 | Loss: 0.9069
# [Train] deit_base | Epoch 4 Batch 150/230 | Loss: 1.1904
# [Train] deit_base | Epoch 4 Batch 160/230 | Loss: 1.0009
# [Train] deit_base | Epoch 4 Batch 170/230 | Loss: 0.9864
# [Train] deit_base | Epoch 4 Batch 180/230 | Loss: 0.9101
# [Train] deit_base | Epoch 4 Batch 190/230 | Loss: 1.0027
# [Train] deit_base | Epoch 4 Batch 200/230 | Loss: 1.1201
# [Train] deit_base | Epoch 4 Batch 210/230 | Loss: 0.9204
# [Train] deit_base | Epoch 4 Batch 220/230 | Loss: 1.1500
# [Val] deit_base | Epoch 4 Batch 0/50 | Loss: 1.0094
# [Val] deit_base | Epoch 4 Batch 10/50 | Loss: 1.2887
# [Val] deit_base | Epoch 4 Batch 20/50 | Loss: 1.0717
# [Val] deit_base | Epoch 4 Batch 30/50 | Loss: 1.0230
# [Val] deit_base | Epoch 4 Batch 40/50 | Loss: 1.0547
# deit_base | Epoch 4/30 | Train Loss: 1.0889 | Train Acc: 0.7009 | Val Loss: 1.0634 | Val Acc: 0.7629
# Best model updated and saved to: /kaggle/working/best_deit_base.pth
#
# ===== deit_base | Epoch
# [Train] deit_base | Epoch 6 Batch 120/230 | Loss: 0.8563
# [Train] deit_base | Epoch 6 Batch 130/230 | Loss: 0.8404
# [Train] deit_base | Epoch 6 Batch 140/230 | Loss: 0.7769
# [Train] deit_base | Epoch 6 Batch 150/230 | Loss: 0.8700
# [Train] deit_base | Epoch 6 Batch 160/230 | Loss: 1.0346
# [Train] deit_base | Epoch 6 Batch 170/230 | Loss: 0.7059
# [Train] deit_base | Epoch 6 Batch 180/230 | Loss: 0.9539
# [Train] deit_base | Epoch 6 Batch 190/230 | Loss: 1.0029
# [Train] deit_base | Epoch 6 Batch 200/230 | Loss: 0.9756
# [Train] deit_base | Epoch 6 Batch 210/230 | Loss: 0.8822
# [Train] deit_base | Epoch 6 Batch 220/230 | Loss: 0.9039
# [Val] deit_base | Epoch 6 Batch 0/50 | Loss: 0.8498
# [Val] deit_base | Epoch 6 Batch 10/50 | Loss: 1.1454
# [Val] deit_base | Epoch 6 Batch 20/50 | Loss: 0.9114
# [Val] deit_base | Epoch 6 Batch 30/50 | Loss: 0.8400
# [Val] deit_base | Epoch 6 Batch 40/50 | Loss: 0.9054
# deit_base | Epoch 6/30 | Train Loss: 0.9121 | Train Acc: 0.7873 | Val Loss: 0.9053 | Val Acc: 0.8086
# Best model updated and saved to: /kaggle/working/best_deit_base.pth
#
# ===== deit_base | Epoch 7/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 362.6201171875 MB
#   GPU memory reserved: 686.0 MB
# [Train] deit_base | Epoch 7 Batch 0/230 | Loss: 0.7956
# [Train] deit_base | Epoch 7 Batch 10/230 | Loss: 1.0578
# [Train] deit_base | Epoch 7 Batch 20/230 | Loss: 0.6858
# [Train] deit_base | Epoch 7 Batch 30/230 | Loss: 0.8115
# [Train] deit_base | Epoch 7 Batch 40/230 | Loss: 0.8133
# [Train] deit_base | Epoch 7 Batch 50/230 | Loss: 0.8912
# [Train] deit_base | Epoch 7 Batch 60/230 | Loss: 0.8447
# [Train] deit_base | Epoch 7 Batch 70/230 | Loss: 0.8877
# [Train] deit_base | Epoch 7 Batch 80/230 | Loss: 1.1113
# [Train] deit_base | Epoch 7 Batch 90/230 | Loss: 0.7628
# [Train] deit_base | Epoch 7 Batch 100/230 | Loss: 0.9395
# [Train] deit_base | Epoch 7 Batch 110/230 | Loss: 0.7330
# [Train] deit_base | Epoch 7 Batch 120/230 | Loss: 0.9331
# [Train] deit_base | Epoch 7 Batch 130/230 | Loss: 0.8461
# [Train] deit_base | Epoch 7 Batch 140/230 | Loss: 0.7498
# [Train] deit_base | Epoch 7 Batch 150/230 | Loss: 1.0764
# [Train] deit_base | Epoch 7 Batch 160/230 | Loss: 0.8495
# [Train] deit_base | Epoch 7 Batch 170/230 | Loss: 0.8469
# [Train] deit_base | Epoch 7 Batch 180/230 | Loss: 0.7228
# [Train] deit_base | Epoch 7 Batch 190/230 | Loss: 0.7985
# [Train] deit_base | Epoch 7 Batch 200/230 | Loss: 0.7341
# [Train] deit_base | Epoch 7 Batch 210/230 | Loss: 0.6746
# [Train] deit_base | Epoch 7 Batch 220/230 | Loss: 0.8225
# [Val] deit_base | Epoch 7 Batch 0/50 | Loss: 0.7975
# [Val] deit_base | Epoch 7 Batch 10/50 | Loss: 1.0930
# [Val] deit_base | Epoch 7 Batch 20/50 | Loss: 0.8592
# [Val] deit_base | Epoch 7 Batch 30/50 | Loss: 0.7778
# [Val] deit_base | Epoch 7 Batch 40/50 | Loss: 0.8539
# deit_base | Epoch 7/30 | Train Loss: 0.8532 | Train Acc: 0.8008 | Val Loss: 0.8521 | Val Acc: 0.8169
# Best model updated and saved to: /kaggle/working/best_deit_base.pth
#
# ===== deit_base | Epoch
# [Train] deit_base | Epoch 9 Batch 100/230 | Loss: 0.8546
# [Train] deit_base | Epoch 9 Batch 110/230 | Loss: 0.9750
# [Train] deit_base | Epoch 9 Batch 120/230 | Loss: 0.6943
# [Train] deit_base | Epoch 9 Batch 130/230 | Loss: 1.1284
# [Train] deit_base | Epoch 9 Batch 140/230 | Loss: 0.6287
# [Train] deit_base | Epoch 9 Batch 150/230 | Loss: 0.8226
# [Train] deit_base | Epoch 9 Batch 160/230 | Loss: 0.7437
# [Train] deit_base | Epoch 9 Batch 170/230 | Loss: 0.5967
# [Train] deit_base | Epoch 9 Batch 180/230 | Loss: 0.6617
# [Train] deit_base | Epoch 9 Batch 190/230 | Loss: 0.9258
# [Train] deit_base | Epoch 9 Batch 200/230 | Loss: 0.6387
# [Train] deit_base | Epoch 9 Batch 210/230 | Loss: 0.7026
# [Train] deit_base | Epoch 9 Batch 220/230 | Loss: 0.6383
# [Val] deit_base | Epoch 9 Batch 0/50 | Loss: 0.7256
# [Val] deit_base | Epoch 9 Batch 10/50 | Loss: 1.0103
# [Val] deit_base | Epoch 9 Batch 20/50 | Loss: 0.7878
# [Val] deit_base | Epoch 9 Batch 30/50 | Loss: 0.6870
# [Val] deit_base | Epoch 9 Batch 40/50 | Loss: 0.7775
# deit_base | Epoch 9/30 | Train Loss: 0.7746 | Train Acc: 0.8174 | Val Loss: 0.7754 | Val Acc: 0.8252
# Best model updated and saved to: /kaggle/working/best_deit_base.pth
#
# ===== deit_base | Epoch 10/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 362.6201171875 MB
#   GPU memory reserved: 686.0 MB
# [Train] deit_base | Epoch 10 Batch 0/230 | Loss: 1.0248
# [Train] deit_base | Epoch 10 Batch 10/230 | Loss: 0.5831
# [Train] deit_base | Epoch 10 Batch 20/230 | Loss: 0.6266
# [Train] deit_base | Epoch 10 Batch 30/230 | Loss: 0.5519
# [Train] deit_base | Epoch 10 Batch 40/230 | Loss: 0.7288
# [Train] deit_base | Epoch 10 Batch 50/230 | Loss: 0.7132
# [Train] deit_base | Epoch 10 Batch 60/230 | Loss: 0.8535
# [Train] deit_base | Epoch 10 Batch 70/230 | Loss: 0.7445
# [Train] deit_base | Epoch 10 Batch 80/230 | Loss: 0.6015
# [Train] deit_base | Epoch 10 Batch 90/230 | Loss: 0.7881
# [Train] deit_base | Epoch 10 Batch 100/230 | Loss: 0.7765
# [Train] deit_base | Epoch 10 Batch 110/230 | Loss: 0.8220
# [Train] deit_base | Epoch 10 Batch 120/230 | Loss: 0.8147
# [Train] deit_base | Epoch 10 Batch 130/230 | Loss: 0.6239
# [Train] deit_base | Epoch 10 Batch 140/230 | Loss: 0.6903
# [Train] deit_base | Epoch 10 Batch 150/230 | Loss: 0.8155
# [Train] deit_base | Epoch 10 Batch 160/230 | Loss: 0.5482
# [Train] deit_base | Epoch 10 Batch 170/230 | Loss: 0.8698
# [Train] deit_base | Epoch 10 Batch 180/230 | Loss: 0.7317
# [Train] deit_base | Epoch 10 Batch 190/230 | Loss: 1.0929
# [Train] deit_base | Epoch 10 Batch 200/230 | Loss: 0.7501
# [Train] deit_base | Epoch 10 Batch 210/230 | Loss: 0.8011
# [Train] deit_base | Epoch 10 Batch 220/230 | Loss: 0.6408
# [Val] deit_base | Epoch 10 Batch 0/50 | Loss: 0.6999
# [Train] deit_base | Epoch 19 Batch 170/230 | Loss: 0.6348
# [Train] deit_base | Epoch 19 Batch 180/230 | Loss: 0.5274
# [Train] deit_base | Epoch 19 Batch 190/230 | Loss: 0.6402
# [Train] deit_base | Epoch 19 Batch 200/230 | Loss: 0.9813
# [Train] deit_base | Epoch 19 Batch 210/230 | Loss: 0.5238
# [Train] deit_base | Epoch 19 Batch 220/230 | Loss: 0.3174
# [Val] deit_base | Epoch 19 Batch 0/50 | Loss: 0.5921
# [Val] deit_base | Epoch 19 Batch 10/50 | Loss: 0.7992
# [Val] deit_base | Epoch 19 Batch 20/50 | Loss: 0.6483
# [Val] deit_base | Epoch 19 Batch 30/50 | Loss: 0.4961
# [Val] deit_base | Epoch 19 Batch 40/50 | Loss: 0.6102
# deit_base | Epoch 19/30 | Train Loss: 0.5904 | Train Acc: 0.8409 | Val Loss: 0.6084 | Val Acc: 0.8373
# Best model updated and saved to: /kaggle/working/best_deit_base.pth
#
# ===== deit_base | Epoch 20/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 362.6201171875 MB
#   GPU memory reserved: 686.0 MB
# [Train] deit_base | Epoch 20 Batch 0/230 | Loss: 0.6529
# [Train] deit_base | Epoch 20 Batch 10/230 | Loss: 0.5698
# [Train] deit_base | Epoch 20 Batch 20/230 | Loss: 0.5440
# [Train] deit_base | Epoch 20 Batch 30/230 | Loss: 0.7329
# [Train] deit_base | Epoch 20 Batch 40/230 | Loss: 0.3932
# [Train] deit_base | Epoch 20 Batch 50/230 | Loss: 0.7568
# [Train] deit_base | Epoch 20 Batch 60/230 | Loss: 0.6860
# [Train] deit_base | Epoch 20 Batch 70/230 | Loss: 0.8375
# [Train] deit_base | Epoch 20 Batch 80/230 | Loss: 0.4711
# [Train] deit_base | Epoch 20 Batch 90/230 | Loss: 0.4841
# [Train] deit_base | Epoch 20 Batch 100/230 | Loss: 0.4969
# [Train] deit_base | Epoch 20 Batch 110/230 | Loss: 0.4103
# [Train] deit_base | Epoch 20 Batch 120/230 | Loss: 0.4582
# [Train] deit_base | Epoch 20 Batch 130/230 | Loss: 0.6514
# [Train] deit_base | Epoch 20 Batch 140/230 | Loss: 0.5413
# [Train] deit_base | Epoch 20 Batch 150/230 | Loss: 0.8111
# [Train] deit_base | Epoch 20 Batch 160/230 | Loss: 0.4382
# [Train] deit_base | Epoch 20 Batch 170/230 | Loss: 0.7304
# [Train] deit_base | Epoch 20 Batch 180/230 | Loss: 0.7823
# [Train] deit_base | Epoch 20 Batch 190/230 | Loss: 0.7353
# [Train] deit_base | Epoch 20 Batch 200/230 | Loss: 0.4081
# [Train] deit_base | Epoch 20 Batch 210/230 | Loss: 0.5969
# [Train] deit_base | Epoch 20 Batch 220/230 | Loss: 0.6816
# [Val] deit_base | Epoch 20 Batch 0/50 | Loss: 0.5855
# [Val] deit_base | Epoch 20 Batch 10/50 | Loss: 0.7873
# [Val] deit_base | Epoch 20 Batch 20/50 | Loss: 0.6404
# [Val] deit_base | Epoch 20 Batch 30/50 | Loss: 0.4862
# [Val] deit_base | Epoch 20 Batch 40/50 | Loss: 0.6012
# deit_base | Epoch 20/30 | Train Loss: 0.5810 | Train Acc: 0.8414 | Val Loss: 0.5990 | Val Acc: 0.8373
# Best model updated and saved to: /kaggle/working/best_deit_base.pth
#
# ===== deit_base | Epoch 21/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 362.6201171875 MB
#   GPU memory reserved: 686.0 MB
# [Train] deit_base | Epoch 21 Batch 0/230 | Loss: 0.3924
# [Train] deit_base | Epoch 21 Batch 10/230 | Loss: 0.3138
# [Train] deit_base | Epoch 21 Batch 20/230 | Loss: 0.6963
# [Train] deit_base | Epoch 21 Batch 30/230 | Loss: 0.3871
# [Train] deit_base | Epoch 21 Batch 40/230 | Loss: 0.5251
# [Train] deit_base | Epoch 21 Batch 50/230 | Loss: 0.3781
# [Train] deit_base | Epoch 21 Batch 60/230 | Loss: 0.7131
# [Train] deit_base | Epoch 21 Batch 70/230 | Loss: 0.5123
# [Train] deit_base | Epoch 21 Batch 80/230 | Loss: 0.4487
# [Train] deit_base | Epoch 21 Batch 90/230 | Loss: 0.5572
# [Train] deit_base | Epoch 21 Batch 100/230 | Loss: 0.6882
# [Train] deit_base | Epoch 21 Batch 110/230 | Loss: 0.5161
# [Train] deit_base | Epoch 21 Batch 120/230 | Loss: 0.4627
# [Train] deit_base | Epoch 21 Batch 130/230 | Loss: 0.5626
# [Train] deit_base | Epoch 21 Batch 140/230 | Loss: 0.6142
# [Train] deit_base | Epoch 21 Batch 150/230 | Loss: 0.4391
# [Train] deit_base | Epoch 21 Batch 160/230 | Loss: 0.4615
# [Train] deit_base | Epoch 21 Batch 170/230 | Loss: 0.5396
# [Train] deit_base | Epoch 21 Batch 180/230 | Loss: 1.0162
# [Train] deit_base | Epoch 21 Batch 190/230 | Loss: 0.3989
# [Train] deit_base | Epoch 21 Batch 200/230 | Loss: 0.4488
# [Train] deit_base | Epoch 21 Batch 210/230 | Loss: 0.7679
# [Train] deit_base | Epoch 21 Batch 220/230 | Loss: 0.8149
# [Val] deit_base | Epoch 21 Batch 0/50 | Loss: 0.5801
# [Val] deit_base | Epoch 21 Batch 10/50 | Loss: 0.7760
# [Val] deit_base | Epoch 21 Batch 20/50 | Loss: 0.6344
# [Val] deit_base | Epoch 21 Batch 30/50 | Loss: 0.4778
# [Val] deit_base | Epoch 21 Batch 40/50 | Loss: 0.5937
# deit_base | Epoch 21/30 | Train Loss: 0.5690 | Train Acc: 0.8423 | Val Loss: 0.5906 | Val Acc: 0.8398
# Best model updated and saved to: /kaggle/working/best_deit_base.pth
#
# ===== deit_base | Epoch 22/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 362.6201171875 MB
#   GPU memory reserved: 686.0 MB
# [Train] deit_base | Epoch 22 Batch 0/230 | Loss: 0.6206
# [Train] deit_base | Epoch 22 Batch 10/230 | Loss: 0.5006
# [Train] deit_base | Epoch 22 Batch 20/230 | Loss: 0.3189
# [Train] deit_base | Epoch 22 Batch 30/230 | Loss: 0.5366
# [Train] deit_base | Epoch 22 Batch 40/230 | Loss: 0.4033
# [Train] deit_base | Epoch 22 Batch 50/230 | Loss: 0.7007
# [Train] deit_base | Epoch 22 Batch 60/230 | Loss: 0.7708
# [Train] deit_base | Epoch 22 Batch 70/230 | Loss: 0.4306
# [Train] deit_base | Epoch 22 Batch 80/230 | Loss: 0.4692
# [Train] deit_base | Epoch 22 Batch 90/230 | Loss: 0.5461
# [Train] deit_base | Epoch 22 Batch 100/230 | Loss: 0.5647
# [Train] deit_base | Epoch 22 Batch 110/230 | Loss: 0.8965
# [Train] deit_base | Epoch 22 Batch 120/230 | Loss: 0.5207
# [Train] deit_base | Epoch 22 Batch 130/230 | Loss: 1.0036
# [Train] deit_base | Epoch 22 Batch 140/230 | Loss: 0.5502
# [Train] deit_base | Epoch 22 Batch 150/230 | Loss: 0.4902
# [Train] deit_base | Epoch 22 Batch 160/230 | Loss: 0.5201
# [Train] deit_base | Epoch 22 Batch 170/230 | Loss: 0.3900
# [Train] deit_base | Epoch 22 Batch 180/230 | Loss: 0.8896
# [Train] deit_base | Epoch 22 Batch 190/230 | Loss: 0.3809
# [Train] deit_base | Epoch 22 Batch 200/230 | Loss: 0.9070
# [Train] deit_base | Epoch 22 Batch 210/230 | Loss: 0.7860
# [Train] deit_base | Epoch 22 Batch 220/230 | Loss: 0.7000
# [Val] deit_base | Epoch 22 Batch 0/50 | Loss: 0.5759
# [Val] deit_base | Epoch 22 Batch 10/50 | Loss: 0.7654
# [Val] deit_base | Epoch 22 Batch 20/50 | Loss: 0.6305
# [Val] deit_base | Epoch 22 Batch 30/50 | Loss: 0.4712
# [Val] deit_base | Epoch 22 Batch 40/50 | Loss: 0.5866
# deit_base | Epoch 22/30 | Train Loss: 0.5614 | Train Acc: 0.8411 | Val Loss: 0.5839 | Val Acc: 0.8411
# Best model updated and saved to: /kaggle/working/best_deit_base.pth
#
# ===== deit_base | Epoch 23/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 362.6201171875 MB
#   GPU memory reserved: 686.0 MB
# [Train] deit_base | Epoch 23 Batch 0/230 | Loss: 0.6244
# [Train] deit_base | Epoch 23 Batch 10/230 | Loss: 0.5240
# [Train] deit_base | Epoch 23 Batch 20/230 | Loss: 0.7239
# [Train] deit_base | Epoch 23 Batch 30/230 | Loss: 0.3254
# [Train] deit_base | Epoch 23 Batch 40/230 | Loss: 0.5301
# [Train] deit_base | Epoch 23 Batch 50/230 | Loss: 0.5064
# [Train] deit_base | Epoch 23 Batch 60/230 | Loss: 0.5855
# [Train] deit_base | Epoch 23 Batch 70/230 | Loss: 0.4271
# [Train] deit_base | Epoch 23 Batch 80/230 | Loss: 0.5459
# [Train] deit_base | Epoch 23 Batch 90/230 | Loss: 0.5302
# [Train] deit_base | Epoch 23 Batch 100/230 | Loss: 0.5191
# [Train] deit_base | Epoch 23 Batch 110/230 | Loss: 0.4184
# [Train] deit_base | Epoch 23 Batch 120/230 | Loss: 0.5121
# [Train] deit_base | Epoch 23 Batch 130/230 | Loss: 0.7211
# [Train] deit_base | Epoch 23 Batch 140/230 | Loss: 0.5386
# [Train] deit_base | Epoch 23 Batch 150/230 | Loss: 0.6939
# [Train] deit_base | Epoch 23 Batch 160/230 | Loss: 0.5878
# [Train] deit_base | Epoch 23 Batch 170/230 | Loss: 0.3062
# [Train] deit_base | Epoch 23 Batch 180/230 | Loss: 0.4694
# [Train] deit_base | Epoch 23 Batch 190/230 | Loss: 0.4802
# [Train] deit_base | Epoch 23 Batch 200/230 | Loss: 0.8130
# [Train] deit_base | Epoch 23 Batch 210/230 | Loss: 0.7409
# [Train] deit_base | Epoch 23 Batch 220/230 | Loss: 0.4714
# [Val] deit_base | Epoch 23 Batch 0/50 | Loss: 0.5698
# [Val] deit_base | Epoch 23 Batch 10/50 | Loss: 0.7555
# [Val] deit_base | Epoch 23 Batch 20/50 | Loss: 0.6249
# [Val] deit_base | Epoch 23 Batch 30/50 | Loss: 0.4637
# [Val] deit_base | Epoch 23 Batch 40/50 | Loss: 0.5799
# deit_base | Epoch 23/30 | Train Loss: 0.5569 | Train Acc: 0.8415 | Val Loss: 0.5765 | Val Acc: 0.8430
# Best model updated and saved to: /kaggle/working/best_deit_base.pth
#
# ===== deit_base | Epoch 24/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated:
# [Train] deit_tiny | Epoch 30 Batch 140/230 | Loss: 0.5426
# [Train] deit_tiny | Epoch 30 Batch 150/230 | Loss: 0.3620
# [Train] deit_tiny | Epoch 30 Batch 160/230 | Loss: 0.5722
# [Train] deit_tiny | Epoch 30 Batch 170/230 | Loss: 0.9290
# [Train] deit_tiny | Epoch 30 Batch 180/230 | Loss: 0.7324
# [Train] deit_tiny | Epoch 30 Batch 190/230 | Loss: 0.4390
# [Train] deit_tiny | Epoch 30 Batch 200/230 | Loss: 0.6241
# [Train] deit_tiny | Epoch 30 Batch 210/230 | Loss: 0.5184
# [Train] deit_tiny | Epoch 30 Batch 220/230 | Loss: 0.5629
# [Val] deit_tiny | Epoch 30 Batch 0/50 | Loss: 0.5305
# [Val] deit_tiny | Epoch 30 Batch 10/50 | Loss: 0.7185
# [Val] deit_tiny | Epoch 30 Batch 20/50 | Loss: 0.6227
# [Val] deit_tiny | Epoch 30 Batch 30/50 | Loss: 0.5835
# [Val] deit_tiny | Epoch 30 Batch 40/50 | Loss: 0.5833
# deit_tiny | Epoch 30/30 | Train Loss: 0.5626 | Train Acc: 0.8373 | Val Loss: 0.5686 | Val Acc: 0.8315
# Best model updated and saved to: /kaggle/working/best_deit_tiny.pth
# Training completed for deit_tiny.
# Best validation accuracy: 0.831532104259377
#
# All model training completed.
# Benchmark summary saved to: /kaggle/working/model_benchmark_summary.csv
#    model_name  best_epoch  best_train_loss  best_train_acc  best_val_loss  \
# 0   deit_base          30         0.509568        0.849571       0.538262
# 1  deit_small          30         0.580854        0.827906       0.590726
# 2   deit_tiny          30         0.562566        0.837308       0.568628
#
#    best_val_acc  total_epochs_trained  early_stopped  \
# 0      0.848697                    30          False
# 1      0.829625                    30          False
# 2      0.831532                    30          False
#
#                        best_model_path  \
# 0   /kaggle/working/best_deit_base.pth
# 1  /kaggle/working/best_deit_small.pth
# 2   /kaggle/working/best_deit_tiny.pth
#
#                                       history_path
# 0   /kaggle/working/deit_base_training_history.csv
# 1  /kaggle/working/deit_small_training_history.csv
# 2   /kaggle/working/deit_tiny_training_history.csv

# %% [markdown]
# ## Convergence behavior

# %%
def plot_convergence(model_name, output_dir, max_epochs=30):
    output_dir = Path(output_dir)

    history_path = output_dir / f"{model_name}_training_history.csv"
    df = pd.read_csv(history_path)

    # limit to first N epochs if needed
    df = df[df["epoch"] <= max_epochs]

    # ===== Loss plot =====
    plt.figure(figsize=(10, 5))
    plt.plot(df["epoch"], df["train_loss"], label="Train Loss")
    plt.plot(df["epoch"], df["val_loss"], label="Validation Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title(f"Convergence (Loss) - {model_name}")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()

    loss_path = output_dir / f"{model_name}_convergence_loss.png"
    plt.savefig(loss_path, dpi=300)
    plt.show()

    # ===== Accuracy plot =====
    plt.figure(figsize=(10, 5))
    plt.plot(df["epoch"], df["train_acc"], label="Train Accuracy")
    plt.plot(df["epoch"], df["val_acc"], label="Validation Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.title(f"Convergence (Accuracy) - {model_name}")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()

    acc_path = output_dir / f"{model_name}_convergence_accuracy.png"
    plt.savefig(acc_path, dpi=300)
    plt.show()

    print(f"Saved plots for {model_name}")


def compare_convergence(model_names, output_dir, max_epochs=30):
    output_dir = Path(output_dir)

    plt.figure(figsize=(12, 6))

    for model_name in model_names:
        df = pd.read_csv(output_dir / f"{model_name}_training_history.csv")
        df = df[df["epoch"] <= max_epochs]

        plt.plot(df["epoch"], df["val_loss"], label=model_name)

    plt.xlabel("Epoch")
    plt.ylabel("Validation Loss")
    plt.title("Validation Loss Convergence Comparison")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()

    plt.savefig(output_dir / "compare_val_loss.png", dpi=300)
    plt.show()


    plt.figure(figsize=(12, 6))

    for model_name in model_names:
        df = pd.read_csv(output_dir / f"{model_name}_training_history.csv")
        df = df[df["epoch"] <= max_epochs]

        plt.plot(df["epoch"], df["val_acc"], label=model_name)

    plt.xlabel("Epoch")
    plt.ylabel("Validation Accuracy")
    plt.title("Validation Accuracy Convergence Comparison")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()

    plt.savefig(output_dir / "compare_val_accuracy.png", dpi=300)
    plt.show()

# %%
output_dir = Path("/kaggle/working/")

# Plot each model separately
for model_name in MODEL_NAMES:
    plot_convergence(
        model_name=model_name,
        output_dir=output_dir,
        max_epochs=30
    )

# Plot comparison across selected models
compare_convergence(
    model_names=MODEL_NAMES,
    output_dir=output_dir,
    max_epochs=30
)
# Out:
# Saved plots for deit_base
# Saved plots for deit_small
# Saved plots for deit_tiny

# %% [markdown]
# # Evaluation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from pathlib import Path
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    f1_score,
    recall_score,
    precision_score,
    classification_report,
    confusion_matrix,
    roc_auc_score,
    roc_curve,
    auc
)
from sklearn.preprocessing import label_binarize


# =========================
# Test evaluation function
# =========================

def evaluate_on_test_set(
    model,
    test_loader,
    device,
    class_names,
    output_dir,
    model_name="model"
):
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

    model.eval()

    all_probs = []
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            outputs = model(images)
            probs = torch.softmax(outputs, dim=1)
            preds = torch.argmax(probs, dim=1)

            all_probs.append(probs.cpu().numpy())
            all_preds.append(preds.cpu().numpy())
            all_labels.append(labels.cpu().numpy())

    all_probs = np.concatenate(all_probs, axis=0)
    all_preds = np.concatenate(all_preds, axis=0)
    all_labels = np.concatenate(all_labels, axis=0)

    num_classes = len(class_names)

    # =========================
    # Overall metrics
    # =========================

    accuracy = accuracy_score(all_labels, all_preds)
    balanced_acc = balanced_accuracy_score(all_labels, all_preds)

    f1_macro = f1_score(all_labels, all_preds, average="macro")
    f1_weighted = f1_score(all_labels, all_preds, average="weighted")

    recall_macro = recall_score(all_labels, all_preds, average="macro")
    recall_weighted = recall_score(all_labels, all_preds, average="weighted")

    precision_macro = precision_score(all_labels, all_preds, average="macro", zero_division=0)
    precision_weighted = precision_score(all_labels, all_preds, average="weighted", zero_division=0)

    # ROC-AUC
    try:
        if num_classes == 2:
            roc_auc = roc_auc_score(all_labels, all_probs[:, 1])
        else:
            roc_auc = roc_auc_score(
                all_labels,
                all_probs,
                multi_class="ovr",
                average="macro"
            )
    except Exception as e:
        print("ROC-AUC could not be calculated:", e)
        roc_auc = np.nan

    metrics_df = pd.DataFrame([{
        "model_name": model_name,
        "accuracy": accuracy,
        "balanced_accuracy": balanced_acc,
        "f1_macro": f1_macro,
        "f1_weighted": f1_weighted,
        "recall_macro": recall_macro,
        "recall_weighted": recall_weighted,
        "precision_macro": precision_macro,
        "precision_weighted": precision_weighted,
        "roc_auc_ovr_macro": roc_auc
    }])

    metrics_path = output_dir / f"{model_name}_test_metrics.csv"
    metrics_df.to_csv(metrics_path, index=False)

    print(f"Saved test metrics to: {metrics_path}")
    print(metrics_df)

    # =========================
    # Per-class classification report
    # =========================

    report_dict = classification_report(
        all_labels,
        all_preds,
        target_names=class_names,
        output_dict=True,
        zero_division=0
    )

    report_df = pd.DataFrame(report_dict).transpose()
    report_path = output_dir / f"{model_name}_classification_report.csv"
    report_df.to_csv(report_path)

    print(f"Saved classification report to: {report_path}")

    # =========================
    # Prediction probabilities CSV
    # =========================

    prob_df = pd.DataFrame(all_probs, columns=[f"prob_{c}" for c in class_names])
    pred_df = pd.DataFrame({
        "true_label_id": all_labels,
        "pred_label_id": all_preds,
        "true_class": [class_names[i] for i in all_labels],
        "pred_class": [class_names[i] for i in all_preds],
        "confidence": np.max(all_probs, axis=1)
    })

    prediction_df = pd.concat([pred_df, prob_df], axis=1)
    prediction_path = output_dir / f"{model_name}_test_predictions.csv"
    prediction_df.to_csv(prediction_path, index=False)

    print(f"Saved test predictions to: {prediction_path}")

    # =========================
    # Confusion matrix
    # =========================

    cm = confusion_matrix(all_labels, all_preds)

    cm_df = pd.DataFrame(
        cm,
        index=class_names,
        columns=class_names
    )

    cm_path = output_dir / f"{model_name}_confusion_matrix.csv"
    cm_df.to_csv(cm_path)

    plt.figure(figsize=(12, 10))
    sns.heatmap(
        cm_df,
        annot=True,
        fmt="d",
        cmap="Blues",
        xticklabels=class_names,
        yticklabels=class_names
    )
    plt.xlabel("Predicted Class")
    plt.ylabel("True Class")
    plt.title(f"Confusion Matrix - {model_name}")
    plt.xticks(rotation=45, ha="right")
    plt.yticks(rotation=0)
    plt.tight_layout()

    cm_plot_path = output_dir / f"{model_name}_confusion_matrix.png"
    plt.savefig(cm_plot_path, dpi=300)
    plt.show()

    print(f"Saved confusion matrix plot to: {cm_plot_path}")

    # =========================
    # Normalized confusion matrix
    # =========================

    cm_norm = cm.astype("float") / cm.sum(axis=1, keepdims=True)
    cm_norm = np.nan_to_num(cm_norm)

    cm_norm_df = pd.DataFrame(
        cm_norm,
        index=class_names,
        columns=class_names
    )

    plt.figure(figsize=(12, 10))
    sns.heatmap(
        cm_norm_df,
        annot=True,
        fmt=".2f",
        cmap="Blues",
        xticklabels=class_names,
        yticklabels=class_names
    )
    plt.xlabel("Predicted Class")
    plt.ylabel("True Class")
    plt.title(f"Normalized Confusion Matrix - {model_name}")
    plt.xticks(rotation=45, ha="right")
    plt.yticks(rotation=0)
    plt.tight_layout()

    cm_norm_plot_path = output_dir / f"{model_name}_normalized_confusion_matrix.png"
    plt.savefig(cm_norm_plot_path, dpi=300)
    plt.show()

    print(f"Saved normalized confusion matrix plot to: {cm_norm_plot_path}")

    # =========================
    # Per-class score visualization
    # =========================

    per_class_df = report_df.loc[class_names, ["precision", "recall", "f1-score", "support"]]
    per_class_score_path = output_dir / f"{model_name}_per_class_scores.csv"
    per_class_df.to_csv(per_class_score_path)

    per_class_df[["precision", "recall", "f1-score"]].plot(
        kind="bar",
        figsize=(14, 7)
    )
    plt.title(f"Per-Class Precision, Recall, F1 Score - {model_name}")
    plt.xlabel("Class")
    plt.ylabel("Score")
    plt.ylim(0, 1)
    plt.xticks(rotation=45, ha="right")
    plt.tight_layout()

    score_plot_path = output_dir / f"{model_name}_per_class_scores.png"
    plt.savefig(score_plot_path, dpi=300)
    plt.show()

    print(f"Saved per-class score plot to: {score_plot_path}")

    # =========================
    # ROC curve
    # =========================

    plt.figure(figsize=(10, 8))

    if num_classes == 2:
        fpr, tpr, _ = roc_curve(all_labels, all_probs[:, 1])
        roc_auc_binary = auc(fpr, tpr)

        plt.plot(fpr, tpr, label=f"{class_names[1]} AUC = {roc_auc_binary:.4f}")

    else:
        y_true_bin = label_binarize(all_labels, classes=list(range(num_classes)))

        for i, class_name in enumerate(class_names):
            fpr, tpr, _ = roc_curve(y_true_bin[:, i], all_probs[:, i])
            class_auc = auc(fpr, tpr)
            plt.plot(fpr, tpr, label=f"{class_name} AUC = {class_auc:.4f}")

    plt.plot([0, 1], [0, 1], linestyle="--")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title(f"ROC-AUC Curve - {model_name}")
    plt.legend(loc="lower right")
    plt.tight_layout()

    roc_plot_path = output_dir / f"{model_name}_roc_auc_curve.png"
    plt.savefig(roc_plot_path, dpi=300)
    plt.show()

    print(f"Saved ROC-AUC curve to: {roc_plot_path}")

    return {
        "metrics_df": metrics_df,
        "classification_report_df": report_df,
        "predictions_df": prediction_df,
        "confusion_matrix_df": cm_df,
        "per_class_df": per_class_df
    }

# %%
output_dir = Path("/kaggle/working/")
eval_output_dir = output_dir / "evaluation_on_test_set"
eval_output_dir.mkdir(parents=True, exist_ok=True)


all_test_metrics = []

for model_name in MODEL_NAMES:
    print(f"\nEvaluating {model_name}")

    # Rebuild model architecture
    model = build_model(
        model_name=model_name,
        num_classes=num_classes,
        freeze_backbone=True
    ).to(device)

    # Load best checkpoint
    checkpoint_path = output_dir / f"best_{model_name}.pth"
    checkpoint = torch.load(checkpoint_path, map_location=device)

    model.load_state_dict(checkpoint["model_state_dict"])

    # Evaluate
    results = evaluate_on_test_set(
        model=model,
        test_loader=test_loader,
        device=device,
        class_names=class_names,
        output_dir=eval_output_dir,
        model_name=model_name
    )

    # Collect overall metrics
    metrics_df = results["metrics_df"]
    all_test_metrics.append(metrics_df)

# Combine all model test results
all_test_metrics_df = pd.concat(all_test_metrics, ignore_index=True)

summary_path = eval_output_dir / "all_models_test_evaluation_summary.csv"
all_test_metrics_df.to_csv(summary_path, index=False)

print("\nAll model evaluation completed.")
print(f"Saved summary to: {summary_path}")

all_test_metrics_df
# Out:
# Evaluating deit_base
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Saved test metrics to: /kaggle/working/evaluation_on_test_set/deit_base_test_metrics.csv
#   model_name  accuracy  balanced_accuracy  f1_macro  f1_weighted  \
# 0  deit_base  0.851875           0.330813  0.322469     0.808291
#
#    recall_macro  recall_weighted  precision_macro  precision_weighted  \
# 0      0.330813         0.851875         0.375071            0.791682
#
#    roc_auc_ovr_macro
# 0           0.823789
# Saved classification report to: /kaggle/working/evaluation_on_test_set/deit_base_classification_report.csv
# Saved test predictions to: /kaggle/working/evaluation_on_test_set/deit_base_test_predictions.csv
# Saved confusion matrix plot to: /kaggle/working/evaluation_on_test_set/deit_base_confusion_matrix.png
# Saved normalized confusion matrix plot to: /kaggle/working/evaluation_on_test_set/deit_base_normalized_confusion_matrix.png
# Saved per-class score plot to: /kaggle/working/evaluation_on_test_set/deit_base_per_class_scores.png
# Saved ROC-AUC curve to: /kaggle/working/evaluation_on_test_set/deit_base_roc_auc_curve.png
#
# Evaluating deit_small
# Saved test metrics to: /kaggle/working/evaluation_on_test_set/deit_small_test_metrics.csv
#    model_name  accuracy  balanced_accuracy  f1_macro  f1_weighted  \
# 0  deit_small  0.834711           0.313733  0.295214     0.785428
#
#    recall_macro  recall_weighted  precision_macro  precision_weighted  \
# 0      0.313733         0.834711         0.278773             0.74168
#
#    roc_auc_ovr_macro
# 0           0.833559
# Saved classification report to: /kaggle/working/evaluation_on_test_set/deit_small_classification_report.csv
# Saved test predictions to: /kaggle/working/evaluation_on_test_set/deit_small_test_predictions.csv
# Saved confusion matrix plot to: /kaggle/working/evaluation_on_test_set/deit_small_confusion_matrix.png
# Saved normalized confusion matrix plot to: /kaggle/working/evaluation_on_test_set/deit_small_normalized_confusion_matrix.png
# Saved per-class score plot to: /kaggle/working/evaluation_on_test_set/deit_small_per_class_scores.png
# Saved ROC-AUC curve to: /kaggle/working/evaluation_on_test_set/deit_small_roc_auc_curve.png
#
# Evaluating deit_tiny
# Saved test metrics to: /kaggle/working/evaluation_on_test_set/deit_tiny_test_metrics.csv
#   model_name  accuracy  balanced_accuracy  f1_macro  f1_weighted  \
# 0  deit_tiny  0.834711           0.315244  0.298251     0.785531
#
#    recall_macro  recall_weighted  precision_macro  precision_weighted  \
# 0      0.315244         0.834711         0.444898            0.800627
#
#    roc_auc_ovr_macro
# 0           0.825341
# Saved classification report to: /kaggle/working/evaluation_on_test_set/deit_tiny_classification_report.csv
# Saved test predictions to: /kaggle/working/evaluation_on_test_set/deit_tiny_test_predictions.csv
# Saved confusion matrix plot to: /kaggle/working/evaluation_on_test_set/deit_tiny_confusion_matrix.png
# Saved normalized confusion matrix plot to: /kaggle/working/evaluation_on_test_set/deit_tiny_normalized_confusion_matrix.png
# Saved per-class score plot to: /kaggle/working/evaluation_on_test_set/deit_tiny_per_class_scores.png
# Saved ROC-AUC curve to: /kaggle/working/evaluation_on_test_set/deit_tiny_roc_auc_curve.png
#
# All model evaluation completed.
# Saved summary to: /kaggle/working/evaluation_on_test_set/all_models_test_evaluation_summary.csv
#    model_name  accuracy  balanced_accuracy  f1_macro  f1_weighted  \
# 0   deit_base  0.851875           0.330813  0.322469     0.808291
# 1  deit_small  0.834711           0.313733  0.295214     0.785428
# 2   deit_tiny  0.834711           0.315244  0.298251     0.785531
#
#    recall_macro  recall_weighted  precision_macro  precision_weighted  \
# 0      0.330813         0.851875         0.375071            0.791682
# 1      0.313733         0.834711         0.278773            0.741680
# 2      0.315244         0.834711         0.444898            0.800627
#
#    roc_auc_ovr_macro
# 0           0.823789
# 1           0.833559
# 2           0.825341
