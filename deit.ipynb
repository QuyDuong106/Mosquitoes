# %% [markdown]
# # Lib

# %%
# !pip uninstall -y torch torchvision torchaudio

# !pip install --pre torch torchvision torchaudio \
  --index-url https://download.pytorch.org/whl/nightly/cu128
# Out:
# Found existing installation: torch 2.10.0+cu128
# Uninstalling torch-2.10.0+cu128:
#   Successfully uninstalled torch-2.10.0+cu128
# Found existing installation: torchvision 0.25.0+cu128
# Uninstalling torchvision-0.25.0+cu128:
#   Successfully uninstalled torchvision-0.25.0+cu128
# Found existing installation: torchaudio 2.10.0+cu128
# Uninstalling torchaudio-2.10.0+cu128:
#   Successfully uninstalled torchaudio-2.10.0+cu128
# Looking in indexes: https://download.pytorch.org/whl/nightly/cu128
# Collecting torch
#   Downloading https://download-r2.pytorch.org/whl/nightly/cu128/torch-2.12.0.dev20260408%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (31 kB)
# Collecting torchvision
#   Downloading https://download-r2.pytorch.org/whl/nightly/cu128/torchvision-0.27.0.dev20260407%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting torchaudio
#   Downloading https://download-r2.pytorch.org/whl/nightly/cu128/torchaudio-2.11.0.dev20260407%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.9 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2026.2.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch) (12.9.4)
# Collecting nvidia-cudnn-cu12==9.20.0.48 (from torch)
#   Downloading https://pypi.nvidia.com/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.20.0.48-py3-none-manylinux_2_27_x86_64.whl (657.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 657.9/657.9 MB 61.3 MB/s eta 0:00:00
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Collecting nvidia-nccl-cu12==2.29.7 (from torch)
#   Downloading https://pypi.nvidia.com/nvidia-nccl-cu12/nvidia_nccl_cu12-2.29.7-py3-none-manylinux_2_18_x86_64.whl (293.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.6/293.6 MB 95.7 MB/s eta 0:00:00
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.5)
# Collecting triton==3.7.0+git282c8251 (from torch)
#   Downloading https://download-r2.pytorch.org/whl/nightly/triton-3.7.0%2Bgit282c8251-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.90)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Collecting torch
#   Downloading https://download-r2.pytorch.org/whl/nightly/cu128/torch-2.12.0.dev20260407%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (31 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Collecting triton==3.7.0+git9c288bc5 (from torch)
#   Downloading https://download-r2.pytorch.org/whl/nightly/triton-3.7.0%2Bgit9c288bc5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch) (1.3.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Downloading https://download-r2.pytorch.org/whl/nightly/cu128/torchvision-0.27.0.dev20260407%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 64.8 MB/s eta 0:00:00
# Downloading https://download-r2.pytorch.org/whl/nightly/cu128/torch-2.12.0.dev20260407%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl (832.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 832.5/832.5 MB 1.3 MB/s eta 0:00:00
# Downloading https://download-r2.pytorch.org/whl/nightly/triton-3.7.0%2Bgit9c288bc5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (292.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.2/292.2 MB 1.9 MB/s eta 0:00:00
# Downloading https://download-r2.pytorch.org/whl/nightly/cu128/torchaudio-2.11.0.dev20260407%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 52.9 MB/s eta 0:00:00
# Installing collected packages: torchaudio, triton, nvidia-nccl-cu12, nvidia-cudnn-cu12, torch, torchvision
#   Attempting uninstall: triton
#     Found existing installation: triton 3.6.0
#     Uninstalling triton-3.6.0:
#       Successfully uninstalled triton-3.6.0
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.27.5
#     Uninstalling nvidia-nccl-cu12-2.27.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.27.5
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.10.2.21
#     Uninstalling nvidia-cudnn-cu12-9.10.2.21:
#       Successfully uninstalled nvidia-cudnn-cu12-9.10.2.21
# Successfully installed nvidia-cudnn-cu12-9.20.0.48 nvidia-nccl-cu12-2.29.7 torch-2.12.0.dev20260407+cu128 torchaudio-2.11.0.dev20260407+cu128 torchvision-0.27.0.dev20260407+cu128 triton-3.7.0+git9c288bc5

# %%
import os
from pathlib import Path
from PIL import Image
import numpy as np


import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import torch
import torch.nn as nn
import torch.distributed as dist

from torch.nn.parallel import DistributedDataParallel as DDP
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.distributed import DistributedSampler
from torchvision import transforms, models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import resample


from sklearn.metrics import (
    accuracy_score,
    precision_recall_fscore_support,
    classification_report,
    confusion_matrix,
    roc_auc_score,
    roc_curve,
    auc
)
from sklearn.preprocessing import label_binarize

# %%
import torchvision
print(torchvision.__version__)
# Out:
# 0.27.0.dev20260407+cu128

# %%
import torch

print("torch:", torch.__version__)
print("torch cuda:", torch.version.cuda)
print("cuda available:", torch.cuda.is_available())
print("gpu:", torch.cuda.get_device_name(0))
print("capability:", torch.cuda.get_device_capability(0))
# Out:
# torch: 2.12.0.dev20260407+cu128
# torch cuda: 12.8
# cuda available: True
# gpu: Tesla T4
# capability: (7, 5)

# %% [markdown]
# # Data

# %%
dataset_dir = Path("/kaggle/input/datasets/duongnguyenquy/mosquitoes-compsci760")

# # Image
# image_dir = dataset_dir / "images" / "images"
# # image_dir = dataset_dir / "image_crop" / "image_crop"

# # Annotation
# annotation_path = r"/kaggle/input/datasets/duongnguyenquy/mosquitoes-compsci760/labels/annotations.csv"
# # annotation_path = dataset_dir /"image_crop"/"image_crop"/ "cropped_annotations.csv"
image_dir = dataset_dir /"image_crop_new/image_crop_new" #original (not cropped images)
# annotation_path = dataset_dir / "image_crop_new/cropped_annotations.csv" #original dataset's csv
annotation_path = f"/kaggle/input/datasets/duongnguyenquy/mosquitoes-compsci760/image_crop_new/image_crop_new/cropped_annotations.csv"


annotations = pd.read_csv(annotation_path)
annotations.head()
# Out:
#                img_fName  img_w  img_h  bbx_xtl  bbx_ytl  bbx_xbr  bbx_ybr  \
# 0  train_00000_crop.jpeg    340    550        0        0      340      550
# 1  train_00001_crop.jpeg   1050   1093        0        0     1050     1093
# 2  train_00002_crop.jpeg    439    750        0        0      439      750
# 3  train_00003_crop.jpeg    417    462        0        0      417      462
# 4  train_00004_crop.jpeg    568    776        0        0      568      776
#
#   class_label      source_image
# 0  albopictus  train_00000.jpeg
# 1  albopictus  train_00001.jpeg
# 2  albopictus  train_00002.jpeg
# 3  albopictus  train_00003.jpeg
# 4       culex  train_00004.jpeg

# %%
annotations.columns
# Out:
# Index(['img_fName', 'img_w', 'img_h', 'bbx_xtl', 'bbx_ytl', 'bbx_xbr',
#        'bbx_ybr', 'class_label', 'source_image'],
#       dtype='object')

# %%
annotations.shape
# Out:
# (10485, 9)

# %%
print("Image dir exists:", image_dir.exists())
print("CSV rows:", len(annotations))
print("CSV columns:", annotations.columns.tolist())

# Get image names from CSV
csv_images = set(annotations["img_fName"].astype(str))

# Get actual image files in folder
image_exts = {".jpg", ".jpeg", ".png"}
folder_images = {
    p.name
    for p in image_dir.iterdir()
    if p.is_file() and p.suffix.lower() in image_exts
}

missing_files = sorted(csv_images - folder_images)
extra_files = sorted(folder_images - csv_images)

print("Unique images in CSV:", len(csv_images))
print("Image files in folder:", len(folder_images))
print("Missing image files:", len(missing_files))
print("Extra image files:", len(extra_files))

if missing_files:
    print("\nFirst missing files:")
    print(missing_files[:20])

if extra_files:
    print("\nFirst extra files:")
    print(extra_files[:20])

if not missing_files:
    print("\nAll CSV image names have matching image files.")
# Out:
# Image dir exists: True
# CSV rows: 10485
# CSV columns: ['img_fName', 'img_w', 'img_h', 'bbx_xtl', 'bbx_ytl', 'bbx_xbr', 'bbx_ybr', 'class_label', 'source_image']
# Unique images in CSV: 10485
# Image files in folder: 10485
# Missing image files: 0
# Extra image files: 0
#
# All CSV image names have matching image files.

# %%
image_df = (
    annotations.groupby("img_fName")["class_label"]
    .agg(lambda x: x.mode().iloc[0])
    .reset_index()
)

print("Number of images:", len(image_df))
print(image_df["class_label"].value_counts())
image_df.head()
# Out:
# Number of images: 10485
# class_label
# albopictus            4655
# culex                 4638
# culiseta               632
# japonicus-koreicus     429
# anopheles               84
# aegypti                 47
# Name: count, dtype: int64
#                img_fName class_label
# 0  train_00000_crop.jpeg  albopictus
# 1  train_00001_crop.jpeg  albopictus
# 2  train_00002_crop.jpeg  albopictus
# 3  train_00003_crop.jpeg  albopictus
# 4  train_00004_crop.jpeg       culex

# %%
# number of images to show
num_images = 6

sample_df = annotations.sample(num_images, random_state=760)

plt.figure(figsize=(12, 8))

for i, (_, row) in enumerate(sample_df.iterrows()):
    img_path = image_dir / row["img_fName"]   # adjust column name if needed
    
    img = Image.open(img_path)

    plt.subplot(2, 3, i + 1)
    plt.imshow(img)
    plt.title(f"Label: {row['class_label']}")
    plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Preprocessing

# %%
label_encoder = LabelEncoder()
image_df["label_id"] = label_encoder.fit_transform(image_df["class_label"])

class_names = list(label_encoder.classes_)
num_classes = len(class_names)

print(class_names)
print("Num classes:", num_classes)
# Out:
# ['aegypti', 'albopictus', 'anopheles', 'culex', 'culiseta', 'japonicus-koreicus']
# Num classes: 6

# %% [markdown]
# # Split

# %%
train_df, temp_df = train_test_split(
    image_df,
    test_size=0.30,
    random_state=42,
    stratify=image_df["label_id"]
)

val_df, test_df = train_test_split(
    temp_df,
    test_size=0.50,
    random_state=42,
    stratify=temp_df["label_id"]
)


#Oversampling method
# train_df = oversample_dataframe(train_df, label_col="label_id")

print("Train:", len(train_df))
print("Val:", len(val_df))
print("Test:", len(test_df))

print("\nTrain label distribution after oversampling:")
print(train_df["label_id"].value_counts())
# Out:
# Train: 7339
# Val: 1573
# Test: 1573
#
# Train label distribution after oversampling:
# label_id
# 1    3258
# 3    3247
# 4     442
# 5     300
# 2      59
# 0      33
# Name: count, dtype: int64

# %%
# train_subset_df = train_df.groupby("label_id", group_keys=False).apply(
#     lambda x: x.sample(min(len(x), 50), random_state=42)
# ).reset_index(drop=True)

# val_subset_df = val_df.groupby("label_id", group_keys=False).apply(
#     lambda x: x.sample(min(len(x), 20), random_state=42)
# ).reset_index(drop=True)

# test_subset_df = test_df.groupby("label_id", group_keys=False).apply(
#     lambda x: x.sample(min(len(x), 20), random_state=42)
# ).reset_index(drop=True)

# print("Subset Train:", len(train_subset_df))
# print("Subset Val:", len(val_subset_df))
# print("Subset Test:", len(test_subset_df))

# %% [markdown]
# # Modeling

# %% [markdown]
# ## ENV

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using:", device)

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
    print("Capability:", torch.cuda.get_device_capability(0))
# Out:
# Using: cuda
# GPU: Tesla T4
# Capability: (7, 5)

# %% [markdown]
# ## Transform

# %%
image_size = 224

# train_transform = transforms.Compose([
#     transforms.Resize((image_size, image_size)),
#     transforms.RandomResizedCrop(image_size, scale=(0.8, 1.0), ratio=(0.75, 1.33)),
#     transforms.RandomHorizontalFlip(p=0.5),
#     transforms.RandomVerticalFlip(p=0.2),
#     transforms.RandomRotation(degrees=15),
#     transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1),
#     transforms.RandomGrayscale(p=0.1),
#     transforms.GaussianBlur(kernel_size=(3, 5), sigma=(0.1, 2.0)),
#     transforms.ToTensor(),
#     transforms.Normalize(mean=[0.485, 0.456, 0.406],
#                          std=[0.229, 0.224, 0.225])
# ])

# eval_transform = transforms.Compose([
#     transforms.Resize((image_size, image_size)),
#     transforms.CenterCrop(image_size),
#     transforms.ToTensor(),
#     transforms.Normalize(mean=[0.485, 0.456, 0.406],
#                          std=[0.229, 0.224, 0.225])
# ])


train_transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

eval_transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %% [markdown]
# ## Dataset

# %%
class MosquitoImageDataset(Dataset):
    def __init__(self, df, image_dir, transform=None):
        self.df = df.reset_index(drop=True)
        self.image_dir = image_dir
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        image_path = self.image_dir / row["img_fName"]
        image = Image.open(image_path).convert("RGB")
        label = int(row["label_id"])

        if self.transform:
            image = self.transform(image)

        return image, label

# %%
train_dataset = MosquitoImageDataset(train_df, image_dir, transform=train_transform)
val_dataset = MosquitoImageDataset(val_df, image_dir, transform=eval_transform)
test_dataset = MosquitoImageDataset(test_df, image_dir, transform=eval_transform)

# Subset
# train_dataset = MosquitoImageDataset(train_subset_df, image_dir, transform=train_transform)
# val_dataset = MosquitoImageDataset(val_subset_df, image_dir, transform=eval_transform)
# test_dataset = MosquitoImageDataset(test_subset_df, image_dir, transform=eval_transform)


train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=2)

# %% [markdown]
# # Baseline modeling
# - Model builder and call out

# %%
import torch
import torch.nn as nn
from torchvision import models
from torchvision.models import (
    ResNet50_Weights,
    ResNet101_Weights,
    EfficientNet_V2_L_Weights,
    EfficientNet_B0_Weights,
    MobileNet_V2_Weights,
)
import timm


def build_model(model_name, num_classes, freeze_backbone=True):
    model_name = model_name.lower()

    if model_name == "resnet50":
        model = models.resnet50(weights=ResNet50_Weights.DEFAULT)
        model.fc = nn.Linear(model.fc.in_features, num_classes)
        backbone_params = [p for name, p in model.named_parameters() if not name.startswith("fc.")]

    elif model_name == "resnet101":
        model = models.resnet101(weights=ResNet101_Weights.DEFAULT)
        model.fc = nn.Linear(model.fc.in_features, num_classes)
        backbone_params = [p for name, p in model.named_parameters() if not name.startswith("fc.")]

    elif model_name == "efficientnet_v2_l":
        model = models.efficientnet_v2_l(weights=EfficientNet_V2_L_Weights.DEFAULT)
        model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)
        backbone_params = model.features.parameters()

    elif model_name == "efficientnet_b0":
        model = models.efficientnet_b0(weights=EfficientNet_B0_Weights.DEFAULT)
        model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)
        backbone_params = model.features.parameters()

    elif model_name == "mobilenet_v2":
        model = models.mobilenet_v2(weights=MobileNet_V2_Weights.DEFAULT)
        model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)
        backbone_params = model.features.parameters()

    elif model_name == "deit_tiny":
        model = timm.create_model(
            "deit_tiny_patch16_224",
            pretrained=True,
            num_classes=num_classes
        )
        backbone_params = [
            p for name, p in model.named_parameters()
            if not name.startswith("head.")
        ]

    elif model_name == "deit_small":
        model = timm.create_model(
            "deit_small_patch16_224",
            pretrained=True,
            num_classes=num_classes
        )
        backbone_params = [
            p for name, p in model.named_parameters()
            if not name.startswith("head.")
        ]

    elif model_name == "deit_base":
        model = timm.create_model(
            "deit_base_patch16_224",
            pretrained=True,
            num_classes=num_classes
        )
        backbone_params = [
            p for name, p in model.named_parameters()
            if not name.startswith("head.")
        ]

    else:
        raise ValueError(f"Unknown model name: {model_name}")

    if freeze_backbone:
        for param in backbone_params:
            param.requires_grad = False

    return model

# %% [markdown]
# # Training process

# %% [markdown]
# ## Training 1 model builder

# %% [markdown]
# - Number of epochs: 30
# - Lr = 1e-5
# - Transfer learning
# - criterion: CrossEntropy loss
# - optimizer: Adam

# %%
def train_one_model(
    model_name,
    train_loader,
    val_loader,
    num_classes,
    class_names,
    device,
    output_dir,
    num_epochs=30,
    patience=5,
    lr=1e-5,
    freeze_backbone=True
):
    print(f"\n\n==============================")
    print(f"Start training: {model_name}")
    print(f"==============================")

    model = build_model(
        model_name=model_name,
        num_classes=num_classes,
        freeze_backbone=freeze_backbone
    ).to(device)

    criterion = nn.CrossEntropyLoss()

    optimizer = torch.optim.Adam(
        filter(lambda p: p.requires_grad, model.parameters()),
        lr=lr
    )

    best_val_loss = float("inf")
    early_stop_counter = 0
    history = []

    print("Selected device:", device)
    print("Model device:", next(model.parameters()).device)

    for epoch in range(num_epochs):
        print(f"\n===== {model_name} | Epoch {epoch + 1}/{num_epochs} =====")

        # =========================
        # Training
        # =========================
        model.train()

        train_loss = 0.0
        train_correct = 0
        train_total = 0

        for batch_idx, (images, labels) in enumerate(train_loader):
            if batch_idx == 0:
                print("Before move:")
                print("  images device:", images.device)
                print("  labels device:", labels.device)

            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            if batch_idx == 0:
                print("After move:")
                print("  images device:", images.device)
                print("  labels device:", labels.device)
                print("  model device:", next(model.parameters()).device)

                if torch.cuda.is_available():
                    print(
                        "  GPU memory allocated:",
                        torch.cuda.memory_allocated() / 1024**2,
                        "MB"
                    )
                    print(
                        "  GPU memory reserved:",
                        torch.cuda.memory_reserved() / 1024**2,
                        "MB"
                    )

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * images.size(0)

            preds = outputs.argmax(dim=1)
            train_correct += (preds == labels).sum().item()
            train_total += labels.size(0)

            if batch_idx % 10 == 0:
                print(
                    f"[Train] {model_name} | "
                    f"Epoch {epoch + 1} Batch {batch_idx}/{len(train_loader)} | "
                    f"Loss: {loss.item():.4f}"
                )

        train_loss /= train_total
        train_acc = train_correct / train_total

        # =========================
        # Validation
        # =========================
        model.eval()

        val_loss = 0.0
        val_correct = 0
        val_total = 0

        with torch.no_grad():
            for batch_idx, (images, labels) in enumerate(val_loader):
                images = images.to(device, non_blocking=True)
                labels = labels.to(device, non_blocking=True)

                outputs = model(images)
                loss = criterion(outputs, labels)

                val_loss += loss.item() * images.size(0)

                preds = outputs.argmax(dim=1)
                val_correct += (preds == labels).sum().item()
                val_total += labels.size(0)

                if batch_idx % 10 == 0:
                    print(
                        f"[Val] {model_name} | "
                        f"Epoch {epoch + 1} Batch {batch_idx}/{len(val_loader)} | "
                        f"Loss: {loss.item():.4f}"
                    )

        val_loss /= val_total
        val_acc = val_correct / val_total

        print(
            f"{model_name} | Epoch {epoch + 1}/{num_epochs} | "
            f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f} | "
            f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}"
        )

        # =========================
        # Save history
        # =========================
        epoch_result = {
            "model_name": model_name,
            "epoch": epoch + 1,
            "train_loss": train_loss,
            "train_acc": train_acc,
            "val_loss": val_loss,
            "val_acc": val_acc,
            "best_val_loss_so_far": min(best_val_loss, val_loss),
            "early_stop_counter": early_stop_counter,
        }

        history.append(epoch_result)

        history_path = output_dir / f"{model_name}_training_history.csv"
        pd.DataFrame(history).to_csv(history_path, index=False)

        # =========================
        # Save best model
        # =========================
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            early_stop_counter = 0

            best_model_path = output_dir / f"best_{model_name}.pth"

            torch.save({
                "model_name": model_name,
                "epoch": epoch + 1,
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
                "train_loss": train_loss,
                "val_loss": val_loss,
                "train_acc": train_acc,
                "val_acc": val_acc,
                "class_names": class_names,
            }, best_model_path)

            print(f"Best model updated and saved to: {best_model_path}")

        else:
            early_stop_counter += 1
            print(
                f"No improvement. Early stop counter: "
                f"{early_stop_counter}/{patience}"
            )

        # update latest history with new early stop counter
        history[-1]["early_stop_counter"] = early_stop_counter
        pd.DataFrame(history).to_csv(history_path, index=False)

        if early_stop_counter >= patience:
            print(f"Early stopping triggered for {model_name}.")
            break

    # =========================
    # Final benchmark result
    # =========================
    history_df = pd.DataFrame(history)

    best_row = history_df.loc[history_df["val_loss"].idxmin()]

    benchmark_result = {
        "model_name": model_name,
        "best_epoch": int(best_row["epoch"]),
        "best_train_loss": float(best_row["train_loss"]),
        "best_train_acc": float(best_row["train_acc"]),
        "best_val_loss": float(best_row["val_loss"]),
        "best_val_acc": float(best_row["val_acc"]),
        "total_epochs_trained": len(history_df),
        "early_stopped": early_stop_counter >= patience,
        "best_model_path": str(output_dir / f"best_{model_name}.pth"),
        "history_path": str(history_path),
    }

    print(f"Training completed for {model_name}.")
    print("Best validation accuracy:", benchmark_result["best_val_acc"])

    return benchmark_result, history_df

# %%
MODEL_NAMES = [
    # "resnet101",
    # "efficientnet_v2_l"
    # "resnet50",
    # "efficientnet_b0",
    # "mobilenet_v2",
    "deit_base"
]

# %%
output_dir = Path("/kaggle/working/")
output_dir.mkdir(parents=True, exist_ok=True)


all_benchmarks = []

for model_name in MODEL_NAMES:
    benchmark_result, history_df = train_one_model(
        model_name=model_name,
        train_loader=train_loader,
        val_loader=val_loader,
        num_classes=num_classes,
        class_names=class_names,
        device=device,
        output_dir=output_dir,
        num_epochs=30,
        patience=5,
        lr=1e-5,
        freeze_backbone=True
    )

    all_benchmarks.append(benchmark_result)

# =========================
# Save combined benchmark
# =========================

benchmark_df = pd.DataFrame(all_benchmarks)

benchmark_path = output_dir / "model_benchmark_summary.csv"
benchmark_df.to_csv(benchmark_path, index=False)

print("\nAll model training completed.")
print(f"Benchmark summary saved to: {benchmark_path}")

benchmark_df
# Out:
# ==============================
# Start training: deit_base
# ==============================
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Selected device: cuda
# Model device: cuda:0
#
# ===== deit_base | Epoch 1/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 345.689453125 MB
#   GPU memory reserved: 402.0 MB
# [Train] deit_base | Epoch 1 Batch 0/230 | Loss: 1.7339
# [Train] deit_base | Epoch 1 Batch 10/230 | Loss: 1.7513
# [Train] deit_base | Epoch 1 Batch 20/230 | Loss: 1.6421
# [Train] deit_base | Epoch 1 Batch 30/230 | Loss: 1.7032
# [Train] deit_base | Epoch 1 Batch 40/230 | Loss: 1.6513
# [Train] deit_base | Epoch 1 Batch 50/230 | Loss: 1.7277
# [Train] deit_base | Epoch 1 Batch 60/230 | Loss: 1.6468
# [Train] deit_base | Epoch 1 Batch 70/230 | Loss: 1.6767
# [Train] deit_base | Epoch 1 Batch 80/230 | Loss: 1.5966
# [Train] deit_base | Epoch 1 Batch 90/230 | Loss: 1.6321
# [Train] deit_base | Epoch 1 Batch 100/230 | Loss: 1.5179
# [Train] deit_base | Epoch 1 Batch 110/230 | Loss: 1.5151
# [Train] deit_base | Epoch 1 Batch 120/230 | Loss: 1.5037
# [Train] deit_base | Epoch 1 Batch 130/230 | Loss: 1.4145
# [Train] deit_base | Epoch 1 Batch 140/230 | Loss: 1.5022
# [Train] deit_base | Epoch 1 Batch 150/230 | Loss: 1.4513
# [Train] deit_base | Epoch 1 Batch 160/230 | Loss: 1.3225
# [Train] deit_base | Epoch 1 Batch 170/230 | Loss: 1.3244
# [Train] deit_base | Epoch 1 Batch 180/230 | Loss: 1.3774
# [Train] deit_base | Epoch 1 Batch 190/230 | Loss: 1.4620
# [Train] deit_base | Epoch 1 Batch 200/230 | Loss: 1.3906
# [Train] deit_base | Epoch 1 Batch 210/230 | Loss: 1.3883
# [Train] deit_base | Epoch 1 Batch 220/230 | Loss: 1.4357
# [Val] deit_base | Epoch 1 Batch 0/50 | Loss: 1.4155
# [Val] deit_base | Epoch 1 Batch 10/50 | Loss: 1.5174
# [Val] deit_base | Epoch 1 Batch 20/50 | Loss: 1.3466
# [Val] deit_base | Epoch 1 Batch 30/50 | Loss: 1.4732
# [Val] deit_base | Epoch 1 Batch 40/50 | Loss: 1.4917
# deit_base | Epoch 1/30 | Train Loss: 1.5330 | Train Acc: 0.4952 | Val Loss: 1.4179 | Val Acc: 0.6039
# Best model updated and saved to: /kaggle/working/best_deit_base.pth
#
# ===== deit_base | Epoch 2/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 362.6201171875 MB
#   GPU memory reserved: 686.0 MB
# [Train] deit_base | Epoch 2 Batch 0/230 | Loss: 1.3748
# [Train] deit_base | Epoch 2 Batch 10/230 | Loss: 1.2219
# [Train] deit_base | Epoch 2 Batch 20/230 | Loss: 1.3085
# [Train] deit_base | Epoch 2 Batch 30/230 | Loss: 1.4214
# [Train] deit_base | Epoch 2 Batch 40/230 | Loss: 1.2222
# [Train] deit_base | Epoch 2 Batch 50/230 | Loss: 1.2132
# [Train] deit_base | Epoch 2 Batch 60/230 | Loss: 1.1485
# [Train] deit_base | Epoch 2 Batch 70/230 | Loss: 1.2511
# [Train] deit_base | Epoch 2 Batch 80/230 | Loss: 1.1458
# [Train] deit_base | Epoch 2 Batch 90/230 | Loss: 1.2416
# [Train] deit_base | Epoch 2 Batch 100/230 | Loss: 1.2514
# [Train] deit_base | Epoch 2 Batch 110/230 | Loss: 1.1436
# [Train] deit_base | Epoch 2 Batch 120/230 | Loss: 1.3354
# [Train] deit_base | Epoch 2 Batch 130/230 | Loss: 1.2621
# [Train] deit_base | Epoch 2 Batch 140/230 | Loss: 1.0549
# [Train] deit_base | Epoch 2 Batch 150/230 | Loss: 1.1655
# [Train] deit_base | Epoch 2 Batch 160/230 | Loss: 1.1568
# [Train] deit_base | Epoch 2 Batch 170/230 | Loss: 1.3363
# [Train] deit_base | Epoch 2 Batch 180/230 | Loss: 1.0742
# [Train] deit_base | Epoch 2 Batch 190/230 | Loss: 1.2414
# [Train] deit_base | Epoch 2 Batch 200/230 | Loss: 1.0231
# [Train] deit_base | Epoch 2 Batch 210/230 | Loss: 1.2443
# [Train] deit_base | Epoch 2 Batch 220/230 | Loss: 1.0684
# [Val] deit_base | Epoch 2 Batch 0/50 | Loss: 1.1667
# [Val] deit_base | Epoch 2 Batch 10/50 | Loss: 1.3296
# [Val] deit_base | Epoch 2 Batch 20/50 | Loss: 1.1246
# [Val] deit_base | Epoch 2 Batch 30/50 | Loss: 1.2321
# [Val] deit_base | Epoch 2 Batch 40/50 | Loss: 1.2787
# deit_base | Epoch 2/30 | Train Loss: 1.2195 | Train Acc: 0.6915 | Val Loss: 1.1974 | Val Acc: 0.7114
# Best model updated and saved to: /kaggle/working/best_deit_base.pth
#
# ===== deit_base | Epoch 3/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 362.6201171875 MB
#   GPU memory reserved: 686.0 MB
# [Train] deit_base | Epoch 3 Batch 0/230 | Loss: 1.0240
# [Train] deit_base | Epoch 3 Batch 10/230 | Loss: 1.1873
# [Train] deit_base | Epoch 3 Batch 20/230 | Loss: 1.0344
# [Train] deit_base | Epoch 3 Batch 30/230 | Loss: 0.9259
# [Train] deit_base | Epoch 3 Batch 40/230 | Loss: 1.2510
# [Train] deit_base | Epoch 3 Batch 50/230 | Loss: 1.0969
# [Train] deit_base | Epoch 3 Batch 60/230 | Loss: 1.1328
# [Train] deit_base | Epoch 3 Batch 70/230 | Loss: 1.1872
# [Train] deit_base | Epoch 3 Batch 80/230 | Loss: 1.1356
# [Train] deit_base | Epoch 3 Batch 90/230 | Loss: 1.0285
# [Train] deit_base | Epoch 3 Batch 100/230 | Loss: 1.2454
# [Train] deit_base | Epoch 3 Batch 110/230 | Loss: 1.1201
# [Train] deit_base | Epoch 3 Batch 120/230 | Loss: 1.1051
# [Train] deit_base | Epoch 3 Batch 130/230 | Loss: 1.1271
# [Train] deit_base | Epoch 3 Batch 140/230 | Loss: 1.0241
# [Train] deit_base | Epoch 3 Batch 150/230 | Loss: 1.0311
# [Train] deit_base | Epoch 3 Batch 160/230 | Loss: 0.9794
# [Train] deit_base | Epoch 3 Batch 170/230 | Loss: 1.1329
# [Train] deit_base | Epoch 3 Batch 180/230 | Loss: 0.9353
# [Train] deit_base | Epoch 3 Batch 190/230 | Loss: 1.1374
# [Train] deit_base | Epoch 3 Batch 200/230 | Loss: 1.0715
# [Train] deit_base | Epoch 3 Batch 210/230 | Loss: 1.0098
# [Train] deit_base | Epoch 3 Batch 220/230 | Loss: 0.8238
# [Val] deit_base | Epoch 3 Batch 0/50 | Loss: 1.0111
# [Val] deit_base | Epoch 3 Batch 10/50 | Loss: 1.2118
# [Val] deit_base | Epoch 3 Batch 20/50 | Loss: 0.9904
# [Val] deit_base | Epoch 3 Batch 30/50 | Loss: 1.0735
# [Val] deit_base | Epoch 3 Batch 40/50 | Loss: 1.1429
# deit_base | Epoch 3/30 | Train Loss: 1.0594 | Train Acc: 0.7403 | Val Loss: 1.0608 | Val Acc: 0.7495
# Best model updated and saved to: /kaggle/working/best_deit_base.pth
#
# ===== deit_base | Epoch 4/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 362.6201171875 MB
#   GPU memory reserved: 686.0 MB
# [Train] deit_base | Epoch 4 Batch 0/230 | Loss: 1.0817
# [Train] deit_base | Epoch 4 Batch 10/230 | Loss: 0.9131
# [Train] deit_base | Epoch 4 Batch 20/230 | Loss: 1.1958
# [Train] deit_base | Epoch 4 Batch 30/230 | Loss: 1.0390
# [Train] deit_base | Epoch 4 Batch 40/230 | Loss: 0.9226
# [Train] deit_base | Epoch 4 Batch 50/230 | Loss: 1.1992
# [Train] deit_base | Epoch 4 Batch 60/230 | Loss: 0.9992
# [Train] deit_base | Epoch 4 Batch 70/230 | Loss: 0.9014
# [Train] deit_base | Epoch 4 Batch 80/230 | Loss: 1.0651
# [Train] deit_base | Epoch 4 Batch 90/230 | Loss: 1.0157
# [Train] deit_base | Epoch 4 Batch 100/230 | Loss: 1.0260
# [Train] deit_base | Epoch 4 Batch 110/230 | Loss: 1.0499
# [Train] deit_base | Epoch 4 Batch 120/230 | Loss: 0.7791
# [Train] deit_base | Epoch 4 Batch 130/230 | Loss: 0.9290
# [Train] deit_base | Epoch 4 Batch 140/230 | Loss: 0.9591
# [Train] deit_base | Epoch 4 Batch 150/230 | Loss: 1.1643
# [Train] deit_base | Epoch 4 Batch 160/230 | Loss: 0.9726
# [Train] deit_base | Epoch 4 Batch 170/230 | Loss: 1.0298
# [Train] deit_base | Epoch 4 Batch 180/230 | Loss: 1.1971
# [Train] deit_base | Epoch 4 Batch 190/230 | Loss: 0.7233
# [Train] deit_base | Epoch 4 Batch 200/230 | Loss: 1.2016
# [Train] deit_base | Epoch 4 Batch 210/230 | Loss: 0.9068
# [Train] deit_base | Epoch 4 Batch 220/230 | Loss: 0.9019
# [Val] deit_base | Epoch 4 Batch 0/50 | Loss: 0.9071
# [Val] deit_base | Epoch 4 Batch 10/50 | Loss: 1.1302
# [Val] deit_base | Epoch 4 Batch 20/50 | Loss: 0.9032
# [Val] deit_base | Epoch 4 Batch 30/50 | Loss: 0.9614
# [Val] deit_base | Epoch 4 Batch 40/50 | Loss: 1.0495
# deit_base | Epoch 4/30 | Train Loss: 0.9541 | Train Acc: 0.7794 | Val Loss: 0.9686 | Val Acc: 0.7743
# Best model updated and saved to: /kaggle/working/best_deit_base.pth
#
# ===== deit_base | Epoch
# [Train] deit_base | Epoch 6 Batch 100/230 | Loss: 0.8961
# [Train] deit_base | Epoch 6 Batch 110/230 | Loss: 0.8950
# [Train] deit_base | Epoch 6 Batch 120/230 | Loss: 0.8136
# [Train] deit_base | Epoch 6 Batch 130/230 | Loss: 0.7215
# [Train] deit_base | Epoch 6 Batch 140/230 | Loss: 0.7808
# [Train] deit_base | Epoch 6 Batch 150/230 | Loss: 0.7718
# [Train] deit_base | Epoch 6 Batch 160/230 | Loss: 0.6906
# [Train] deit_base | Epoch 6 Batch 170/230 | Loss: 1.0037
# [Train] deit_base | Epoch 6 Batch 180/230 | Loss: 1.0190
# [Train] deit_base | Epoch 6 Batch 190/230 | Loss: 0.8542
# [Train] deit_base | Epoch 6 Batch 200/230 | Loss: 0.8662
# [Train] deit_base | Epoch 6 Batch 210/230 | Loss: 1.0350
# [Train] deit_base | Epoch 6 Batch 220/230 | Loss: 0.8181
# [Val] deit_base | Epoch 6 Batch 0/50 | Loss: 0.7822
# [Val] deit_base | Epoch 6 Batch 10/50 | Loss: 1.0196
# [Val] deit_base | Epoch 6 Batch 20/50 | Loss: 0.7997
# [Val] deit_base | Epoch 6 Batch 30/50 | Loss: 0.8151
# [Val] deit_base | Epoch 6 Batch 40/50 | Loss: 0.9294
# deit_base | Epoch 6/30 | Train Loss: 0.8345 | Train Acc: 0.8038 | Val Loss: 0.8520 | Val Acc: 0.7947
# Best model updated and saved to: /kaggle/working/best_deit_base.pth
#
# ===== deit_base | Epoch 7/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 362.6201171875 MB
#   GPU memory reserved: 686.0 MB
# [Train] deit_base | Epoch 7 Batch 0/230 | Loss: 0.9672
# [Train] deit_base | Epoch 7 Batch 10/230 | Loss: 0.8962
# [Train] deit_base | Epoch 7 Batch 20/230 | Loss: 0.8626
# [Train] deit_base | Epoch 7 Batch 30/230 | Loss: 0.7647
# [Train] deit_base | Epoch 7 Batch 40/230 | Loss: 0.7920
# [Train] deit_base | Epoch 7 Batch 50/230 | Loss: 0.9659
# [Train] deit_base | Epoch 7 Batch 60/230 | Loss: 0.7909
# [Train] deit_base | Epoch 7 Batch 70/230 | Loss: 0.8066
# [Train] deit_base | Epoch 7 Batch 80/230 | Loss: 1.1689
# [Train] deit_base | Epoch 7 Batch 90/230 | Loss: 0.6263
# [Train] deit_base | Epoch 7 Batch 100/230 | Loss: 0.7672
# [Train] deit_base | Epoch 7 Batch 110/230 | Loss: 0.7260
# [Train] deit_base | Epoch 7 Batch 120/230 | Loss: 0.9507
# [Train] deit_base | Epoch 7 Batch 130/230 | Loss: 0.8997
# [Train] deit_base | Epoch 7 Batch 140/230 | Loss: 0.7145
# [Train] deit_base | Epoch 7 Batch 150/230 | Loss: 0.9117
# [Train] deit_base | Epoch 7 Batch 160/230 | Loss: 0.9812
# [Train] deit_base | Epoch 7 Batch 170/230 | Loss: 0.7373
# [Train] deit_base | Epoch 7 Batch 180/230 | Loss: 0.6681
# [Train] deit_base | Epoch 7 Batch 190/230 | Loss: 0.7387
# [Train] deit_base | Epoch 7 Batch 200/230 | Loss: 0.8584
# [Train] deit_base | Epoch 7 Batch 210/230 | Loss: 0.9944
# [Train] deit_base | Epoch 7 Batch 220/230 | Loss: 0.6447
# [Val] deit_base | Epoch 20 Batch 0/50 | Loss: 0.5691
# [Val] deit_base | Epoch 20 Batch 10/50 | Loss: 0.7285
# [Val] deit_base | Epoch 20 Batch 20/50 | Loss: 0.6144
# [Val] deit_base | Epoch 20 Batch 30/50 | Loss: 0.5043
# [Val] deit_base | Epoch 20 Batch 40/50 | Loss: 0.6690
# deit_base | Epoch 20/30 | Train Loss: 0.5711 | Train Acc: 0.8402 | Val Loss: 0.6004 | Val Acc: 0.8245
# Best model updated and saved to: /kaggle/working/best_deit_base.pth
#
# ===== deit_base | Epoch 21/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 362.6201171875 MB
#   GPU memory reserved: 686.0 MB
# [Train] deit_base | Epoch 21 Batch 0/230 | Loss: 0.6776
# [Train] deit_base | Epoch 21 Batch 10/230 | Loss: 0.4605
# [Train] deit_base | Epoch 21 Batch 20/230 | Loss: 0.5686
# [Train] deit_base | Epoch 21 Batch 30/230 | Loss: 0.6628
# [Train] deit_base | Epoch 21 Batch 40/230 | Loss: 0.6566
# [Train] deit_base | Epoch 21 Batch 50/230 | Loss: 0.4991
# [Train] deit_base | Epoch 21 Batch 60/230 | Loss: 0.7261
# [Train] deit_base | Epoch 21 Batch 70/230 | Loss: 0.6671
# [Train] deit_base | Epoch 21 Batch 80/230 | Loss: 0.5108
# [Train] deit_base | Epoch 21 Batch 90/230 | Loss: 0.3947
# [Train] deit_base | Epoch 21 Batch 100/230 | Loss: 0.3743
# [Train] deit_base | Epoch 21 Batch 110/230 | Loss: 0.6040
# [Train] deit_base | Epoch 21 Batch 120/230 | Loss: 0.6180
# [Train] deit_base | Epoch 21 Batch 130/230 | Loss: 0.9268
# [Train] deit_base | Epoch 21 Batch 140/230 | Loss: 0.7634
# [Train] deit_base | Epoch 21 Batch 150/230 | Loss: 0.4531
# [Train] deit_base | Epoch 21 Batch 160/230 | Loss: 0.4639
# [Train] deit_base | Epoch 21 Batch 170/230 | Loss: 0.5891
# [Train] deit_base | Epoch 21 Batch 180/230 | Loss: 0.6123
# [Train] deit_base | Epoch 21 Batch 190/230 | Loss: 0.5742
# [Train] deit_base | Epoch 21 Batch 200/230 | Loss: 0.4470
# [Train] deit_base | Epoch 21 Batch 210/230 | Loss: 0.7367
# [Train] deit_base | Epoch 21 Batch 220/230 | Loss: 0.4641
# [Val] deit_base | Epoch 21 Batch 0/50 | Loss: 0.5630
# [Val] deit_base | Epoch 21 Batch 10/50 | Loss: 0.7185
# [Val] deit_base | Epoch 21 Batch 20/50 | Loss: 0.6085
# [Val] deit_base | Epoch 21 Batch 30/50 | Loss: 0.4948
# [Val] deit_base | Epoch 21 Batch 40/50 | Loss: 0.6613
# deit_base | Epoch 21/30 | Train Loss: 0.5594 | Train Acc: 0.8434 | Val Loss: 0.5921 | Val Acc: 0.8277
# Best model updated and saved to: /kaggle/working/best_deit_base.pth
#
# ===== deit_base | Epoch 22/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 362.6201171875 MB
#   GPU memory reserved: 686.0 MB
# [Train] deit_base | Epoch 22 Batch 0/230 | Loss: 0.4431
# [Train] deit_base | Epoch 22 Batch 10/230 | Loss: 0.5211
# [Train] deit_base | Epoch 22 Batch 20/230 | Loss: 0.2793
# [Train] deit_base | Epoch 22 Batch 30/230 | Loss: 0.4901
# [Train] deit_base | Epoch 22 Batch 40/230 | Loss: 0.8767
# [Train] deit_base | Epoch 22 Batch 50/230 | Loss: 0.3855
# [Train] deit_base | Epoch 22 Batch 60/230 | Loss: 0.4522
# [Train] deit_base | Epoch 23 Batch 200/230 | Loss: 0.4366
# [Train] deit_base | Epoch 23 Batch 210/230 | Loss: 0.7617
# [Train] deit_base | Epoch 23 Batch 220/230 | Loss: 0.5122
# [Val] deit_base | Epoch 23 Batch 0/50 | Loss: 0.5543
# [Val] deit_base | Epoch 23 Batch 10/50 | Loss: 0.7016
# [Val] deit_base | Epoch 23 Batch 20/50 | Loss: 0.6011
# [Val] deit_base | Epoch 23 Batch 30/50 | Loss: 0.4803
# [Val] deit_base | Epoch 23 Batch 40/50 | Loss: 0.6475
# deit_base | Epoch 23/30 | Train Loss: 0.5495 | Train Acc: 0.8432 | Val Loss: 0.5792 | Val Acc: 0.8303
# Best model updated and saved to: /kaggle/working/best_deit_base.pth
#
# ===== deit_base | Epoch 24/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 362.6201171875 MB
#   GPU memory reserved: 686.0 MB
# [Train] deit_base | Epoch 24 Batch 0/230 | Loss: 0.4579
# [Train] deit_base | Epoch 24 Batch 10/230 | Loss: 0.3807
# [Train] deit_base | Epoch 24 Batch 20/230 | Loss: 0.5009
# [Train] deit_base | Epoch 24 Batch 30/230 | Loss: 0.5632
# [Train] deit_base | Epoch 24 Batch 40/230 | Loss: 0.6582
# [Train] deit_base | Epoch 24 Batch 50/230 | Loss: 0.5910
# [Train] deit_base | Epoch 24 Batch 60/230 | Loss: 0.7342
# [Train] deit_base | Epoch 24 Batch 70/230 | Loss: 0.3810
# [Train] deit_base | Epoch 24 Batch 80/230 | Loss: 0.6458
# [Train] deit_base | Epoch 24 Batch 90/230 | Loss: 0.6149
# [Train] deit_base | Epoch 24 Batch 100/230 | Loss: 0.6171
# [Train] deit_base | Epoch 24 Batch 110/230 | Loss: 0.4300
# [Train] deit_base | Epoch 24 Batch 120/230 | Loss: 0.4462
# [Train] deit_base | Epoch 24 Batch 130/230 | Loss: 0.6239
# [Train] deit_base | Epoch 24 Batch 140/230 | Loss: 0.8979
# [Train] deit_base | Epoch 24 Batch 150/230 | Loss: 0.5172
# [Train] deit_base | Epoch 24 Batch 160/230 | Loss: 0.4562
# [Train] deit_base | Epoch 24 Batch 170/230 | Loss: 0.6495
# [Train] deit_base | Epoch 24 Batch 180/230 | Loss: 0.4107
# [Train] deit_base | Epoch 24 Batch 190/230 | Loss: 0.5372
# [Train] deit_base | Epoch 24 Batch 200/230 | Loss: 0.5740
# [Train] deit_base | Epoch 24 Batch 210/230 | Loss: 0.7914
# [Train] deit_base | Epoch 24 Batch 220/230 | Loss: 0.2528
# [Val] deit_base | Epoch 24 Batch 0/50 | Loss: 0.5494
# [Val] deit_base | Epoch 24 Batch 10/50 | Loss: 0.6937
# [Val] deit_base | Epoch 24 Batch 20/50 | Loss: 0.5961
# [Val] deit_base | Epoch 24 Batch 30/50 | Loss: 0.4730
# [Val] deit_base | Epoch 24 Batch 40/50 | Loss: 0.6406
# deit_base | Epoch 24/30 | Train Loss: 0.5380 | Train Acc: 0.8463 | Val Loss: 0.5722 | Val Acc: 0.8322
# Best model updated and saved to: /kaggle/working/best_deit_base.pth
#
# ===== deit_base | Epoch 25/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 362.6201171875 MB
#   GPU memory reserved: 686.0 MB
# [Train] deit_base | Epoch
# [Train] deit_base | Epoch 26 Batch 170/230 | Loss: 0.3310
# [Train] deit_base | Epoch 26 Batch 180/230 | Loss: 0.8256
# [Train] deit_base | Epoch 26 Batch 190/230 | Loss: 0.8494
# [Train] deit_base | Epoch 26 Batch 200/230 | Loss: 0.5716
# [Train] deit_base | Epoch 26 Batch 210/230 | Loss: 0.4815
# [Train] deit_base | Epoch 26 Batch 220/230 | Loss: 0.6356
# [Val] deit_base | Epoch 26 Batch 0/50 | Loss: 0.5419
# [Val] deit_base | Epoch 26 Batch 10/50 | Loss: 0.6794
# [Val] deit_base | Epoch 26 Batch 20/50 | Loss: 0.5901
# [Val] deit_base | Epoch 26 Batch 30/50 | Loss: 0.4610
# [Val] deit_base | Epoch 26 Batch 40/50 | Loss: 0.6284
# deit_base | Epoch 26/30 | Train Loss: 0.5249 | Train Acc: 0.8481 | Val Loss: 0.5611 | Val Acc: 0.8341
# Best model updated and saved to: /kaggle/working/best_deit_base.pth
#
# ===== deit_base | Epoch 27/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 362.6201171875 MB
#   GPU memory reserved: 686.0 MB
# [Train] deit_base | Epoch 27 Batch 0/230 | Loss: 0.7447
# [Train] deit_base | Epoch 27 Batch 10/230 | Loss: 0.5096
# [Train] deit_base | Epoch 27 Batch 20/230 | Loss: 0.8186
# [Train] deit_base | Epoch 27 Batch 30/230 | Loss: 0.4756
# [Train] deit_base | Epoch 27 Batch 40/230 | Loss: 0.3942
# [Train] deit_base | Epoch 27 Batch 50/230 | Loss: 0.6040
# [Train] deit_base | Epoch 27 Batch 60/230 | Loss: 0.5669
# [Train] deit_base | Epoch 27 Batch 70/230 | Loss: 0.4633
# [Train] deit_base | Epoch 27 Batch 80/230 | Loss: 0.6075
# [Train] deit_base | Epoch 27 Batch 90/230 | Loss: 0.7978
# [Train] deit_base | Epoch 27 Batch 100/230 | Loss: 0.5943
# [Train] deit_base | Epoch 27 Batch 110/230 | Loss: 0.7710
# [Train] deit_base | Epoch 27 Batch 120/230 | Loss: 0.5149
# [Train] deit_base | Epoch 27 Batch 130/230 | Loss: 0.4476
# [Train] deit_base | Epoch 27 Batch 140/230 | Loss: 0.4594
# [Train] deit_base | Epoch 27 Batch 150/230 | Loss: 0.4714
# [Train] deit_base | Epoch 27 Batch 160/230 | Loss: 0.5265
# [Train] deit_base | Epoch 27 Batch 170/230 | Loss: 0.3856
# [Train] deit_base | Epoch 27 Batch 180/230 | Loss: 0.4802
# [Train] deit_base | Epoch 27 Batch 190/230 | Loss: 0.4983
# [Train] deit_base | Epoch 27 Batch 200/230 | Loss: 0.6673
# [Train] deit_base | Epoch 27 Batch 210/230 | Loss: 0.5808
# [Train] deit_base | Epoch 27 Batch 220/230 | Loss: 0.3367
# [Val] deit_base | Epoch 27 Batch 0/50 | Loss: 0.5384
# [Val] deit_base | Epoch 27 Batch 10/50 | Loss: 0.6726
# [Val] deit_base | Epoch 27 Batch 20/50 | Loss: 0.5866
# [Val] deit_base | Epoch 27 Batch 30/50 | Loss: 0.4555
# [Val] deit_base | Epoch 27 Batch 40/50 | Loss: 0.6226
# deit_base | Epoch 27/30 | Train Loss: 0.5214 | Train Acc: 0.8493 | Val Loss: 0.5557 | Val Acc: 0.8353
# Best model updated and saved to: /kaggle/working/best_deit_base.pth
#
# ===== deit_base | Epoch 28/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 362.6201171875 MB
#   GPU memory reserved: 686.0 MB
# [Train] deit_base | Epoch
# [Train] deit_base | Epoch 29 Batch 140/230 | Loss: 0.6647
# [Train] deit_base | Epoch 29 Batch 150/230 | Loss: 0.7776
# [Train] deit_base | Epoch 29 Batch 160/230 | Loss: 0.3977
# [Train] deit_base | Epoch 29 Batch 170/230 | Loss: 0.5076
# [Train] deit_base | Epoch 29 Batch 180/230 | Loss: 0.6291
# [Train] deit_base | Epoch 29 Batch 190/230 | Loss: 0.4348
# [Train] deit_base | Epoch 29 Batch 200/230 | Loss: 0.5916
# [Train] deit_base | Epoch 29 Batch 210/230 | Loss: 0.5112
# [Train] deit_base | Epoch 29 Batch 220/230 | Loss: 0.4835
# [Val] deit_base | Epoch 29 Batch 0/50 | Loss: 0.5318
# [Val] deit_base | Epoch 29 Batch 10/50 | Loss: 0.6616
# [Val] deit_base | Epoch 29 Batch 20/50 | Loss: 0.5825
# [Val] deit_base | Epoch 29 Batch 30/50 | Loss: 0.4470
# [Val] deit_base | Epoch 29 Batch 40/50 | Loss: 0.6136
# deit_base | Epoch 29/30 | Train Loss: 0.5125 | Train Acc: 0.8498 | Val Loss: 0.5470 | Val Acc: 0.8373
# Best model updated and saved to: /kaggle/working/best_deit_base.pth
#
# ===== deit_base | Epoch 30/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 362.6201171875 MB
#   GPU memory reserved: 686.0 MB
# [Train] deit_base | Epoch 30 Batch 0/230 | Loss: 0.5797
# [Train] deit_base | Epoch 30 Batch 10/230 | Loss: 0.5422
# [Train] deit_base | Epoch 30 Batch 20/230 | Loss: 0.4427
# [Train] deit_base | Epoch 30 Batch 30/230 | Loss: 0.4365
# [Train] deit_base | Epoch 30 Batch 40/230 | Loss: 0.7658
# [Train] deit_base | Epoch 30 Batch 50/230 | Loss: 0.6925
# [Train] deit_base | Epoch 30 Batch 60/230 | Loss: 0.3676
# [Train] deit_base | Epoch 30 Batch 70/230 | Loss: 0.3149
# [Train] deit_base | Epoch 30 Batch 80/230 | Loss: 0.3163
# [Train] deit_base | Epoch 30 Batch 90/230 | Loss: 0.6217
# [Train] deit_base | Epoch 30 Batch 100/230 | Loss: 0.5262
# [Train] deit_base | Epoch 30 Batch 110/230 | Loss: 0.4714
# [Train] deit_base | Epoch 30 Batch 120/230 | Loss: 0.5406
# [Train] deit_base | Epoch 30 Batch 130/230 | Loss: 0.5262
# [Train] deit_base | Epoch 30 Batch 140/230 | Loss: 0.5247
# [Train] deit_base | Epoch 30 Batch 150/230 | Loss: 0.5505
# [Train] deit_base | Epoch 30 Batch 160/230 | Loss: 0.4182
# [Train] deit_base | Epoch 30 Batch 170/230 | Loss: 0.3389
# [Train] deit_base | Epoch 30 Batch 180/230 | Loss: 0.5215
# [Train] deit_base | Epoch 30 Batch 190/230 | Loss: 0.3033
# [Train] deit_base | Epoch 30 Batch 200/230 | Loss: 0.6067
# [Train] deit_base | Epoch 30 Batch 210/230 | Loss: 0.5804
# [Train] deit_base | Epoch 30 Batch 220/230 | Loss: 0.7942
# [Val] deit_base | Epoch 30 Batch 0/50 | Loss: 0.5289
# [Val] deit_base | Epoch 30 Batch 10/50 | Loss: 0.6564
# [Val] deit_base | Epoch 30 Batch 20/50 | Loss: 0.5793
# [Val] deit_base | Epoch 30 Batch 30/50 | Loss: 0.4424
# [Val] deit_base | Epoch 30 Batch 40/50 | Loss: 0.6080
# deit_base | Epoch 30/30 | Train Loss: 0.5069 | Train Acc: 0.8519 | Val Loss: 0.5425 | Val Acc: 0.8392
# Best model updated and saved to: /kaggle/working/best_deit_base.pth
# Training completed for deit_base.
# Best validation accuracy: 0.8391608391608392
#
# All model training completed.
# Benchmark summary saved to: /kaggle/working/model_benchmark_summary.csv
#   model_name  best_epoch  best_train_loss  best_train_acc  best_val_loss  \
# 0  deit_base          30         0.506865        0.851887       0.542547
#
#    best_val_acc  total_epochs_trained  early_stopped  \
# 0      0.839161                    30          False
#
#                       best_model_path  \
# 0  /kaggle/working/best_deit_base.pth
#
#                                      history_path
# 0  /kaggle/working/deit_base_training_history.csv

# %% [markdown]
# ## Convergence behavior

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

def plot_convergence(model_name, output_dir, max_epochs=30):
    output_dir = Path(output_dir)

    history_path = output_dir / f"{model_name}_training_history.csv"
    df = pd.read_csv(history_path)

    # limit to first N epochs if needed
    df = df[df["epoch"] <= max_epochs]

    # ===== Loss plot =====
    plt.figure(figsize=(10, 5))
    plt.plot(df["epoch"], df["train_loss"], label="Train Loss")
    plt.plot(df["epoch"], df["val_loss"], label="Validation Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title(f"Convergence (Loss) - {model_name}")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()

    loss_path = output_dir / f"{model_name}_convergence_loss.png"
    plt.savefig(loss_path, dpi=300)
    plt.show()

    # ===== Accuracy plot =====
    plt.figure(figsize=(10, 5))
    plt.plot(df["epoch"], df["train_acc"], label="Train Accuracy")
    plt.plot(df["epoch"], df["val_acc"], label="Validation Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.title(f"Convergence (Accuracy) - {model_name}")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()

    acc_path = output_dir / f"{model_name}_convergence_accuracy.png"
    plt.savefig(acc_path, dpi=300)
    plt.show()

    print(f"Saved plots for {model_name}")


def compare_convergence(model_names, output_dir, max_epochs=30):
    output_dir = Path(output_dir)

    plt.figure(figsize=(12, 6))

    for model_name in model_names:
        df = pd.read_csv(output_dir / f"{model_name}_training_history.csv")
        df = df[df["epoch"] <= max_epochs]

        plt.plot(df["epoch"], df["val_loss"], label=model_name)

    plt.xlabel("Epoch")
    plt.ylabel("Validation Loss")
    plt.title("Validation Loss Convergence Comparison")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()

    plt.savefig(output_dir / "compare_val_loss.png", dpi=300)
    plt.show()


    plt.figure(figsize=(12, 6))

    for model_name in model_names:
        df = pd.read_csv(output_dir / f"{model_name}_training_history.csv")
        df = df[df["epoch"] <= max_epochs]

        plt.plot(df["epoch"], df["val_acc"], label=model_name)

    plt.xlabel("Epoch")
    plt.ylabel("Validation Accuracy")
    plt.title("Validation Accuracy Convergence Comparison")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()

    plt.savefig(output_dir / "compare_val_accuracy.png", dpi=300)
    plt.show()

# %%
output_dir = Path("/kaggle/working/")

# Plot each model separately
for model_name in MODEL_NAMES:
    plot_convergence(
        model_name=model_name,
        output_dir=output_dir,
        max_epochs=30
    )

# Plot comparison across selected models
compare_convergence(
    model_names=MODEL_NAMES,
    output_dir=output_dir,
    max_epochs=30
)
# Out:
# Saved plots for deit_base

# %% [markdown]
# # Evaluation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from pathlib import Path
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    f1_score,
    recall_score,
    precision_score,
    classification_report,
    confusion_matrix,
    roc_auc_score,
    roc_curve,
    auc
)
from sklearn.preprocessing import label_binarize


# =========================
# Test evaluation function
# =========================

def evaluate_on_test_set(
    model,
    test_loader,
    device,
    class_names,
    output_dir,
    model_name="model"
):
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

    model.eval()

    all_probs = []
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            outputs = model(images)
            probs = torch.softmax(outputs, dim=1)
            preds = torch.argmax(probs, dim=1)

            all_probs.append(probs.cpu().numpy())
            all_preds.append(preds.cpu().numpy())
            all_labels.append(labels.cpu().numpy())

    all_probs = np.concatenate(all_probs, axis=0)
    all_preds = np.concatenate(all_preds, axis=0)
    all_labels = np.concatenate(all_labels, axis=0)

    num_classes = len(class_names)

    # =========================
    # Overall metrics
    # =========================

    accuracy = accuracy_score(all_labels, all_preds)
    balanced_acc = balanced_accuracy_score(all_labels, all_preds)

    f1_macro = f1_score(all_labels, all_preds, average="macro")
    f1_weighted = f1_score(all_labels, all_preds, average="weighted")

    recall_macro = recall_score(all_labels, all_preds, average="macro")
    recall_weighted = recall_score(all_labels, all_preds, average="weighted")

    precision_macro = precision_score(all_labels, all_preds, average="macro", zero_division=0)
    precision_weighted = precision_score(all_labels, all_preds, average="weighted", zero_division=0)

    # ROC-AUC
    try:
        if num_classes == 2:
            roc_auc = roc_auc_score(all_labels, all_probs[:, 1])
        else:
            roc_auc = roc_auc_score(
                all_labels,
                all_probs,
                multi_class="ovr",
                average="macro"
            )
    except Exception as e:
        print("ROC-AUC could not be calculated:", e)
        roc_auc = np.nan

    metrics_df = pd.DataFrame([{
        "model_name": model_name,
        "accuracy": accuracy,
        "balanced_accuracy": balanced_acc,
        "f1_macro": f1_macro,
        "f1_weighted": f1_weighted,
        "recall_macro": recall_macro,
        "recall_weighted": recall_weighted,
        "precision_macro": precision_macro,
        "precision_weighted": precision_weighted,
        "roc_auc_ovr_macro": roc_auc
    }])

    metrics_path = output_dir / f"{model_name}_test_metrics.csv"
    metrics_df.to_csv(metrics_path, index=False)

    print(f"Saved test metrics to: {metrics_path}")
    print(metrics_df)

    # =========================
    # Per-class classification report
    # =========================

    report_dict = classification_report(
        all_labels,
        all_preds,
        target_names=class_names,
        output_dict=True,
        zero_division=0
    )

    report_df = pd.DataFrame(report_dict).transpose()
    report_path = output_dir / f"{model_name}_classification_report.csv"
    report_df.to_csv(report_path)

    print(f"Saved classification report to: {report_path}")

    # =========================
    # Prediction probabilities CSV
    # =========================

    prob_df = pd.DataFrame(all_probs, columns=[f"prob_{c}" for c in class_names])
    pred_df = pd.DataFrame({
        "true_label_id": all_labels,
        "pred_label_id": all_preds,
        "true_class": [class_names[i] for i in all_labels],
        "pred_class": [class_names[i] for i in all_preds],
        "confidence": np.max(all_probs, axis=1)
    })

    prediction_df = pd.concat([pred_df, prob_df], axis=1)
    prediction_path = output_dir / f"{model_name}_test_predictions.csv"
    prediction_df.to_csv(prediction_path, index=False)

    print(f"Saved test predictions to: {prediction_path}")

    # =========================
    # Confusion matrix
    # =========================

    cm = confusion_matrix(all_labels, all_preds)

    cm_df = pd.DataFrame(
        cm,
        index=class_names,
        columns=class_names
    )

    cm_path = output_dir / f"{model_name}_confusion_matrix.csv"
    cm_df.to_csv(cm_path)

    plt.figure(figsize=(12, 10))
    sns.heatmap(
        cm_df,
        annot=True,
        fmt="d",
        cmap="Blues",
        xticklabels=class_names,
        yticklabels=class_names
    )
    plt.xlabel("Predicted Class")
    plt.ylabel("True Class")
    plt.title(f"Confusion Matrix - {model_name}")
    plt.xticks(rotation=45, ha="right")
    plt.yticks(rotation=0)
    plt.tight_layout()

    cm_plot_path = output_dir / f"{model_name}_confusion_matrix.png"
    plt.savefig(cm_plot_path, dpi=300)
    plt.show()

    print(f"Saved confusion matrix plot to: {cm_plot_path}")

    # =========================
    # Normalized confusion matrix
    # =========================

    cm_norm = cm.astype("float") / cm.sum(axis=1, keepdims=True)
    cm_norm = np.nan_to_num(cm_norm)

    cm_norm_df = pd.DataFrame(
        cm_norm,
        index=class_names,
        columns=class_names
    )

    plt.figure(figsize=(12, 10))
    sns.heatmap(
        cm_norm_df,
        annot=True,
        fmt=".2f",
        cmap="Blues",
        xticklabels=class_names,
        yticklabels=class_names
    )
    plt.xlabel("Predicted Class")
    plt.ylabel("True Class")
    plt.title(f"Normalized Confusion Matrix - {model_name}")
    plt.xticks(rotation=45, ha="right")
    plt.yticks(rotation=0)
    plt.tight_layout()

    cm_norm_plot_path = output_dir / f"{model_name}_normalized_confusion_matrix.png"
    plt.savefig(cm_norm_plot_path, dpi=300)
    plt.show()

    print(f"Saved normalized confusion matrix plot to: {cm_norm_plot_path}")

    # =========================
    # Per-class score visualization
    # =========================

    per_class_df = report_df.loc[class_names, ["precision", "recall", "f1-score", "support"]]
    per_class_score_path = output_dir / f"{model_name}_per_class_scores.csv"
    per_class_df.to_csv(per_class_score_path)

    per_class_df[["precision", "recall", "f1-score"]].plot(
        kind="bar",
        figsize=(14, 7)
    )
    plt.title(f"Per-Class Precision, Recall, F1 Score - {model_name}")
    plt.xlabel("Class")
    plt.ylabel("Score")
    plt.ylim(0, 1)
    plt.xticks(rotation=45, ha="right")
    plt.tight_layout()

    score_plot_path = output_dir / f"{model_name}_per_class_scores.png"
    plt.savefig(score_plot_path, dpi=300)
    plt.show()

    print(f"Saved per-class score plot to: {score_plot_path}")

    # =========================
    # ROC curve
    # =========================

    plt.figure(figsize=(10, 8))

    if num_classes == 2:
        fpr, tpr, _ = roc_curve(all_labels, all_probs[:, 1])
        roc_auc_binary = auc(fpr, tpr)

        plt.plot(fpr, tpr, label=f"{class_names[1]} AUC = {roc_auc_binary:.4f}")

    else:
        y_true_bin = label_binarize(all_labels, classes=list(range(num_classes)))

        for i, class_name in enumerate(class_names):
            fpr, tpr, _ = roc_curve(y_true_bin[:, i], all_probs[:, i])
            class_auc = auc(fpr, tpr)
            plt.plot(fpr, tpr, label=f"{class_name} AUC = {class_auc:.4f}")

    plt.plot([0, 1], [0, 1], linestyle="--")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title(f"ROC-AUC Curve - {model_name}")
    plt.legend(loc="lower right")
    plt.tight_layout()

    roc_plot_path = output_dir / f"{model_name}_roc_auc_curve.png"
    plt.savefig(roc_plot_path, dpi=300)
    plt.show()

    print(f"Saved ROC-AUC curve to: {roc_plot_path}")

    return {
        "metrics_df": metrics_df,
        "classification_report_df": report_df,
        "predictions_df": prediction_df,
        "confusion_matrix_df": cm_df,
        "per_class_df": per_class_df
    }

# %%
output_dir = Path("/kaggle/working/")
eval_output_dir = output_dir / "evaluation_on_test_set"
eval_output_dir.mkdir(parents=True, exist_ok=True)


all_test_metrics = []

for model_name in MODEL_NAMES:
    print(f"\nEvaluating {model_name}")

    # Rebuild model architecture
    model = build_model(
        model_name=model_name,
        num_classes=num_classes,
        freeze_backbone=True
    ).to(device)

    # Load best checkpoint
    checkpoint_path = output_dir / f"best_{model_name}.pth"
    checkpoint = torch.load(checkpoint_path, map_location=device)

    model.load_state_dict(checkpoint["model_state_dict"])

    # Evaluate
    results = evaluate_on_test_set(
        model=model,
        test_loader=test_loader,
        device=device,
        class_names=class_names,
        output_dir=eval_output_dir,
        model_name=model_name
    )

    # Collect overall metrics
    metrics_df = results["metrics_df"]
    all_test_metrics.append(metrics_df)

# Combine all model test results
all_test_metrics_df = pd.concat(all_test_metrics, ignore_index=True)

summary_path = eval_output_dir / "all_models_test_evaluation_summary.csv"
all_test_metrics_df.to_csv(summary_path, index=False)

print("\nAll model evaluation completed.")
print(f"Saved summary to: {summary_path}")

all_test_metrics_df
# Out:
# Evaluating deit_base
# Saved test metrics to: /kaggle/working/evaluation_on_test_set/deit_base_test_metrics.csv
#   model_name  accuracy  balanced_accuracy  f1_macro  f1_weighted  \
# 0  deit_base  0.848697           0.337385  0.336739     0.809099
#
#    recall_macro  recall_weighted  precision_macro  precision_weighted  \
# 0      0.337385         0.848697         0.451365            0.812964
#
#    roc_auc_ovr_macro
# 0           0.847855
# Saved classification report to: /kaggle/working/evaluation_on_test_set/deit_base_classification_report.csv
# Saved test predictions to: /kaggle/working/evaluation_on_test_set/deit_base_test_predictions.csv
# Saved confusion matrix plot to: /kaggle/working/evaluation_on_test_set/deit_base_confusion_matrix.png
# Saved normalized confusion matrix plot to: /kaggle/working/evaluation_on_test_set/deit_base_normalized_confusion_matrix.png
# Saved per-class score plot to: /kaggle/working/evaluation_on_test_set/deit_base_per_class_scores.png
# Saved ROC-AUC curve to: /kaggle/working/evaluation_on_test_set/deit_base_roc_auc_curve.png
#
# All model evaluation completed.
# Saved summary to: /kaggle/working/evaluation_on_test_set/all_models_test_evaluation_summary.csv
#   model_name  accuracy  balanced_accuracy  f1_macro  f1_weighted  \
# 0  deit_base  0.848697           0.337385  0.336739     0.809099
#
#    recall_macro  recall_weighted  precision_macro  precision_weighted  \
# 0      0.337385         0.848697         0.451365            0.812964
#
#    roc_auc_ovr_macro
# 0           0.847855
