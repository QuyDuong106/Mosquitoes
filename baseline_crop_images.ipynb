# %% [markdown]
# # Lib

# %%
# !pip uninstall -y torch torchvision torchaudio

# !pip install --pre torch torchvision torchaudio \
  --index-url https://download.pytorch.org/whl/nightly/cu128
# Out:
# Found existing installation: torch 2.10.0+cu128
# Uninstalling torch-2.10.0+cu128:
#   Successfully uninstalled torch-2.10.0+cu128
# Found existing installation: torchvision 0.25.0+cu128
# Uninstalling torchvision-0.25.0+cu128:
#   Successfully uninstalled torchvision-0.25.0+cu128
# Found existing installation: torchaudio 2.10.0+cu128
# Uninstalling torchaudio-2.10.0+cu128:
#   Successfully uninstalled torchaudio-2.10.0+cu128
# Looking in indexes: https://download.pytorch.org/whl/nightly/cu128
# Collecting torch
#   Downloading https://download-r2.pytorch.org/whl/nightly/cu128/torch-2.12.0.dev20260408%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (31 kB)
# Collecting torchvision
#   Downloading https://download-r2.pytorch.org/whl/nightly/cu128/torchvision-0.27.0.dev20260407%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting torchaudio
#   Downloading https://download-r2.pytorch.org/whl/nightly/cu128/torchaudio-2.11.0.dev20260407%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.9 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2026.2.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch) (12.9.4)
# Collecting nvidia-cudnn-cu12==9.20.0.48 (from torch)
#   Downloading https://pypi.nvidia.com/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.20.0.48-py3-none-manylinux_2_27_x86_64.whl (657.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 657.9/657.9 MB 52.0 MB/s eta 0:00:00
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Collecting nvidia-nccl-cu12==2.29.7 (from torch)
#   Downloading https://pypi.nvidia.com/nvidia-nccl-cu12/nvidia_nccl_cu12-2.29.7-py3-none-manylinux_2_18_x86_64.whl (293.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.6/293.6 MB 75.8 MB/s eta 0:00:00
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.5)
# Collecting triton==3.7.0+git282c8251 (from torch)
#   Downloading https://download-r2.pytorch.org/whl/nightly/triton-3.7.0%2Bgit282c8251-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.90)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Collecting torch
#   Downloading https://download-r2.pytorch.org/whl/nightly/cu128/torch-2.12.0.dev20260407%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (31 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Collecting triton==3.7.0+git9c288bc5 (from torch)
#   Downloading https://download-r2.pytorch.org/whl/nightly/triton-3.7.0%2Bgit9c288bc5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch) (1.3.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Downloading https://download-r2.pytorch.org/whl/nightly/cu128/torchvision-0.27.0.dev20260407%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 100.4 MB/s eta 0:00:00
# Downloading https://download-r2.pytorch.org/whl/nightly/cu128/torch-2.12.0.dev20260407%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl (832.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 832.5/832.5 MB 1.5 MB/s eta 0:00:00
# Downloading https://download-r2.pytorch.org/whl/nightly/triton-3.7.0%2Bgit9c288bc5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (292.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.2/292.2 MB 1.5 MB/s eta 0:00:00
# Downloading https://download-r2.pytorch.org/whl/nightly/cu128/torchaudio-2.11.0.dev20260407%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 67.1 MB/s eta 0:00:00
# Installing collected packages: torchaudio, triton, nvidia-nccl-cu12, nvidia-cudnn-cu12, torch, torchvision
#   Attempting uninstall: triton
#     Found existing installation: triton 3.6.0
#     Uninstalling triton-3.6.0:
#       Successfully uninstalled triton-3.6.0
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.27.5
#     Uninstalling nvidia-nccl-cu12-2.27.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.27.5
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.10.2.21
#     Uninstalling nvidia-cudnn-cu12-9.10.2.21:
#       Successfully uninstalled nvidia-cudnn-cu12-9.10.2.21
# Successfully installed nvidia-cudnn-cu12-9.20.0.48 nvidia-nccl-cu12-2.29.7 torch-2.12.0.dev20260407+cu128 torchaudio-2.11.0.dev20260407+cu128 torchvision-0.27.0.dev20260407+cu128 triton-3.7.0+git9c288bc5

# %%
import os
from pathlib import Path
from PIL import Image
import numpy as np


import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import torch
import torch.nn as nn
import torch.distributed as dist

from torch.nn.parallel import DistributedDataParallel as DDP
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.distributed import DistributedSampler
from torchvision import transforms, models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import resample


from sklearn.metrics import (
    accuracy_score,
    precision_recall_fscore_support,
    classification_report,
    confusion_matrix,
    roc_auc_score,
    roc_curve,
    auc
)
from sklearn.preprocessing import label_binarize

# %%
import torchvision
print(torchvision.__version__)
# Out:
# 0.27.0.dev20260407+cu128

# %%
import torch

print("torch:", torch.__version__)
print("torch cuda:", torch.version.cuda)
print("cuda available:", torch.cuda.is_available())
print("gpu:", torch.cuda.get_device_name(0))
print("capability:", torch.cuda.get_device_capability(0))
# Out:
# torch: 2.12.0.dev20260407+cu128
# torch cuda: 12.8
# cuda available: True
# gpu: Tesla T4
# capability: (7, 5)

# %% [markdown]
# # Data

# %%
dataset_dir = Path("/kaggle/input/datasets/duongnguyenquy/mosquitoes-compsci760")

# Image
# image_dir = dataset_dir / "images" / "images"
image_dir = dataset_dir / "image_crop" / "image_crop"

# Annotation
# annotation_path = r"/kaggle/input/datasets/duongnguyenquy/mosquitoes-compsci760/labels/annotations.csv"
annotation_path = dataset_dir /"image_crop"/"image_crop"/ "cropped_annotations.csv"

annotations = pd.read_csv(annotation_path)
annotations.head()
# Out:
#                  img_fName  img_w  img_h  bbx_xtl  bbx_ytl  bbx_xbr  bbx_ybr  \
# 0  train_00000_0_crop.jpeg    340    550        0        0      340      550
# 1  train_00001_1_crop.jpeg   1050   1093        0        0     1050     1093
# 2  train_00002_2_crop.jpeg    439    750        0        0      439      750
# 3  train_00003_3_crop.jpeg    417    462        0        0      417      462
# 4  train_00004_4_crop.jpeg    568    776        0        0      568      776
#
#   class_label      source_image
# 0  albopictus  train_00000.jpeg
# 1  albopictus  train_00001.jpeg
# 2  albopictus  train_00002.jpeg
# 3  albopictus  train_00003.jpeg
# 4       culex  train_00004.jpeg

# %%
annotations.columns
# Out:
# Index(['img_fName', 'img_w', 'img_h', 'bbx_xtl', 'bbx_ytl', 'bbx_xbr',
#        'bbx_ybr', 'class_label', 'source_image'],
#       dtype='object')

# %%
annotations.shape
# Out:
# (10357, 9)

# %%
image_df = (
    annotations.groupby("img_fName")["class_label"]
    .agg(lambda x: x.mode().iloc[0])
    .reset_index()
)

print("Number of images:", len(image_df))
print(image_df["class_label"].value_counts())
image_df.head()
# Out:
# Number of images: 10357
# class_label
# albopictus            4612
# culex                 4563
# culiseta               622
# japonicus-koreicus     429
# anopheles               84
# aegypti                 47
# Name: count, dtype: int64
#                  img_fName class_label
# 0  train_00000_0_crop.jpeg  albopictus
# 1  train_00001_1_crop.jpeg  albopictus
# 2  train_00002_2_crop.jpeg  albopictus
# 3  train_00003_3_crop.jpeg  albopictus
# 4  train_00004_4_crop.jpeg       culex

# %%
# number of images to show
num_images = 6

sample_df = annotations.sample(num_images, random_state=760)

plt.figure(figsize=(12, 8))

for i, (_, row) in enumerate(sample_df.iterrows()):
    img_path = image_dir / row["img_fName"]   # adjust column name if needed
    
    img = Image.open(img_path)

    plt.subplot(2, 3, i + 1)
    plt.imshow(img)
    plt.title(f"Label: {row['class_label']}")
    plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Preprocessing

# %%
label_encoder = LabelEncoder()
image_df["label_id"] = label_encoder.fit_transform(image_df["class_label"])

class_names = list(label_encoder.classes_)
num_classes = len(class_names)

print(class_names)
print("Num classes:", num_classes)
# Out:
# ['aegypti', 'albopictus', 'anopheles', 'culex', 'culiseta', 'japonicus-koreicus']
# Num classes: 6

# %% [markdown]
# # Split

# %%
def oversample_dataframe(df, label_col, random_state=42):
    max_count = df[label_col].value_counts().max()
    balanced = []

    for label in df[label_col].unique():
        subset = df[df[label_col] == label]
        upsampled = resample(
            subset,
            replace=True,
            n_samples=max_count,
            random_state=random_state
        )
        balanced.append(upsampled)

    return pd.concat(balanced).sample(frac=1, random_state=random_state).reset_index(drop=True)


from imblearn.over_sampling import ADASYN
import pandas as pd

def adasyn_resample_dataframe(df, label_col, random_state=42):
    """
    Resample a DataFrame using ADASYN to balance classes.
    
    Parameters:
        df (pd.DataFrame): Input DataFrame
        label_col (str): Name of the target column
        random_state (int): Random seed for reproducibility
        
    Returns:
        pd.DataFrame: Balanced DataFrame with synthetic samples
    """
    X = df.drop(columns=[label_col])
    y = df[label_col]

    # Initialize ADASYN
    adasyn = ADASYN(random_state=random_state)

    # Fit and resample
    X_res, y_res = adasyn.fit_resample(X, y)

    # Reconstruct DataFrame
    df_resampled = pd.DataFrame(X_res, columns=X.columns)
    df_resampled[label_col] = y_res

    # Shuffle the DataFrame
    return df_resampled.sample(frac=1, random_state=random_state).reset_index(drop=True)

# %%
train_df, temp_df = train_test_split(
    image_df,
    test_size=0.30,
    random_state=42,
    stratify=image_df["label_id"]
)

val_df, test_df = train_test_split(
    temp_df,
    test_size=0.50,
    random_state=42,
    stratify=temp_df["label_id"]
)


#Oversampling method
# train_df = oversample_dataframe(train_df, label_col="label_id")

print("Train:", len(train_df))
print("Val:", len(val_df))
print("Test:", len(test_df))

print("\nTrain label distribution after oversampling:")
print(train_df["label_id"].value_counts())
# Out:
# Train: 7249
# Val: 1554
# Test: 1554
#
# Train label distribution after oversampling:
# label_id
# 1    3228
# 3    3194
# 4     435
# 5     300
# 2      59
# 0      33
# Name: count, dtype: int64

# %%
# train_subset_df = train_df.groupby("label_id", group_keys=False).apply(
#     lambda x: x.sample(min(len(x), 50), random_state=42)
# ).reset_index(drop=True)

# val_subset_df = val_df.groupby("label_id", group_keys=False).apply(
#     lambda x: x.sample(min(len(x), 20), random_state=42)
# ).reset_index(drop=True)

# test_subset_df = test_df.groupby("label_id", group_keys=False).apply(
#     lambda x: x.sample(min(len(x), 20), random_state=42)
# ).reset_index(drop=True)

# print("Subset Train:", len(train_subset_df))
# print("Subset Val:", len(val_subset_df))
# print("Subset Test:", len(test_subset_df))

# %% [markdown]
# # Modeling

# %% [markdown]
# ## ENV

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using:", device)

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
    print("Capability:", torch.cuda.get_device_capability(0))
# Out:
# Using: cuda
# GPU: Tesla T4
# Capability: (7, 5)

# %% [markdown]
# ## Transform

# %%
image_size = 224

# train_transform = transforms.Compose([
#     transforms.Resize((image_size, image_size)),
#     transforms.RandomResizedCrop(image_size, scale=(0.8, 1.0), ratio=(0.75, 1.33)),
#     transforms.RandomHorizontalFlip(p=0.5),
#     transforms.RandomVerticalFlip(p=0.2),
#     transforms.RandomRotation(degrees=15),
#     transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1),
#     transforms.RandomGrayscale(p=0.1),
#     transforms.GaussianBlur(kernel_size=(3, 5), sigma=(0.1, 2.0)),
#     transforms.ToTensor(),
#     transforms.Normalize(mean=[0.485, 0.456, 0.406],
#                          std=[0.229, 0.224, 0.225])
# ])

# eval_transform = transforms.Compose([
#     transforms.Resize((image_size, image_size)),
#     transforms.CenterCrop(image_size),
#     transforms.ToTensor(),
#     transforms.Normalize(mean=[0.485, 0.456, 0.406],
#                          std=[0.229, 0.224, 0.225])
# ])


train_transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

eval_transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %% [markdown]
# ## Dataset

# %%
class MosquitoImageDataset(Dataset):
    def __init__(self, df, image_dir, transform=None):
        self.df = df.reset_index(drop=True)
        self.image_dir = image_dir
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        image_path = self.image_dir / row["img_fName"]
        image = Image.open(image_path).convert("RGB")
        label = int(row["label_id"])

        if self.transform:
            image = self.transform(image)

        return image, label

# %%
train_dataset = MosquitoImageDataset(train_df, image_dir, transform=train_transform)
val_dataset = MosquitoImageDataset(val_df, image_dir, transform=eval_transform)
test_dataset = MosquitoImageDataset(test_df, image_dir, transform=eval_transform)

# Subset
# train_dataset = MosquitoImageDataset(train_subset_df, image_dir, transform=train_transform)
# val_dataset = MosquitoImageDataset(val_subset_df, image_dir, transform=eval_transform)
# test_dataset = MosquitoImageDataset(test_subset_df, image_dir, transform=eval_transform)


train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=2)

# %% [markdown]
# # Baseline modeling
# - Model builder and call out

# %%
import torch
import torch.nn as nn
from torchvision import models
from torchvision.models import (
    ResNet50_Weights,
    ResNet101_Weights,
    EfficientNet_V2_L_Weights,
    EfficientNet_B0_Weights,
    MobileNet_V2_Weights,
)

def build_model(model_name, num_classes, freeze_backbone=True):
    model_name = model_name.lower()

    if model_name == "resnet50":
        model = models.resnet50(weights=ResNet50_Weights.DEFAULT)
        model.fc = nn.Linear(model.fc.in_features, num_classes)
        backbone_params = [p for name, p in model.named_parameters() if not name.startswith("fc.")]

    elif model_name == "resnet101":
        model = models.resnet101(weights=ResNet101_Weights.DEFAULT)
        model.fc = nn.Linear(model.fc.in_features, num_classes)
        backbone_params = [p for name, p in model.named_parameters() if not name.startswith("fc.")]

    elif model_name == "efficientnet_v2_l":
        model = models.efficientnet_v2_l(weights=EfficientNet_V2_L_Weights.DEFAULT)
        model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)
        backbone_params = model.features.parameters()

    elif model_name == "efficientnet_b0":
        model = models.efficientnet_b0(weights=EfficientNet_B0_Weights.DEFAULT)
        model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)
        backbone_params = model.features.parameters()

    elif model_name == "mobilenet_v2":
        model = models.mobilenet_v2(weights=MobileNet_V2_Weights.DEFAULT)
        model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)
        backbone_params = model.features.parameters()

    else:
        raise ValueError(f"Unknown model name: {model_name}")

    if freeze_backbone:
        for param in backbone_params:
            param.requires_grad = False

    return model

# %% [markdown]
# # Training process

# %% [markdown]
# ## Training 1 model builder

# %% [markdown]
# - Number of epochs: 30
# - Lr = 1e-5
# - Transfer learning
# - criterion: CrossEntropy loss
# - optimizer: Adam

# %%
def train_one_model(
    model_name,
    train_loader,
    val_loader,
    num_classes,
    class_names,
    device,
    output_dir,
    num_epochs=30,
    patience=5,
    lr=1e-5,
    freeze_backbone=True
):
    print(f"\n\n==============================")
    print(f"Start training: {model_name}")
    print(f"==============================")

    model = build_model(
        model_name=model_name,
        num_classes=num_classes,
        freeze_backbone=freeze_backbone
    ).to(device)

    criterion = nn.CrossEntropyLoss()

    optimizer = torch.optim.Adam(
        filter(lambda p: p.requires_grad, model.parameters()),
        lr=lr
    )

    best_val_loss = float("inf")
    early_stop_counter = 0
    history = []

    print("Selected device:", device)
    print("Model device:", next(model.parameters()).device)

    for epoch in range(num_epochs):
        print(f"\n===== {model_name} | Epoch {epoch + 1}/{num_epochs} =====")

        # =========================
        # Training
        # =========================
        model.train()

        train_loss = 0.0
        train_correct = 0
        train_total = 0

        for batch_idx, (images, labels) in enumerate(train_loader):
            if batch_idx == 0:
                print("Before move:")
                print("  images device:", images.device)
                print("  labels device:", labels.device)

            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            if batch_idx == 0:
                print("After move:")
                print("  images device:", images.device)
                print("  labels device:", labels.device)
                print("  model device:", next(model.parameters()).device)

                if torch.cuda.is_available():
                    print(
                        "  GPU memory allocated:",
                        torch.cuda.memory_allocated() / 1024**2,
                        "MB"
                    )
                    print(
                        "  GPU memory reserved:",
                        torch.cuda.memory_reserved() / 1024**2,
                        "MB"
                    )

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * images.size(0)

            preds = outputs.argmax(dim=1)
            train_correct += (preds == labels).sum().item()
            train_total += labels.size(0)

            if batch_idx % 10 == 0:
                print(
                    f"[Train] {model_name} | "
                    f"Epoch {epoch + 1} Batch {batch_idx}/{len(train_loader)} | "
                    f"Loss: {loss.item():.4f}"
                )

        train_loss /= train_total
        train_acc = train_correct / train_total

        # =========================
        # Validation
        # =========================
        model.eval()

        val_loss = 0.0
        val_correct = 0
        val_total = 0

        with torch.no_grad():
            for batch_idx, (images, labels) in enumerate(val_loader):
                images = images.to(device, non_blocking=True)
                labels = labels.to(device, non_blocking=True)

                outputs = model(images)
                loss = criterion(outputs, labels)

                val_loss += loss.item() * images.size(0)

                preds = outputs.argmax(dim=1)
                val_correct += (preds == labels).sum().item()
                val_total += labels.size(0)

                if batch_idx % 10 == 0:
                    print(
                        f"[Val] {model_name} | "
                        f"Epoch {epoch + 1} Batch {batch_idx}/{len(val_loader)} | "
                        f"Loss: {loss.item():.4f}"
                    )

        val_loss /= val_total
        val_acc = val_correct / val_total

        print(
            f"{model_name} | Epoch {epoch + 1}/{num_epochs} | "
            f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f} | "
            f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}"
        )

        # =========================
        # Save history
        # =========================
        epoch_result = {
            "model_name": model_name,
            "epoch": epoch + 1,
            "train_loss": train_loss,
            "train_acc": train_acc,
            "val_loss": val_loss,
            "val_acc": val_acc,
            "best_val_loss_so_far": min(best_val_loss, val_loss),
            "early_stop_counter": early_stop_counter,
        }

        history.append(epoch_result)

        history_path = output_dir / f"{model_name}_training_history.csv"
        pd.DataFrame(history).to_csv(history_path, index=False)

        # =========================
        # Save best model
        # =========================
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            early_stop_counter = 0

            best_model_path = output_dir / f"best_{model_name}.pth"

            torch.save({
                "model_name": model_name,
                "epoch": epoch + 1,
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
                "train_loss": train_loss,
                "val_loss": val_loss,
                "train_acc": train_acc,
                "val_acc": val_acc,
                "class_names": class_names,
            }, best_model_path)

            print(f"Best model updated and saved to: {best_model_path}")

        else:
            early_stop_counter += 1
            print(
                f"No improvement. Early stop counter: "
                f"{early_stop_counter}/{patience}"
            )

        # update latest history with new early stop counter
        history[-1]["early_stop_counter"] = early_stop_counter
        pd.DataFrame(history).to_csv(history_path, index=False)

        if early_stop_counter >= patience:
            print(f"Early stopping triggered for {model_name}.")
            break

    # =========================
    # Final benchmark result
    # =========================
    history_df = pd.DataFrame(history)

    best_row = history_df.loc[history_df["val_loss"].idxmin()]

    benchmark_result = {
        "model_name": model_name,
        "best_epoch": int(best_row["epoch"]),
        "best_train_loss": float(best_row["train_loss"]),
        "best_train_acc": float(best_row["train_acc"]),
        "best_val_loss": float(best_row["val_loss"]),
        "best_val_acc": float(best_row["val_acc"]),
        "total_epochs_trained": len(history_df),
        "early_stopped": early_stop_counter >= patience,
        "best_model_path": str(output_dir / f"best_{model_name}.pth"),
        "history_path": str(history_path),
    }

    print(f"Training completed for {model_name}.")
    print("Best validation accuracy:", benchmark_result["best_val_acc"])

    return benchmark_result, history_df

# %%
MODEL_NAMES = [
    # "resnet101",
    # "efficientnet_v2_l"
    "resnet50",
    "efficientnet_b0",
    "mobilenet_v2"
]

# %%
output_dir = Path("/kaggle/working/")
output_dir.mkdir(parents=True, exist_ok=True)


all_benchmarks = []

for model_name in MODEL_NAMES:
    benchmark_result, history_df = train_one_model(
        model_name=model_name,
        train_loader=train_loader,
        val_loader=val_loader,
        num_classes=num_classes,
        class_names=class_names,
        device=device,
        output_dir=output_dir,
        num_epochs=30,
        patience=5,
        lr=1e-5,
        freeze_backbone=True
    )

    all_benchmarks.append(benchmark_result)

# =========================
# Save combined benchmark
# =========================

benchmark_df = pd.DataFrame(all_benchmarks)

benchmark_path = output_dir / "model_benchmark_summary.csv"
benchmark_df.to_csv(benchmark_path, index=False)

print("\nAll model training completed.")
print(f"Benchmark summary saved to: {benchmark_path}")

benchmark_df
# Out:
# ==============================
# Start training: resnet50
# ==============================
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 178MB/s]
# Selected device: cuda
# Model device: cuda:0
#
# ===== resnet50 | Epoch 1/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 108.33447265625 MB
#   GPU memory reserved: 138.0 MB
# [Train] resnet50 | Epoch 1 Batch 0/227 | Loss: 1.7633
# [Train] resnet50 | Epoch 1 Batch 10/227 | Loss: 1.7064
# [Train] resnet50 | Epoch 1 Batch 20/227 | Loss: 1.7352
# [Train] resnet50 | Epoch 1 Batch 30/227 | Loss: 1.6909
# [Train] resnet50 | Epoch 1 Batch 40/227 | Loss: 1.6756
# [Train] resnet50 | Epoch 1 Batch 50/227 | Loss: 1.6159
# [Train] resnet50 | Epoch 1 Batch 60/227 | Loss: 1.6268
# [Train] resnet50 | Epoch 1 Batch 70/227 | Loss: 1.5850
# [Train] resnet50 | Epoch 1 Batch 80/227 | Loss: 1.5862
# [Train] resnet50 | Epoch 1 Batch 90/227 | Loss: 1.5472
# [Train] resnet50 | Epoch 1 Batch 100/227 | Loss: 1.6524
# [Train] resnet50 | Epoch 1 Batch 110/227 | Loss: 1.5685
# [Train] resnet50 | Epoch 1 Batch 120/227 | Loss: 1.5543
# [Train] resnet50 | Epoch 1 Batch 130/227 | Loss: 1.5067
# [Train] resnet50 | Epoch 1 Batch 140/227 | Loss: 1.5506
# [Train] resnet50 | Epoch 1 Batch 150/227 | Loss: 1.5326
# [Train] resnet50 | Epoch 1 Batch 160/227 | Loss: 1.5034
# Best model updated and saved to: /kaggle/working/best_resnet50.pth
#
# ===== resnet50 | Epoch 3/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 124.72802734375 MB
#   GPU memory reserved: 658.0 MB
# [Train] resnet50 | Epoch 3 Batch 0/227 | Loss: 1.2380
# [Train] resnet50 | Epoch 3 Batch 10/227 | Loss: 1.2289
# [Train] resnet50 | Epoch 3 Batch 20/227 | Loss: 1.0952
# [Train] resnet50 | Epoch 3 Batch 30/227 | Loss: 1.1586
# [Train] resnet50 | Epoch 3 Batch 40/227 | Loss: 1.3063
# [Train] resnet50 | Epoch 3 Batch 50/227 | Loss: 1.0920
# [Train] resnet50 | Epoch 3 Batch 60/227 | Loss: 1.1774
# [Train] resnet50 | Epoch 3 Batch 70/227 | Loss: 1.2219
# [Train] resnet50 | Epoch 3 Batch 80/227 | Loss: 1.2095
# [Train] resnet50 | Epoch 3 Batch 90/227 | Loss: 1.2178
# [Train] resnet50 | Epoch 3 Batch 100/227 | Loss: 1.2699
# [Train] resnet50 | Epoch 3 Batch 110/227 | Loss: 1.2632
# [Train] resnet50 | Epoch 3 Batch 120/227 | Loss: 1.2023
# [Train] resnet50 | Epoch 3 Batch 130/227 | Loss: 1.2589
# [Train] resnet50 | Epoch 3 Batch 140/227 | Loss: 1.2600
# [Train] resnet50 | Epoch 3 Batch 150/227 | Loss: 1.2695
# [Train] resnet50 | Epoch 3 Batch 160/227 | Loss: 1.0535
# [Train] resnet50 | Epoch 3 Batch 170/227 | Loss: 1.1031
# [Train] resnet50 | Epoch 3 Batch 180/227 | Loss: 1.2838
# [Train] resnet50 | Epoch 3 Batch 190/227 | Loss: 1.1499
# [Train] resnet50 | Epoch 3 Batch 200/227 | Loss: 1.1402
# [Train] resnet50 | Epoch 3 Batch 210/227 | Loss: 1.1099
# [Train] resnet50 | Epoch 3 Batch 220/227 | Loss: 1.1635
# [Val] resnet50 | Epoch 3 Batch 0/49 | Loss: 1.2627
# [Val] resnet50 | Epoch 3 Batch 10/49 | Loss: 1.1225
# [Val] resnet50 | Epoch 3 Batch 20/49 | Loss: 1.1646
# [Val] resnet50 | Epoch 3 Batch 30/49 | Loss: 1.2547
# [Val] resnet50 | Epoch 3 Batch 40/49 | Loss: 1.0802
# resnet50 | Epoch 3/30 | Train Loss: 1.2009 | Train Acc: 0.5804 | Val Loss: 1.1810 | Val Acc: 0.6094
# Best model updated and saved to: /kaggle/working/best_resnet50.pth
#
# ===== resnet50 | Epoch 4/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 124.72802734375 MB
#   GPU memory reserved: 658.0 MB
# [Train] resnet50 | Epoch 4 Batch 0/227 | Loss: 1.1259
# [Train] resnet50 | Epoch 4 Batch 10/227 | Loss: 1.2471
# [Train] resnet50 | Epoch 4 Batch 20/227 | Loss: 1.2208
# [Train] resnet50 | Epoch 4 Batch 30/227 | Loss: 1.2098
# [Train] resnet50 | Epoch 4 Batch 40/227 | Loss: 1.2757
# [Train] resnet50 | Epoch 4 Batch 50/227 | Loss: 1.0789
# [Train] resnet50 | Epoch 4 Batch 60/227 | Loss: 0.9938
# [Train] resnet50 | Epoch 4 Batch 70/227 | Loss: 1.2136
# [Train] resnet50 | Epoch 4 Batch 80/227 | Loss: 1.1663
# [Train] resnet50 | Epoch 4 Batch 90/227 | Loss: 0.9540
# [Train] resnet50 | Epoch 4 Batch 100/227 | Loss: 1.1696
# [Train] resnet50 | Epoch 4 Batch 110/227 | Loss: 1.2365
# [Train] resnet50 | Epoch 4 Batch 120/227 | Loss: 1.1338
# [Train] resnet50 | Epoch 4 Batch 130/227 | Loss: 1.1236
# [Train] resnet50 | Epoch 4 Batch 140/227 | Loss: 1.0600
# [Train] resnet50 | Epoch 4 Batch 150/227 | Loss: 1.2351
# [Train] resnet50 | Epoch 4 Batch 160/227 | Loss: 1.1023
# [Train] resnet50 | Epoch 4 Batch 170/227 | Loss: 0.9917
# [Train] resnet50 | Epoch 4 Batch 180/227 | Loss: 0.9804
# [Train] resnet50 | Epoch 4 Batch 190/227 | Loss: 1.1119
# [Train] resnet50 | Epoch 4 Batch 200/227 | Loss: 1.1890
# [Train] resnet50 | Epoch 4 Batch 210/227 | Loss: 1.2713
# [Train] resnet50 | Epoch 4 Batch 220/227 | Loss: 1.0573
# [Val] resnet50 | Epoch 4 Batch 0/49 | Loss: 1.2220
# [Val] resnet50 | Epoch 4 Batch 10/49 | Loss: 1.0662
# [Val] resnet50 | Epoch 4 Batch 20/49 | Loss: 1.0923
# [Val] resnet50 | Epoch 4 Batch 30/49 | Loss: 1.1938
# [Val] resnet50 | Epoch 4 Batch 40/49 | Loss: 0.9929
# resnet50 | Epoch 4/30 | Train Loss: 1.1346 | Train Acc: 0.6484 | Val Loss: 1.1188 | Val Acc: 0.6583
# Best model updated and saved to: /kaggle/working/best_resnet50.pth
#
# ===== resnet50 | Epoch 5/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 124.72802734375 MB
#   GPU memory reserved: 658.0 MB
# [Train] resnet50 | Epoch 5 Batch 0/227 | Loss: 0.9863
# [Train] resnet50 | Epoch 5 Batch 10/227 | Loss: 0.9796
# [Train] resnet50 | Epoch 5 Batch 20/227 | Loss: 1.0134
# [Train] resnet50 | Epoch 5 Batch 30/227 | Loss: 0.9622
# [Train] resnet50 | Epoch 5 Batch 40/227 | Loss: 1.1408
# [Train] resnet50 | Epoch 5 Batch 50/227 | Loss: 1.0809
# [Train] resnet50 | Epoch 5 Batch 60/227 | Loss: 1.2970
# [Train] resnet50 | Epoch 5 Batch 70/227 | Loss: 1.1560
# [Train] resnet50 | Epoch 5 Batch 80/227 | Loss: 1.3324
# [Train] resnet50 | Epoch 5 Batch 90/227 | Loss: 1.0303
# [Train] resnet50 | Epoch 5 Batch 100/227 | Loss: 1.2285
# [Train] resnet50 | Epoch 5 Batch 110/227 | Loss: 0.9358
# [Train] resnet50 | Epoch 5 Batch 120/227 | Loss: 1.1873
# [Train] resnet50 | Epoch 5 Batch 130/227 | Loss: 0.9385
# [Train] resnet50 | Epoch 5 Batch 140/227 | Loss: 1.1368
# [Train] resnet50 | Epoch 5 Batch 150/227 | Loss: 1.1531
# [Train] resnet50 | Epoch 5 Batch 160/227 | Loss: 1.0071
# [Train] resnet50 | Epoch 5 Batch 170/227 | Loss: 1.0579
# [Train] resnet50 | Epoch 5 Batch 180/227 | Loss: 1.1066
# [Train] resnet50 | Epoch 5 Batch 190/227 | Loss: 0.9923
# [Train] resnet50 | Epoch 5 Batch 200/227 | Loss: 1.0117
# [Train] resnet50 | Epoch 5 Batch 210/227 | Loss: 0.9552
# [Train] resnet50 | Epoch 5 Batch 220/227 | Loss: 1.0085
# [Val] resnet50 | Epoch 5 Batch 0/49 | Loss: 1.1800
# [Val] resnet50 | Epoch 5 Batch 10/49 | Loss: 1.0185
# [Val] resnet50 | Epoch 5 Batch 20/49 | Loss: 1.0506
# [Val] resnet50 | Epoch 5 Batch 30/49 | Loss: 1.1606
# [Val] resnet50 | Epoch 5 Batch 40/49 | Loss: 0.9422
# resnet50 | Epoch 5/30 | Train Loss: 1.0817 | Train Acc: 0.7000 | Val Loss: 1.0808 | Val Acc: 0.6969
# Best model updated and saved to: /kaggle/working/best_resnet50.pth
#
# ===== resnet50 | Epoch 6/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 124.72802734375 MB
#   GPU memory reserved: 658.0 MB
# [Train] resnet50 | Epoch 6 Batch 0/227 | Loss: 1.0231
# [Train] resnet50 | Epoch 6 Batch 10/227 | Loss: 0.9542
# [Train] resnet50 | Epoch 6 Batch 20/227 | Loss: 1.1432
# [Train] resnet50 | Epoch 6 Batch 30/227 | Loss: 1.0796
# [Train] resnet50 | Epoch 6 Batch 40/227 | Loss: 1.2193
# [Train] resnet50 | Epoch 6 Batch 50/227 | Loss: 0.9980
# [Train] resnet50 | Epoch 6 Batch 60/227 | Loss: 1.2242
# [Train] resnet50 | Epoch 6 Batch 70/227 | Loss: 0.8321
# [Train] resnet50 | Epoch 6 Batch 80/227 | Loss: 1.1121
# [Train] resnet50 | Epoch 6 Batch 90/227 | Loss: 0.9141
# [Train] resnet50 | Epoch 6 Batch 100/227 | Loss: 0.9515
# [Train] resnet50 | Epoch 6 Batch 110/227 | Loss: 1.0946
# [Train] resnet50 | Epoch 6 Batch 120/227 | Loss: 0.9018
# [Train] resnet50 | Epoch 6 Batch 130/227 | Loss: 1.0049
# [Train] resnet50 | Epoch 6 Batch 140/227 | Loss: 1.1592
# [Train] resnet50 | Epoch 6 Batch 150/227 | Loss: 1.1238
# [Train] resnet50 | Epoch 6 Batch 160/227 | Loss: 1.0848
# [Train] resnet50 | Epoch 6 Batch 170/227 | Loss: 0.9792
# [Train] resnet50 | Epoch 6 Batch 180/227 | Loss: 0.9385
# [Train] resnet50 | Epoch 6 Batch 190/227 | Loss: 1.1795
# [Train] resnet50 | Epoch 6 Batch 200/227 | Loss: 0.9382
# [Train] resnet50 | Epoch 6 Batch 210/227 | Loss: 1.0933
# [Train] resnet50 | Epoch 6 Batch 220/227 | Loss: 1.0463
# [Val] resnet50 | Epoch 6 Batch 0/49 | Loss: 1.1483
# [Val] resnet50 | Epoch 6 Batch 10/49 | Loss: 0.9952
# [Val] resnet50 | Epoch 6 Batch 20/49 | Loss: 1.0153
# [Val] resnet50 | Epoch 6 Batch 30/49 | Loss: 1.1410
# [Val] resnet50 | Epoch 6 Batch 40/49 | Loss: 0.9015
# resnet50 | Epoch 6/30 | Train Loss: 1.0459 | Train Acc: 0.7242 | Val Loss: 1.0490 | Val Acc: 0.7194
# Best model updated and saved to: /kaggle/working/best_resnet50.pth
#
# ===== resnet50 | Epoch 7/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 124.72802734375 MB
#   GPU memory reserved: 658.0 MB
# [Train] resnet50 | Epoch
# Best model updated and saved to: /kaggle/working/best_resnet50.pth
#
# ===== resnet50 | Epoch 10/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 124.72802734375 MB
#   GPU memory reserved: 658.0 MB
# [Train] resnet50 | Epoch 10 Batch 0/227 | Loss: 1.2201
# [Train] resnet50 | Epoch 10 Batch 10/227 | Loss: 0.9389
# [Train] resnet50 | Epoch 10 Batch 20/227 | Loss: 1.2549
# [Train] resnet50 | Epoch 10 Batch 30/227 | Loss: 1.1145
# [Train] resnet50 | Epoch 10 Batch 40/227 | Loss: 0.9485
# [Train] resnet50 | Epoch 10 Batch 50/227 | Loss: 0.8819
# [Train] resnet50 | Epoch 10 Batch 60/227 | Loss: 0.7576
# [Train] resnet50 | Epoch 10 Batch 70/227 | Loss: 1.1374
# [Train] resnet50 | Epoch 10 Batch 80/227 | Loss: 1.1664
# [Train] resnet50 | Epoch 10 Batch 90/227 | Loss: 0.8855
# [Train] resnet50 | Epoch 10 Batch 100/227 | Loss: 1.0636
# [Train] resnet50 | Epoch 10 Batch 110/227 | Loss: 1.0547
# [Train] resnet50 | Epoch 10 Batch 120/227 | Loss: 0.7247
# [Train] resnet50 | Epoch 10 Batch 130/227 | Loss: 0.8690
# [Train] resnet50 | Epoch 10 Batch 140/227 | Loss: 0.9279
# [Train] resnet50 | Epoch 10 Batch 150/227 | Loss: 1.0843
# [Train] resnet50 | Epoch 10 Batch 160/227 | Loss: 1.1385
# [Train] resnet50 | Epoch 10 Batch 170/227 | Loss: 0.7834
# [Train] resnet50 | Epoch 10 Batch 180/227 | Loss: 0.9732
# [Train] resnet50 | Epoch 10 Batch 190/227 | Loss: 1.0593
# [Train] resnet50 | Epoch 10 Batch 200/227 | Loss: 0.8471
# [Train] resnet50 | Epoch 10 Batch 210/227 | Loss: 0.8988
# [Train] resnet50 | Epoch 10 Batch 220/227 | Loss: 1.0526
# [Val] resnet50 | Epoch 10 Batch 0/49 | Loss: 1.0834
# [Val] resnet50 | Epoch 10 Batch 10/49 | Loss: 0.9069
# [Val] resnet50 | Epoch 10 Batch 20/49 | Loss: 0.9186
# [Val] resnet50 | Epoch 10 Batch 30/49 | Loss: 1.0604
# [Val] resnet50 | Epoch 10 Batch 40/49 | Loss: 0.7801
# resnet50 | Epoch 10/30 | Train Loss: 0.9524 | Train Acc: 0.7691 | Val Loss: 0.9625 | Val Acc: 0.7606
# Best model updated and saved to: /kaggle/working/best_resnet50.pth
#
# ===== resnet50 | Epoch 11/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 124.72802734375 MB
#   GPU memory reserved: 658.0 MB
# [Train] resnet50 | Epoch 11 Batch 0/227 | Loss: 0.8509
# [Train] resnet50 | Epoch 11 Batch 10/227 | Loss: 0.7203
# [Train] resnet50 | Epoch 11 Batch 20/227 | Loss: 1.0236
# [Train] resnet50 | Epoch 11 Batch 30/227 | Loss: 0.8021
# [Train] resnet50 | Epoch 11 Batch 40/227 | Loss: 0.9893
# [Train] resnet50 | Epoch 11 Batch 50/227 | Loss: 1.0459
# [Train] resnet50 | Epoch 11 Batch 60/227 | Loss: 1.0233
# [Train] resnet50 | Epoch 11 Batch 70/227 | Loss: 0.7346
# [Train] resnet50 | Epoch 11 Batch 80/227 | Loss: 0.8408
# [Train] resnet50 | Epoch 11 Batch 90/227 | Loss: 0.9144
# [Train] resnet50 | Epoch 11 Batch 100/227 | Loss: 0.8925
# [Val] resnet50 | Epoch 19 Batch 0/49 | Loss: 0.9637
# [Val] resnet50 | Epoch 19 Batch 10/49 | Loss: 0.8114
# [Val] resnet50 | Epoch 19 Batch 20/49 | Loss: 0.7910
# [Val] resnet50 | Epoch 19 Batch 30/49 | Loss: 0.9678
# [Val] resnet50 | Epoch 19 Batch 40/49 | Loss: 0.6654
# resnet50 | Epoch 19/30 | Train Loss: 0.8310 | Train Acc: 0.7894 | Val Loss: 0.8528 | Val Acc: 0.7851
# Best model updated and saved to: /kaggle/working/best_resnet50.pth
#
# ===== resnet50 | Epoch 20/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 124.72802734375 MB
#   GPU memory reserved: 658.0 MB
# [Train] resnet50 | Epoch 20 Batch 0/227 | Loss: 0.7122
# [Train] resnet50 | Epoch 20 Batch 10/227 | Loss: 0.6570
# [Train] resnet50 | Epoch 20 Batch 20/227 | Loss: 0.7262
# [Train] resnet50 | Epoch 20 Batch 30/227 | Loss: 0.9261
# [Train] resnet50 | Epoch 20 Batch 40/227 | Loss: 0.8204
# [Train] resnet50 | Epoch 20 Batch 50/227 | Loss: 0.8806
# [Train] resnet50 | Epoch 20 Batch 60/227 | Loss: 0.6048
# [Train] resnet50 | Epoch 20 Batch 70/227 | Loss: 0.7527
# [Train] resnet50 | Epoch 20 Batch 80/227 | Loss: 0.7586
# [Train] resnet50 | Epoch 20 Batch 90/227 | Loss: 0.8288
# [Train] resnet50 | Epoch 20 Batch 100/227 | Loss: 0.6384
# [Train] resnet50 | Epoch 20 Batch 110/227 | Loss: 0.8078
# [Train] resnet50 | Epoch 20 Batch 120/227 | Loss: 1.1037
# [Train] resnet50 | Epoch 20 Batch 130/227 | Loss: 0.7331
# [Train] resnet50 | Epoch 20 Batch 140/227 | Loss: 0.8708
# [Train] resnet50 | Epoch 20 Batch 150/227 | Loss: 1.0278
# [Train] resnet50 | Epoch 20 Batch 160/227 | Loss: 0.6441
# [Train] resnet50 | Epoch 20 Batch 170/227 | Loss: 1.2908
# [Train] resnet50 | Epoch 20 Batch 180/227 | Loss: 0.9199
# [Train] resnet50 | Epoch 20 Batch 190/227 | Loss: 0.6678
# [Train] resnet50 | Epoch 20 Batch 200/227 | Loss: 0.5630
# [Train] resnet50 | Epoch 20 Batch 210/227 | Loss: 0.6607
# [Train] resnet50 | Epoch 20 Batch 220/227 | Loss: 0.6402
# [Val] resnet50 | Epoch 20 Batch 0/49 | Loss: 0.9372
# [Val] resnet50 | Epoch 20 Batch 10/49 | Loss: 0.8142
# [Val] resnet50 | Epoch 20 Batch 20/49 | Loss: 0.7951
# [Val] resnet50 | Epoch 20 Batch 30/49 | Loss: 0.9535
# [Val] resnet50 | Epoch 20 Batch 40/49 | Loss: 0.6675
# resnet50 | Epoch 20/30 | Train Loss: 0.8258 | Train Acc: 0.7943 | Val Loss: 0.8521 | Val Acc: 0.7851
# Best model updated and saved to: /kaggle/working/best_resnet50.pth
#
# ===== resnet50 | Epoch 21/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 124.72802734375 MB
#   GPU memory reserved: 658.0 MB
# [Train] resnet50 | Epoch 21 Batch 0/227 | Loss: 0.7924
# [Train] resnet50 | Epoch 21 Batch 10/227 | Loss: 0.8885
# [Train] resnet50 | Epoch 21 Batch 20/227 | Loss: 0.6970
# [Train] resnet50 | Epoch 21 Batch 30/227 | Loss: 1.1758
# [Train] resnet50 | Epoch 21 Batch 40/227 | Loss: 0.7540
# [Train] resnet50 | Epoch 21 Batch 50/227 | Loss: 0.8848
# [Train] resnet50 | Epoch 21 Batch 60/227 | Loss: 0.9812
# [Train] resnet50 | Epoch 21 Batch 70/227 | Loss: 0.7271
# [Train] resnet50 | Epoch 21 Batch 80/227 | Loss: 0.8107
# [Train] resnet50 | Epoch 21 Batch 90/227 | Loss: 0.9873
# [Train] resnet50 | Epoch 21 Batch 100/227 | Loss: 0.8056
# [Train] resnet50 | Epoch 21 Batch 110/227 | Loss: 0.5958
# [Train] resnet50 | Epoch 21 Batch 120/227 | Loss: 0.9445
# [Train] resnet50 | Epoch 21 Batch 130/227 | Loss: 0.8286
# [Train] resnet50 | Epoch 21 Batch 140/227 | Loss: 0.8484
# [Train] resnet50 | Epoch 21 Batch 150/227 | Loss: 1.3404
# [Train] resnet50 | Epoch 21 Batch 160/227 | Loss: 0.8425
# [Train] resnet50 | Epoch 21 Batch 170/227 | Loss: 0.7134
# [Train] resnet50 | Epoch 21 Batch 180/227 | Loss: 0.6296
# [Train] resnet50 | Epoch 21 Batch 190/227 | Loss: 0.8530
# [Train] resnet50 | Epoch 21 Batch 200/227 | Loss: 0.6929
# [Train] resnet50 | Epoch 21 Batch 210/227 | Loss: 0.8716
# [Train] resnet50 | Epoch 21 Batch 220/227 | Loss: 0.8440
# [Val] resnet50 | Epoch 21 Batch 0/49 | Loss: 0.9238
# [Val] resnet50 | Epoch 21 Batch 10/49 | Loss: 0.7880
# [Val] resnet50 | Epoch 21 Batch 20/49 | Loss: 0.7670
# [Val] resnet50 | Epoch 21 Batch 30/49 | Loss: 0.9551
# [Val] resnet50 | Epoch 21 Batch 40/49 | Loss: 0.6613
# resnet50 | Epoch 21/30 | Train Loss: 0.8161 | Train Acc: 0.7945 | Val Loss: 0.8328 | Val Acc: 0.7883
# Best model updated and saved to: /kaggle/working/best_resnet50.pth
#
# ===== resnet50 | Epoch 22/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 124.72802734375 MB
#   GPU memory reserved: 658.0 MB
# [Train] resnet50 | Epoch 22 Batch 0/227 | Loss: 0.5678
# [Train] resnet50 | Epoch 22 Batch 10/227 | Loss: 0.5819
# [Train] resnet50 | Epoch 22 Batch 20/227 | Loss: 0.8545
# [Train] resnet50 | Epoch 22 Batch 30/227 | Loss: 0.8797
# [Train] resnet50 | Epoch 22 Batch 40/227 | Loss: 0.8718
# [Train] resnet50 | Epoch 22 Batch 50/227 | Loss: 0.7002
# [Train] resnet50 | Epoch 22 Batch 60/227 | Loss: 0.8425
# [Train] resnet50 | Epoch 22 Batch 70/227 | Loss: 0.7936
# [Train] resnet50 | Epoch 22 Batch 80/227 | Loss: 0.8447
# [Train] resnet50 | Epoch 22 Batch 90/227 | Loss: 0.7908
# [Train] resnet50 | Epoch 22 Batch 100/227 | Loss: 0.6460
# [Train] resnet50 | Epoch 22 Batch 110/227 | Loss: 0.8335
# [Train] resnet50 | Epoch 22 Batch 120/227 | Loss: 0.7152
# [Train] resnet50 | Epoch 22 Batch 130/227 | Loss: 0.8014
# [Train] resnet50 | Epoch 22 Batch 140/227 | Loss: 0.9880
# [Train] resnet50 | Epoch 22 Batch 150/227 | Loss: 1.1566
# [Train] resnet50 | Epoch 22 Batch 160/227 | Loss: 0.8502
# Best model updated and saved to: /kaggle/working/best_resnet50.pth
#
# ===== resnet50 | Epoch 24/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 124.72802734375 MB
#   GPU memory reserved: 658.0 MB
# [Train] resnet50 | Epoch 24 Batch 0/227 | Loss: 0.6763
# [Train] resnet50 | Epoch 24 Batch 10/227 | Loss: 0.6956
# [Train] resnet50 | Epoch 24 Batch 20/227 | Loss: 0.6541
# [Train] resnet50 | Epoch 24 Batch 30/227 | Loss: 0.5919
# [Train] resnet50 | Epoch 24 Batch 40/227 | Loss: 1.0066
# [Train] resnet50 | Epoch 24 Batch 50/227 | Loss: 1.1532
# [Train] resnet50 | Epoch 24 Batch 60/227 | Loss: 0.8005
# [Train] resnet50 | Epoch 24 Batch 70/227 | Loss: 0.9622
# [Train] resnet50 | Epoch 24 Batch 80/227 | Loss: 0.5995
# [Train] resnet50 | Epoch 24 Batch 90/227 | Loss: 0.7670
# [Train] resnet50 | Epoch 24 Batch 100/227 | Loss: 0.6777
# [Train] resnet50 | Epoch 24 Batch 110/227 | Loss: 0.6559
# [Train] resnet50 | Epoch 24 Batch 120/227 | Loss: 0.7051
# [Train] resnet50 | Epoch 24 Batch 130/227 | Loss: 0.7260
# [Train] resnet50 | Epoch 24 Batch 140/227 | Loss: 1.0434
# [Train] resnet50 | Epoch 24 Batch 150/227 | Loss: 0.7467
# [Train] resnet50 | Epoch 24 Batch 160/227 | Loss: 0.8213
# [Train] resnet50 | Epoch 24 Batch 170/227 | Loss: 0.8112
# [Train] resnet50 | Epoch 24 Batch 180/227 | Loss: 0.8206
# [Train] resnet50 | Epoch 24 Batch 190/227 | Loss: 0.8015
# [Train] resnet50 | Epoch 24 Batch 200/227 | Loss: 0.8034
# [Train] resnet50 | Epoch 24 Batch 210/227 | Loss: 0.8088
# [Train] resnet50 | Epoch 24 Batch 220/227 | Loss: 0.7258
# [Val] resnet50 | Epoch 24 Batch 0/49 | Loss: 0.9134
# [Val] resnet50 | Epoch 24 Batch 10/49 | Loss: 0.7747
# [Val] resnet50 | Epoch 24 Batch 20/49 | Loss: 0.7581
# [Val] resnet50 | Epoch 24 Batch 30/49 | Loss: 0.9392
# [Val] resnet50 | Epoch 24 Batch 40/49 | Loss: 0.6330
# resnet50 | Epoch 24/30 | Train Loss: 0.7898 | Train Acc: 0.7990 | Val Loss: 0.8138 | Val Acc: 0.7838
# Best model updated and saved to: /kaggle/working/best_resnet50.pth
#
# ===== resnet50 | Epoch 25/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 124.72802734375 MB
#   GPU memory reserved: 658.0 MB
# [Train] resnet50 | Epoch 25 Batch 0/227 | Loss: 0.6823
# [Train] resnet50 | Epoch 25 Batch 10/227 | Loss: 0.7182
# ...
# Best model updated and saved to: /kaggle/working/best_mobilenet_v2.pth
#
# ===== mobilenet_v2 | Epoch 24/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 43.43701171875 MB
#   GPU memory reserved: 954.0 MB
# [Train] mobilenet_v2 | Epoch 24 Batch 0/227 | Loss: 0.7727
# [Train] mobilenet_v2 | Epoch 24 Batch 10/227 | Loss: 0.9524
# [Train] mobilenet_v2 | Epoch 24 Batch 20/227 | Loss: 0.6961
# [Train] mobilenet_v2 | Epoch 24 Batch 30/227 | Loss: 0.9045
# [Train] mobilenet_v2 | Epoch 24 Batch 40/227 | Loss: 0.9481
# [Train] mobilenet_v2 | Epoch 24 Batch 50/227 | Loss: 0.8890
# [Train] mobilenet_v2 | Epoch 24 Batch 60/227 | Loss: 0.8111
# [Train] mobilenet_v2 | Epoch 24 Batch 70/227 | Loss: 0.7904
# [Train] mobilenet_v2 | Epoch 24 Batch 80/227 | Loss: 0.8583
# [Train] mobilenet_v2 | Epoch 24 Batch 90/227 | Loss: 0.7848
# [Train] mobilenet_v2 | Epoch 24 Batch 100/227 | Loss: 0.5459
# [Train] mobilenet_v2 | Epoch 24 Batch 110/227 | Loss: 0.7777
# [Train] mobilenet_v2 | Epoch 24 Batch 120/227 | Loss: 0.6622
# [Train] mobilenet_v2 | Epoch 24 Batch 130/227 | Loss: 0.7905
# [Train] mobilenet_v2 | Epoch 24 Batch 140/227 | Loss: 0.7191
# [Train] mobilenet_v2 | Epoch 24 Batch 150/227 | Loss: 1.0890
# [Train] mobilenet_v2 | Epoch 24 Batch 160/227 | Loss: 0.8406
# [Train] mobilenet_v2 | Epoch 24 Batch 170/227 | Loss: 0.8066
# [Train] mobilenet_v2 | Epoch 24 Batch 180/227 | Loss: 0.8448
# [Train] mobilenet_v2 | Epoch 24 Batch 190/227 | Loss: 0.5785
# [Train] mobilenet_v2 | Epoch 24 Batch 200/227 | Loss: 0.6036
# [Train] mobilenet_v2 | Epoch 24 Batch 210/227 | Loss: 1.0247
# [Train] mobilenet_v2 | Epoch 24 Batch 220/227 | Loss: 0.6203
# [Val] mobilenet_v2 | Epoch 24 Batch 0/49 | Loss: 0.8309
# [Val] mobilenet_v2 | Epoch 24 Batch 10/49 | Loss: 0.8094
# [Val] mobilenet_v2 | Epoch 24 Batch 20/49 | Loss: 0.7386
# [Val] mobilenet_v2 | Epoch 24 Batch 30/49 | Loss: 1.0453
# [Val] mobilenet_v2 | Epoch 24 Batch 40/49 | Loss: 0.6193
# mobilenet_v2 | Epoch 24/30 | Train Loss: 0.7949 | Train Acc: 0.7840 | Val Loss: 0.8146 | Val Acc: 0.7690
# Best model updated and saved to: /kaggle/working/best_mobilenet_v2.pth
#
# ===== mobilenet_v2 | Epoch 25/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 43.43701171875 MB
#   GPU memory reserved: 954.0 MB
# [Train] mobilenet_v2 | Epoch 25 Batch 0/227 | Loss: 0.6414
# [Train] mobilenet_v2 | Epoch 25 Batch 10/227 | Loss: 1.0092
# [Train] mobilenet_v2 | Epoch 25 Batch 20/227 | Loss: 0.7371
# [Train] mobilenet_v2 | Epoch 25 Batch 30/227 | Loss: 0.6708
# [Train] mobilenet_v2 | Epoch 25 Batch 40/227 | Loss: 0.7422
# [Train] mobilenet_v2 | Epoch 25 Batch 50/227 | Loss: 0.9451
# [Train] mobilenet_v2 | Epoch 25 Batch 60/227 | Loss: 0.8030
# [Train] mobilenet_v2 | Epoch 25 Batch 70/227 | Loss: 0.8902
# [Train] mobilenet_v2 | Epoch 25 Batch 80/227 | Loss: 0.8312
# [Train] mobilenet_v2 | Epoch 26 Batch 150/227 | Loss: 0.8661
# [Train] mobilenet_v2 | Epoch 26 Batch 160/227 | Loss: 0.7078
# [Train] mobilenet_v2 | Epoch 26 Batch 170/227 | Loss: 0.6719
# [Train] mobilenet_v2 | Epoch 26 Batch 180/227 | Loss: 0.8358
# [Train] mobilenet_v2 | Epoch 26 Batch 190/227 | Loss: 0.7970
# [Train] mobilenet_v2 | Epoch 26 Batch 200/227 | Loss: 1.0375
# [Train] mobilenet_v2 | Epoch 26 Batch 210/227 | Loss: 1.0262
# [Train] mobilenet_v2 | Epoch 26 Batch 220/227 | Loss: 0.7651
# [Val] mobilenet_v2 | Epoch 26 Batch 0/49 | Loss: 0.8054
# [Val] mobilenet_v2 | Epoch 26 Batch 10/49 | Loss: 0.7930
# [Val] mobilenet_v2 | Epoch 26 Batch 20/49 | Loss: 0.7250
# [Val] mobilenet_v2 | Epoch 26 Batch 30/49 | Loss: 1.0231
# [Val] mobilenet_v2 | Epoch 26 Batch 40/49 | Loss: 0.5920
# mobilenet_v2 | Epoch 26/30 | Train Loss: 0.7829 | Train Acc: 0.7859 | Val Loss: 0.7995 | Val Acc: 0.7831
# Best model updated and saved to: /kaggle/working/best_mobilenet_v2.pth
#
# ===== mobilenet_v2 | Epoch 27/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 43.43701171875 MB
#   GPU memory reserved: 954.0 MB
# [Train] mobilenet_v2 | Epoch 27 Batch 0/227 | Loss: 1.0492
# [Train] mobilenet_v2 | Epoch 27 Batch 10/227 | Loss: 1.1052
# [Train] mobilenet_v2 | Epoch 27 Batch 20/227 | Loss: 0.8055
# [Train] mobilenet_v2 | Epoch 27 Batch 30/227 | Loss: 0.7424
# [Train] mobilenet_v2 | Epoch 27 Batch 40/227 | Loss: 0.5205
# [Train] mobilenet_v2 | Epoch 27 Batch 50/227 | Loss: 0.5560
# [Train] mobilenet_v2 | Epoch 27 Batch 60/227 | Loss: 0.6029
# [Train] mobilenet_v2 | Epoch 27 Batch 70/227 | Loss: 0.7085
# [Train] mobilenet_v2 | Epoch 27 Batch 80/227 | Loss: 0.6084
# [Train] mobilenet_v2 | Epoch 27 Batch 90/227 | Loss: 0.7035
# [Train] mobilenet_v2 | Epoch 27 Batch 100/227 | Loss: 0.7075
# [Train] mobilenet_v2 | Epoch 27 Batch 110/227 | Loss: 0.8667
# [Train] mobilenet_v2 | Epoch 27 Batch 120/227 | Loss: 0.7557
# [Train] mobilenet_v2 | Epoch 27 Batch 130/227 | Loss: 0.6588
# [Train] mobilenet_v2 | Epoch 27 Batch 140/227 | Loss: 0.8371
# [Train] mobilenet_v2 | Epoch 27 Batch 150/227 | Loss: 0.5361
# [Train] mobilenet_v2 | Epoch 27 Batch 160/227 | Loss: 0.6721
# [Train] mobilenet_v2 | Epoch 27 Batch 170/227 | Loss: 0.8203
# [Train] mobilenet_v2 | Epoch 27 Batch 180/227 | Loss: 0.8428
# [Train] mobilenet_v2 | Epoch 27 Batch 190/227 | Loss: 0.5340
# [Train] mobilenet_v2 | Epoch 27 Batch 200/227 | Loss: 1.1053
# [Train] mobilenet_v2 | Epoch 27 Batch 210/227 | Loss: 0.7517
# [Train] mobilenet_v2 | Epoch 27 Batch 220/227 | Loss: 0.9642
# [Val] mobilenet_v2 | Epoch 27 Batch 0/49 | Loss: 0.8087
# [Val] mobilenet_v2 | Epoch 27 Batch 10/49 | Loss: 0.8090
# [Val] mobilenet_v2 | Epoch 27 Batch 20/49 | Loss: 0.7172
# [Val] mobilenet_v2 | Epoch 27 Batch 30/49 | Loss: 1.0250
# [Val] mobilenet_v2 | Epoch 27 Batch 40/49 | Loss: 0.6045
# mobilenet_v2 | Epoch 27/30 | Train Loss: 0.7729 | Train Acc: 0.7887 | Val Loss: 0.7953 | Val Acc: 0.7806
# Best model updated and saved to: /kaggle/working/best_mobilenet_v2.pth
#
# ===== mobilenet_v2 | Epoch 28/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 43.43701171875 MB
#   GPU memory reserved: 954.0 MB
# [Train] mobilenet_v2 | Epoch 28 Batch 0/227 | Loss: 0.6896
# [Train] mobilenet_v2 | Epoch 28 Batch 10/227 | Loss: 0.6714
# [Train] mobilenet_v2 | Epoch 28 Batch 20/227 | Loss: 0.9830
# [Train] mobilenet_v2 | Epoch 28 Batch 30/227 | Loss: 0.5546
# [Train] mobilenet_v2 | Epoch 28 Batch 40/227 | Loss: 0.9521
# [Train] mobilenet_v2 | Epoch 28 Batch 50/227 | Loss: 0.6273
# [Train] mobilenet_v2 | Epoch 28 Batch 60/227 | Loss: 0.8495
# [Train] mobilenet_v2 | Epoch 28 Batch 70/227 | Loss: 0.6559
# [Train] mobilenet_v2 | Epoch 28 Batch 80/227 | Loss: 1.1051
# [Train] mobilenet_v2 | Epoch 28 Batch 90/227 | Loss: 0.4821
# [Train] mobilenet_v2 | Epoch 28 Batch 100/227 | Loss: 0.6274
# [Train] mobilenet_v2 | Epoch 28 Batch 110/227 | Loss: 0.6135
# [Train] mobilenet_v2 | Epoch 28 Batch 120/227 | Loss: 1.1149
# [Train] mobilenet_v2 | Epoch 28 Batch 130/227 | Loss: 0.9439
# [Train] mobilenet_v2 | Epoch 28 Batch 140/227 | Loss: 0.7511
# [Train] mobilenet_v2 | Epoch 28 Batch 150/227 | Loss: 0.8118
# [Train] mobilenet_v2 | Epoch 28 Batch 160/227 | Loss: 0.6107
# [Train] mobilenet_v2 | Epoch 28 Batch 170/227 | Loss: 0.5343
# [Train] mobilenet_v2 | Epoch 28 Batch 180/227 | Loss: 0.6535
# [Train] mobilenet_v2 | Epoch 28 Batch 190/227 | Loss: 1.0291
# [Train] mobilenet_v2 | Epoch 28 Batch 200/227 | Loss: 0.7250
# [Train] mobilenet_v2 | Epoch 28 Batch 210/227 | Loss: 0.7809
# [Train] mobilenet_v2 | Epoch 28 Batch 220/227 | Loss: 0.7517
# [Val] mobilenet_v2 | Epoch 28 Batch 0/49 | Loss: 0.7862
# [Val] mobilenet_v2 | Epoch 28 Batch 10/49 | Loss: 0.7983
# [Val] mobilenet_v2 | Epoch 28 Batch 20/49 | Loss: 0.7045
# [Val] mobilenet_v2 | Epoch 28 Batch 30/49 | Loss: 1.0195
# [Val] mobilenet_v2 | Epoch 28 Batch 40/49 | Loss: 0.6010
# mobilenet_v2 | Epoch 28/30 | Train Loss: 0.7719 | Train Acc: 0.7837 | Val Loss: 0.7867 | Val Acc: 0.7819
# Best model updated and saved to: /kaggle/working/best_mobilenet_v2.pth
#
# ===== mobilenet_v2 | Epoch 29/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 43.43701171875 MB
#   GPU memory reserved: 954.0 MB
# [Train] mobilenet_v2 | Epoch 29 Batch 0/227 | Loss: 0.7105
# [Train] mobilenet_v2 | Epoch 29 Batch 10/227 | Loss: 0.5633
# [Train] mobilenet_v2 | Epoch 29 Batch 20/227 | Loss: 0.7851
# [Train] mobilenet_v2 | Epoch 29 Batch 30/227 | Loss: 0.6333
# [Train] mobilenet_v2 | Epoch 29 Batch 40/227 | Loss: 0.6025
# [Train] mobilenet_v2 | Epoch 29 Batch 50/227 | Loss: 0.9187
# [Train] mobilenet_v2 | Epoch 29 Batch 60/227 | Loss: 0.8299
# [Train] mobilenet_v2 | Epoch 29 Batch 70/227 | Loss: 0.6867
# [Train] mobilenet_v2 | Epoch 29 Batch 80/227 | Loss: 0.3661
# [Train] mobilenet_v2 | Epoch 29 Batch 90/227 | Loss: 0.5855
# [Train] mobilenet_v2 | Epoch 29 Batch 100/227 | Loss: 0.7152
# [Train] mobilenet_v2 | Epoch 29 Batch 110/227 | Loss: 0.8494
# [Train] mobilenet_v2 | Epoch 29 Batch 120/227 | Loss: 0.6356
# [Train] mobilenet_v2 | Epoch 29 Batch 130/227 | Loss: 1.1896
# [Train] mobilenet_v2 | Epoch 29 Batch 140/227 | Loss: 0.8199
# [Train] mobilenet_v2 | Epoch 29 Batch 150/227 | Loss: 0.7149
# [Train] mobilenet_v2 | Epoch 29 Batch 160/227 | Loss: 0.9707
# [Train] mobilenet_v2 | Epoch 29 Batch 170/227 | Loss: 0.7881
# [Train] mobilenet_v2 | Epoch 29 Batch 180/227 | Loss: 0.5313
# [Train] mobilenet_v2 | Epoch 29 Batch 190/227 | Loss: 0.7466
# [Train] mobilenet_v2 | Epoch 29 Batch 200/227 | Loss: 0.6621
# [Train] mobilenet_v2 | Epoch 29 Batch 210/227 | Loss: 0.7135
# [Train] mobilenet_v2 | Epoch 29 Batch 220/227 | Loss: 0.5489
# [Val] mobilenet_v2 | Epoch 29 Batch 0/49 | Loss: 0.7906
# [Val] mobilenet_v2 | Epoch 29 Batch 10/49 | Loss: 0.7963
# [Val] mobilenet_v2 | Epoch 29 Batch 20/49 | Loss: 0.7140
# [Val] mobilenet_v2 | Epoch 29 Batch 30/49 | Loss: 1.0162
# [Val] mobilenet_v2 | Epoch 29 Batch 40/49 | Loss: 0.6029
# mobilenet_v2 | Epoch 29/30 | Train Loss: 0.7620 | Train Acc: 0.7884 | Val Loss: 0.7881 | Val Acc: 0.7735
# No improvement. Early stop counter: 1/5
#
# ===== mobilenet_v2 | Epoch 30/30 =====
# Before move:
#   images device: cpu
#   labels device: cpu
# After move:
#   images device: cuda:0
#   labels device: cuda:0
#   model device: cuda:0
#   GPU memory allocated: 43.43701171875 MB
#   GPU memory reserved: 954.0 MB
# [Train] mobilenet_v2 | Epoch 30 Batch 0/227 | Loss: 0.5830
# [Train] mobilenet_v2 | Epoch 30 Batch 10/227 | Loss: 0.5163
# [Train] mobilenet_v2 | Epoch 30 Batch 20/227 | Loss: 0.8561
# [Train] mobilenet_v2 | Epoch 30 Batch 30/227 | Loss: 0.7128
# [Train] mobilenet_v2 | Epoch 30 Batch 40/227 | Loss: 0.7713
# [Train] mobilenet_v2 | Epoch 30 Batch 50/227 | Loss: 0.7659
# [Train] mobilenet_v2 | Epoch 30 Batch 60/227 | Loss: 0.6752
# [Train] mobilenet_v2 | Epoch 30 Batch 70/227 | Loss: 0.9143
# [Train] mobilenet_v2 | Epoch 30 Batch 80/227 | Loss: 0.9060
# [Train] mobilenet_v2 | Epoch 30 Batch 90/227 | Loss: 0.7565
# [Train] mobilenet_v2 | Epoch 30 Batch 100/227 | Loss: 0.6394
# [Train] mobilenet_v2 | Epoch 30 Batch 110/227 | Loss: 0.7136
# [Train] mobilenet_v2 | Epoch 30 Batch 120/227 | Loss: 0.7132
# [Train] mobilenet_v2 | Epoch 30 Batch 130/227 | Loss: 0.7977
# [Train] mobilenet_v2 | Epoch 30 Batch 140/227 | Loss: 0.7827
# [Train] mobilenet_v2 | Epoch 30 Batch 150/227 | Loss: 0.7246
# [Train] mobilenet_v2 | Epoch 30 Batch 160/227 | Loss: 0.8020
# [Train] mobilenet_v2 | Epoch 30 Batch 170/227 | Loss: 0.9298
# [Train] mobilenet_v2 | Epoch 30 Batch 180/227 | Loss: 0.8675
# [Train] mobilenet_v2 | Epoch 30 Batch 190/227 | Loss: 0.8663
# [Train] mobilenet_v2 | Epoch 30 Batch 200/227 | Loss: 0.7061
# [Train] mobilenet_v2 | Epoch 30 Batch 210/227 | Loss: 0.7543
# [Train] mobilenet_v2 | Epoch 30 Batch 220/227 | Loss: 0.8000
# [Val] mobilenet_v2 | Epoch 30 Batch 0/49 | Loss: 0.7833
# [Val] mobilenet_v2 | Epoch 30 Batch 10/49 | Loss: 0.7891
# [Val] mobilenet_v2 | Epoch 30 Batch 20/49 | Loss: 0.7204
# [Val] mobilenet_v2 | Epoch 30 Batch 30/49 | Loss: 1.0107
# [Val] mobilenet_v2 | Epoch 30 Batch 40/49 | Loss: 0.5911
# mobilenet_v2 | Epoch 30/30 | Train Loss: 0.7588 | Train Acc: 0.7844 | Val Loss: 0.7816 | Val Acc: 0.7819
# Best model updated and saved to: /kaggle/working/best_mobilenet_v2.pth
# Training completed for mobilenet_v2.
# Best validation accuracy: 0.7818532818532818
#
# All model training completed.
# Benchmark summary saved to: /kaggle/working/model_benchmark_summary.csv
#         model_name  best_epoch  best_train_loss  best_train_acc  \
# 0         resnet50          28         0.761682        0.798869
# 1  efficientnet_b0          30         0.740549        0.797351
# 2     mobilenet_v2          30         0.758806        0.784384
#
#    best_val_loss  best_val_acc  total_epochs_trained  early_stopped  \
# 0       0.780177      0.797297                    30          False
# 1       0.728707      0.814672                    30          False
# 2       0.781567      0.781853                    30          False
#
#                             best_model_path  \
# 0         /kaggle/working/best_resnet50.pth
# 1  /kaggle/working/best_efficientnet_b0.pth
# 2     /kaggle/working/best_mobilenet_v2.pth
#
#                                         history_path
# 0      /kaggle/working/resnet50_training_history.csv
# 1  /kaggle/working/efficientnet_b0_training_histo...
# 2  /kaggle/working/mobilenet_v2_training_history.csv

# %% [markdown]
# ## Convergence behavior

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

def plot_convergence(model_name, output_dir, max_epochs=30):
    output_dir = Path(output_dir)

    history_path = output_dir / f"{model_name}_training_history.csv"
    df = pd.read_csv(history_path)

    # limit to first N epochs if needed
    df = df[df["epoch"] <= max_epochs]

    # ===== Loss plot =====
    plt.figure(figsize=(10, 5))
    plt.plot(df["epoch"], df["train_loss"], label="Train Loss")
    plt.plot(df["epoch"], df["val_loss"], label="Validation Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title(f"Convergence (Loss) - {model_name}")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()

    loss_path = output_dir / f"{model_name}_convergence_loss.png"
    plt.savefig(loss_path, dpi=300)
    plt.show()

    # ===== Accuracy plot =====
    plt.figure(figsize=(10, 5))
    plt.plot(df["epoch"], df["train_acc"], label="Train Accuracy")
    plt.plot(df["epoch"], df["val_acc"], label="Validation Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.title(f"Convergence (Accuracy) - {model_name}")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()

    acc_path = output_dir / f"{model_name}_convergence_accuracy.png"
    plt.savefig(acc_path, dpi=300)
    plt.show()

    print(f"Saved plots for {model_name}")


def compare_convergence(model_names, output_dir, max_epochs=30):
    output_dir = Path(output_dir)

    plt.figure(figsize=(12, 6))

    for model_name in model_names:
        df = pd.read_csv(output_dir / f"{model_name}_training_history.csv")
        df = df[df["epoch"] <= max_epochs]

        plt.plot(df["epoch"], df["val_loss"], label=model_name)

    plt.xlabel("Epoch")
    plt.ylabel("Validation Loss")
    plt.title("Validation Loss Convergence Comparison")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()

    plt.savefig(output_dir / "compare_val_loss.png", dpi=300)
    plt.show()


    plt.figure(figsize=(12, 6))

    for model_name in model_names:
        df = pd.read_csv(output_dir / f"{model_name}_training_history.csv")
        df = df[df["epoch"] <= max_epochs]

        plt.plot(df["epoch"], df["val_acc"], label=model_name)

    plt.xlabel("Epoch")
    plt.ylabel("Validation Accuracy")
    plt.title("Validation Accuracy Convergence Comparison")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()

    plt.savefig(output_dir / "compare_val_accuracy.png", dpi=300)
    plt.show()

# %%
output_dir = Path("/kaggle/working/")

# Plot each model separately
for model_name in MODEL_NAMES:
    plot_convergence(
        model_name=model_name,
        output_dir=output_dir,
        max_epochs=30
    )

# Plot comparison across selected models
compare_convergence(
    model_names=MODEL_NAMES,
    output_dir=output_dir,
    max_epochs=30
)
# Out:
# Saved plots for resnet50
# Saved plots for efficientnet_b0
# Saved plots for mobilenet_v2

# %% [markdown]
# # Evaluation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from pathlib import Path
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    f1_score,
    recall_score,
    precision_score,
    classification_report,
    confusion_matrix,
    roc_auc_score,
    roc_curve,
    auc
)
from sklearn.preprocessing import label_binarize


# =========================
# Test evaluation function
# =========================

def evaluate_on_test_set(
    model,
    test_loader,
    device,
    class_names,
    output_dir,
    model_name="model"
):
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

    model.eval()

    all_probs = []
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            outputs = model(images)
            probs = torch.softmax(outputs, dim=1)
            preds = torch.argmax(probs, dim=1)

            all_probs.append(probs.cpu().numpy())
            all_preds.append(preds.cpu().numpy())
            all_labels.append(labels.cpu().numpy())

    all_probs = np.concatenate(all_probs, axis=0)
    all_preds = np.concatenate(all_preds, axis=0)
    all_labels = np.concatenate(all_labels, axis=0)

    num_classes = len(class_names)

    # =========================
    # Overall metrics
    # =========================

    accuracy = accuracy_score(all_labels, all_preds)
    balanced_acc = balanced_accuracy_score(all_labels, all_preds)

    f1_macro = f1_score(all_labels, all_preds, average="macro")
    f1_weighted = f1_score(all_labels, all_preds, average="weighted")

    recall_macro = recall_score(all_labels, all_preds, average="macro")
    recall_weighted = recall_score(all_labels, all_preds, average="weighted")

    precision_macro = precision_score(all_labels, all_preds, average="macro", zero_division=0)
    precision_weighted = precision_score(all_labels, all_preds, average="weighted", zero_division=0)

    # ROC-AUC
    try:
        if num_classes == 2:
            roc_auc = roc_auc_score(all_labels, all_probs[:, 1])
        else:
            roc_auc = roc_auc_score(
                all_labels,
                all_probs,
                multi_class="ovr",
                average="macro"
            )
    except Exception as e:
        print("ROC-AUC could not be calculated:", e)
        roc_auc = np.nan

    metrics_df = pd.DataFrame([{
        "model_name": model_name,
        "accuracy": accuracy,
        "balanced_accuracy": balanced_acc,
        "f1_macro": f1_macro,
        "f1_weighted": f1_weighted,
        "recall_macro": recall_macro,
        "recall_weighted": recall_weighted,
        "precision_macro": precision_macro,
        "precision_weighted": precision_weighted,
        "roc_auc_ovr_macro": roc_auc
    }])

    metrics_path = output_dir / f"{model_name}_test_metrics.csv"
    metrics_df.to_csv(metrics_path, index=False)

    print(f"Saved test metrics to: {metrics_path}")
    print(metrics_df)

    # =========================
    # Per-class classification report
    # =========================

    report_dict = classification_report(
        all_labels,
        all_preds,
        target_names=class_names,
        output_dict=True,
        zero_division=0
    )

    report_df = pd.DataFrame(report_dict).transpose()
    report_path = output_dir / f"{model_name}_classification_report.csv"
    report_df.to_csv(report_path)

    print(f"Saved classification report to: {report_path}")

    # =========================
    # Prediction probabilities CSV
    # =========================

    prob_df = pd.DataFrame(all_probs, columns=[f"prob_{c}" for c in class_names])
    pred_df = pd.DataFrame({
        "true_label_id": all_labels,
        "pred_label_id": all_preds,
        "true_class": [class_names[i] for i in all_labels],
        "pred_class": [class_names[i] for i in all_preds],
        "confidence": np.max(all_probs, axis=1)
    })

    prediction_df = pd.concat([pred_df, prob_df], axis=1)
    prediction_path = output_dir / f"{model_name}_test_predictions.csv"
    prediction_df.to_csv(prediction_path, index=False)

    print(f"Saved test predictions to: {prediction_path}")

    # =========================
    # Confusion matrix
    # =========================

    cm = confusion_matrix(all_labels, all_preds)

    cm_df = pd.DataFrame(
        cm,
        index=class_names,
        columns=class_names
    )

    cm_path = output_dir / f"{model_name}_confusion_matrix.csv"
    cm_df.to_csv(cm_path)

    plt.figure(figsize=(12, 10))
    sns.heatmap(
        cm_df,
        annot=True,
        fmt="d",
        cmap="Blues",
        xticklabels=class_names,
        yticklabels=class_names
    )
    plt.xlabel("Predicted Class")
    plt.ylabel("True Class")
    plt.title(f"Confusion Matrix - {model_name}")
    plt.xticks(rotation=45, ha="right")
    plt.yticks(rotation=0)
    plt.tight_layout()

    cm_plot_path = output_dir / f"{model_name}_confusion_matrix.png"
    plt.savefig(cm_plot_path, dpi=300)
    plt.show()

    print(f"Saved confusion matrix plot to: {cm_plot_path}")

    # =========================
    # Normalized confusion matrix
    # =========================

    cm_norm = cm.astype("float") / cm.sum(axis=1, keepdims=True)
    cm_norm = np.nan_to_num(cm_norm)

    cm_norm_df = pd.DataFrame(
        cm_norm,
        index=class_names,
        columns=class_names
    )

    plt.figure(figsize=(12, 10))
    sns.heatmap(
        cm_norm_df,
        annot=True,
        fmt=".2f",
        cmap="Blues",
        xticklabels=class_names,
        yticklabels=class_names
    )
    plt.xlabel("Predicted Class")
    plt.ylabel("True Class")
    plt.title(f"Normalized Confusion Matrix - {model_name}")
    plt.xticks(rotation=45, ha="right")
    plt.yticks(rotation=0)
    plt.tight_layout()

    cm_norm_plot_path = output_dir / f"{model_name}_normalized_confusion_matrix.png"
    plt.savefig(cm_norm_plot_path, dpi=300)
    plt.show()

    print(f"Saved normalized confusion matrix plot to: {cm_norm_plot_path}")

    # =========================
    # Per-class score visualization
    # =========================

    per_class_df = report_df.loc[class_names, ["precision", "recall", "f1-score", "support"]]
    per_class_score_path = output_dir / f"{model_name}_per_class_scores.csv"
    per_class_df.to_csv(per_class_score_path)

    per_class_df[["precision", "recall", "f1-score"]].plot(
        kind="bar",
        figsize=(14, 7)
    )
    plt.title(f"Per-Class Precision, Recall, F1 Score - {model_name}")
    plt.xlabel("Class")
    plt.ylabel("Score")
    plt.ylim(0, 1)
    plt.xticks(rotation=45, ha="right")
    plt.tight_layout()

    score_plot_path = output_dir / f"{model_name}_per_class_scores.png"
    plt.savefig(score_plot_path, dpi=300)
    plt.show()

    print(f"Saved per-class score plot to: {score_plot_path}")

    # =========================
    # ROC curve
    # =========================

    plt.figure(figsize=(10, 8))

    if num_classes == 2:
        fpr, tpr, _ = roc_curve(all_labels, all_probs[:, 1])
        roc_auc_binary = auc(fpr, tpr)

        plt.plot(fpr, tpr, label=f"{class_names[1]} AUC = {roc_auc_binary:.4f}")

    else:
        y_true_bin = label_binarize(all_labels, classes=list(range(num_classes)))

        for i, class_name in enumerate(class_names):
            fpr, tpr, _ = roc_curve(y_true_bin[:, i], all_probs[:, i])
            class_auc = auc(fpr, tpr)
            plt.plot(fpr, tpr, label=f"{class_name} AUC = {class_auc:.4f}")

    plt.plot([0, 1], [0, 1], linestyle="--")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title(f"ROC-AUC Curve - {model_name}")
    plt.legend(loc="lower right")
    plt.tight_layout()

    roc_plot_path = output_dir / f"{model_name}_roc_auc_curve.png"
    plt.savefig(roc_plot_path, dpi=300)
    plt.show()

    print(f"Saved ROC-AUC curve to: {roc_plot_path}")

    return {
        "metrics_df": metrics_df,
        "classification_report_df": report_df,
        "predictions_df": prediction_df,
        "confusion_matrix_df": cm_df,
        "per_class_df": per_class_df
    }

# %%
output_dir = Path("/kaggle/working/")
eval_output_dir = output_dir / "evaluation_on_test_set"
eval_output_dir.mkdir(parents=True, exist_ok=True)


all_test_metrics = []

for model_name in MODEL_NAMES:
    print(f"\nEvaluating {model_name}")

    # Rebuild model architecture
    model = build_model(
        model_name=model_name,
        num_classes=num_classes,
        freeze_backbone=True
    ).to(device)

    # Load best checkpoint
    checkpoint_path = output_dir / f"best_{model_name}.pth"
    checkpoint = torch.load(checkpoint_path, map_location=device)

    model.load_state_dict(checkpoint["model_state_dict"])

    # Evaluate
    results = evaluate_on_test_set(
        model=model,
        test_loader=test_loader,
        device=device,
        class_names=class_names,
        output_dir=eval_output_dir,
        model_name=model_name
    )

    # Collect overall metrics
    metrics_df = results["metrics_df"]
    all_test_metrics.append(metrics_df)

# Combine all model test results
all_test_metrics_df = pd.concat(all_test_metrics, ignore_index=True)

summary_path = eval_output_dir / "all_models_test_evaluation_summary.csv"
all_test_metrics_df.to_csv(summary_path, index=False)

print("\nAll model evaluation completed.")
print(f"Saved summary to: {summary_path}")

all_test_metrics_df
# Out:
# Evaluating resnet50
# Saved test metrics to: /kaggle/working/evaluation_on_test_set/resnet50_test_metrics.csv
#   model_name  accuracy  balanced_accuracy  f1_macro  f1_weighted  \
# 0   resnet50   0.80695           0.303812  0.285337     0.757975
#
#    recall_macro  recall_weighted  precision_macro  precision_weighted  \
# 0      0.303812          0.80695         0.269189            0.715157
#
#    roc_auc_ovr_macro
# 0           0.743967
# Saved classification report to: /kaggle/working/evaluation_on_test_set/resnet50_classification_report.csv
# Saved test predictions to: /kaggle/working/evaluation_on_test_set/resnet50_test_predictions.csv
# Saved confusion matrix plot to: /kaggle/working/evaluation_on_test_set/resnet50_confusion_matrix.png
# Saved normalized confusion matrix plot to: /kaggle/working/evaluation_on_test_set/resnet50_normalized_confusion_matrix.png
# Saved per-class score plot to: /kaggle/working/evaluation_on_test_set/resnet50_per_class_scores.png
# Saved ROC-AUC curve to: /kaggle/working/evaluation_on_test_set/resnet50_roc_auc_curve.png
#
# Evaluating efficientnet_b0
# Saved test metrics to: /kaggle/working/evaluation_on_test_set/efficientnet_b0_test_metrics.csv
#         model_name  accuracy  balanced_accuracy  f1_macro  f1_weighted  \
# 0  efficientnet_b0   0.82175           0.313255  0.299428     0.775117
#
#    recall_macro  recall_weighted  precision_macro  precision_weighted  \
# 0      0.313255          0.82175         0.524895            0.801754
#
#    roc_auc_ovr_macro
# 0           0.721604
# Saved classification report to: /kaggle/working/evaluation_on_test_set/efficientnet_b0_classification_report.csv
# Saved test predictions to: /kaggle/working/evaluation_on_test_set/efficientnet_b0_test_predictions.csv
# Saved confusion matrix plot to: /kaggle/working/evaluation_on_test_set/efficientnet_b0_confusion_matrix.png
# Saved normalized confusion matrix plot to: /kaggle/working/evaluation_on_test_set/efficientnet_b0_normalized_confusion_matrix.png
# Saved per-class score plot to: /kaggle/working/evaluation_on_test_set/efficientnet_b0_per_class_scores.png
# Saved ROC-AUC curve to: /kaggle/working/evaluation_on_test_set/efficientnet_b0_roc_auc_curve.png
#
# Evaluating mobilenet_v2
# Saved test metrics to: /kaggle/working/evaluation_on_test_set/mobilenet_v2_test_metrics.csv
#      model_name  accuracy  balanced_accuracy  f1_macro  f1_weighted  \
# 0  mobilenet_v2  0.790219           0.297581  0.279583     0.742718
#
#    recall_macro  recall_weighted  precision_macro  precision_weighted  \
# 0      0.297581         0.790219           0.2657            0.706087
#
#    roc_auc_ovr_macro
# 0           0.733981
# Saved classification report to: /kaggle/working/evaluation_on_test_set/mobilenet_v2_classification_report.csv
# Saved test predictions to: /kaggle/working/evaluation_on_test_set/mobilenet_v2_test_predictions.csv
# Saved confusion matrix plot to: /kaggle/working/evaluation_on_test_set/mobilenet_v2_confusion_matrix.png
# Saved normalized confusion matrix plot to: /kaggle/working/evaluation_on_test_set/mobilenet_v2_normalized_confusion_matrix.png
# Saved per-class score plot to: /kaggle/working/evaluation_on_test_set/mobilenet_v2_per_class_scores.png
# Saved ROC-AUC curve to: /kaggle/working/evaluation_on_test_set/mobilenet_v2_roc_auc_curve.png
#
# All model evaluation completed.
# Saved summary to: /kaggle/working/evaluation_on_test_set/all_models_test_evaluation_summary.csv
#         model_name  accuracy  balanced_accuracy  f1_macro  f1_weighted  \
# 0         resnet50  0.806950           0.303812  0.285337     0.757975
# 1  efficientnet_b0  0.821750           0.313255  0.299428     0.775117
# 2     mobilenet_v2  0.790219           0.297581  0.279583     0.742718
#
#    recall_macro  recall_weighted  precision_macro  precision_weighted  \
# 0      0.303812         0.806950         0.269189            0.715157
# 1      0.313255         0.821750         0.524895            0.801754
# 2      0.297581         0.790219         0.265700            0.706087
#
#    roc_auc_ovr_macro
# 0           0.743967
# 1           0.721604
# 2           0.733981
